# %%
# !pip install datasets evaluate transformers[sentencepiece]
# !pip install accelerate
# # To run the training on TPU, you will need to uncomment the following line:
# # !pip install cloud-tpu-client==0.10 torch==1.9.0 https://storage.googleapis.com/tpu-pytorch/wheels/torch_xla-1.9-cp37-cp37m-linux_x86_64.whl
# !apt install git-lfs

# %%
import torch

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
from datasets import load_dataset

from datasets import load_from_disk

load_dir = "../data/my_data_NO_ZERO"

raw_datasets = load_from_disk(load_dir)
print(raw_datasets)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'title', 'context', 'question', 'answers'],
#         num_rows: 7464
#     })
#     validation: Dataset({
#         features: ['id', 'title', 'context', 'question', 'answers'],
#         num_rows: 1792
#     })
# })

# %%
raw_datasets['train'][0]
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased")

# %%
def preprocess_function(examples):
    questions = [q.strip() for q in examples["question"]]
    inputs = tokenizer(
        questions,
        examples["context"],
        max_length=384,
        truncation="only_second",
        return_offsets_mapping=True,
        padding="max_length",
    )

    offset_mapping = inputs.pop("offset_mapping")
    answers = examples["answers"]
    start_positions = []
    end_positions = []

    for i, offset in enumerate(offset_mapping):
        answer = answers[i]
        start_char = answer["answer_start"][0]
        end_char = answer["answer_start"][0] + len(answer["text"][0])
        sequence_ids = inputs.sequence_ids(i)

        # Find the start and end of the context
        idx = 0
        while sequence_ids[idx] != 1:
            idx += 1
        context_start = idx
        while sequence_ids[idx] == 1:
            idx += 1
        context_end = idx - 1

        # If the answer is not fully inside the context, label it (0, 0)
        if offset[context_start][0] > end_char or offset[context_end][1] < start_char:
            start_positions.append(0)
            end_positions.append(0)
        else:
            # Otherwise it's the start and end token positions
            idx = context_start
            while idx <= context_end and offset[idx][0] <= start_char:
                idx += 1
            start_positions.append(idx - 1)

            idx = context_end
            while idx >= context_start and offset[idx][1] >= end_char:
                idx -= 1
            end_positions.append(idx + 1)

    inputs["start_positions"] = start_positions
    inputs["end_positions"] = end_positions
    return inputs

# %%
tokenized_dataset = raw_datasets.map(preprocess_function, batched=True, remove_columns=raw_datasets["train"].column_names)

# %%
from transformers import DefaultDataCollator
data_collator = DefaultDataCollator()
# Out:
# 2024-04-26 00:07:32.547031: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-26 00:07:32.547079: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-26 00:07:32.547925: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-26 00:07:32.553978: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-26 00:07:33.524548: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from transformers import AutoModelForQuestionAnswering, TrainingArguments, Trainer, AutoConfig

config = AutoConfig.from_pretrained('distilbert-base-uncased')
model = AutoModelForQuestionAnswering.from_pretrained("distilbert-base-uncased").to('cuda')
# Out:
# Some weights of DistilBertForQuestionAnswering were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
training_args = TrainingArguments(
    output_dir="span_nz",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=5,
    weight_decay=0.01,
    push_to_hub=True,
)

trainer = Trainer(
    model=model,
    args=training_args,
    tokenizer=tokenizer,
    train_dataset=tokenized_dataset["train"],
    eval_dataset=tokenized_dataset["validation"],
    data_collator=data_collator,
)

trainer.train()
# Out:
# /home/nsl/gpu_env_pip/lib64/python3.10/site-packages/accelerate/accelerator.py:436: FutureWarning: Passing the following arguments to `Accelerator` is deprecated and will be removed in version 1.0 of Accelerate: dict_keys(['dispatch_batches', 'split_batches', 'even_batches', 'use_seedable_sampler']). Please pass an `accelerate.DataLoaderConfiguration` instead:
# dataloader_config = DataLoaderConfiguration(dispatch_batches=None, split_batches=False, even_batches=True, use_seedable_sampler=True)
#   warnings.warn(
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: sachinsharma (iiitd-sachin). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/nsl/nlp/project/src/wandb/run-20240426_000739-c5d8s63z</code>
# Syncing run <strong><a href='https://wandb.ai/iiitd-sachin/huggingface/runs/c5d8s63z' target="_blank">absurd-fire-9</a></strong> to <a href='https://wandb.ai/iiitd-sachin/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/iiitd-sachin/huggingface' target="_blank">https://wandb.ai/iiitd-sachin/huggingface</a>
#  View run at <a href='https://wandb.ai/iiitd-sachin/huggingface/runs/c5d8s63z' target="_blank">https://wandb.ai/iiitd-sachin/huggingface/runs/c5d8s63z</a>
#     <div>
#
#       <progress value='2335' max='2335' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2335/2335 06:28, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.588528</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.933300</td>
#       <td>0.599740</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.470400</td>
#       <td>0.631586</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.349800</td>
#       <td>0.704786</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.268200</td>
#       <td>0.752165</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=2335, training_loss=0.4655816023048548, metrics={'train_runtime': 390.9338, 'train_samples_per_second': 95.464, 'train_steps_per_second': 5.973, 'total_flos': 3656980269895680.0, 'train_loss': 0.4655816023048548, 'epoch': 5.0})

# %%
model.save_pretrained("../models/span_nz")
tokenizer.save_pretrained("../models/span_nz")
# Out:
# ('../models/span_nz/tokenizer_config.json',
#  '../models/span_nz/special_tokens_map.json',
#  '../models/span_nz/vocab.txt',
#  '../models/span_nz/added_tokens.json',
#  '../models/span_nz/tokenizer.json')

# %%
from transformers import AutoModelForQuestionAnswering

model = AutoModelForQuestionAnswering.from_pretrained("../models/span_nz").to('cuda')

# %%
raw_datasets['validation']['question']
# Out:
# ['hey',
#  'check this out huh yeah that is the stuff what do you think',
#  'all right look you are not really gonna buy that are you do not you think you have embarrassed me enough for one day',
#  'oh i embarrass you',
#  'oh i embarrass you',
#  'all right look if you insist on wearing that in public you know you are gonna spend the rest of the afternoon all by yourself',
#  'oh yeah if you are gonna make me choose between you and the hat i choose the hat',
#  'oh yeah if you are gonna make me choose between you and the hat i choose the hat',
#  'okay wait all right that is it okay i am out of here i am not going to be embarrassed anymore',
#  'look this is ridiculous we should be packing you',
#  'great monica moving',
#  'i am not',
#  'oh really then how come all your stuff is in this box',
#  'hey',
#  'hey',
#  'hey',
#  'you were the next caller five hours ago you must be going crazy',
#  'you were the next caller five hours ago you must be going crazy',
#  'hey hey what going on',
#  'she broke my arm',
#  'he touched my fanny',
#  'no she touched mine first',
#  'that is my job',
#  'that is my job',
#  'wow this girl is good',
#  'oh ho yeah a song with rhyming words oo i never thought of that before',
#  'look at you all jealous',
#  'okay see see everyone else is happy she is done',
#  'oh no one of those look for the hidden meaning songs',
#  'oh no one of those look for the hidden meaning songs',
#  'oh no one of those look for the hidden meaning songs',
#  'and now you want that money back',
#  'and now you want that money back',
#  'chandler what kind of an idiot do you take me for',
#  'chandler what kind of an idiot do you take me for',
#  'chandler what kind of an idiot do you take me for',
#  'chandler what kind of an idiot do you take me for',
#  'it is not a real game i made it up',
#  'i am sorry you lost your money but i won it fair and square',
#  'i am sorry you lost your money but i won it fair and square',
#  'i am sorry you lost your money but i won it fair and square',
#  'look here is a picture of scotty jared naked',
#  'hey he is wearing a sweater',
#  'hey he is wearing a sweater',
#  'really',
#  'oh oh did did did i wake you',
#  'hmmm this is so nice',
#  'ohhh',
#  'oh look at the little cat',
#  'what',
#  'hey guys guys did you see my new china cabinet',
#  'hey my father house does that',
#  'o o o okay how did it go tell me everything',
#  'all right let do it',
#  'no no no what was that',
#  'joey could you get that what are you doing here i thought you were in your room',
#  'ohh lilies joey they are my favorite thank you',
#  'ohh lilies joey they are my favorite thank you',
#  'oh man',
#  'this is so great',
#  'i actually feel like i am going on a real date',
#  'i actually feel like i am going on a real date',
#  'oh a subscription to playboy my kind of woman',
#  'oh yeah it must be tough to keep your hands of him huh',
#  'oh yeah it must be tough to keep your hands of him huh',
#  'no no no no he is not no why are you trying to ruin the game come on',
#  'no no no no he is not no why are you trying to ruin the game come on',
#  'what are you doing here',
#  'what',
#  'my father is chuck magioni',
#  'no no that is just chuck magioni i i sold him a house last year',
#  'no no that is just chuck magioni i i sold him a house last year',
#  'and i am very sorry but i do not know where your father is and that is the truth',
#  'oh',
#  'heh',
#  'you know i wanted to tell you yesterday but i just i kinda felt all floopy and',
#  'uh huh uh huh',
#  'okay okay this can go on for a while',
#  'that sounds fair',
#  'that sounds fair',
#  'maybe i will take her to that new french restaurant down the street',
#  'ah yeah wait a second now',
#  'i do not have the money to take her to a fancy place like that',
#  'i do not have the money to take her to a fancy place like that',
#  'now you know how you really feel about it',
#  'oh oh that is a risky little game',
#  'oh oh that is a risky little game',
#  'oh oh that is a risky little game',
#  'are you really gonna do this',
#  'yeah i am gonna have a baby i am gonna have a baby i am gonna have a baby',
#  'with who',
#  'ah it is still not the time',
#  'chandler gone again',
#  'oh my god why would you play hide and seek with someone you know is a flight risk',
#  'oh my god why would you play hide and seek with someone you know is a flight risk',
#  'aw we we are so so umm well i i i like you and i i love umm you know hanging out with you',
#  'aw we we are so so umm well i i i like you and i i love umm you know hanging out with you',
#  'aw we we are so so umm well i i i like you and i i love umm you know hanging out with you',
#  'and i mean i am having a lot of fun',
#  'and and the answer is is it is going somewhere fun',
#  'julie cervix is dilated a seven centimeters that is about four fingers the doctor let me feel it myself',
#  'gotta go i miss you too i love you but it is getting real late now',
#  'excuse me',
#  'did you know this is not ma',
#  'since then',
#  'since then',
#  'since then',
#  'you are one to talk',
#  'oh man please tell me one of them is ma',
#  'of course course one of them is ma what the matter with you',
#  'of course course one of them is ma what the matter with you',
#  'looks good uh',
#  'oh my god you guys are selling the entertainment center',
#  'why i love that thing',
#  'oh no',
#  'oh no',
#  'ahh gepeto five zero zero zero dollars are you insane',
#  'what kind of profit is that and you call yourself an accountant',
#  'what kind of profit is that and you call yourself an accountant',
#  'what kind of profit is that and you call yourself an accountant',
#  'nooo',
#  'nooo',
#  'oh what do you do',
#  'oh what do you do',
#  'oh just say it kyle',
#  'what about her whining and her constant need for attention',
#  'what about her whining and her constant need for attention',
#  'oh right because you are so capable of change',
#  'you know he hums when he pees',
#  'you know he hums when he pees',
#  'it makes him miss the bowl but whatever',
#  'it makes him miss the bowl but whatever',
#  'that is all right we we do not need you in fact hey i am over it already',
#  'yeah and you know what i do not give a tiny rat ass',
#  'and you know even if they break up again you would better not let him in your sad men club',
#  'you are so efficient i love you',
#  'let go',
#  'no no no we need something old',
#  'that will work',
#  'that will work',
#  'that will work',
#  'okay now we just need something borrowed',
#  'that is stealing',
#  'that is stealing',
#  'that is stealing',
#  'it is brilliant',
#  'goodbye mike we will see you at the wedding fella',
#  'well you are welcome glad i could help',
#  'but i am not gay and i especially would not want you to think i was gay',
#  'well so anyway beth what i am saying is i should have considered your feelings before i went home with you that night',
#  'i have ah i have recently learned what it like to be on your side of it and i am sorry',
#  'i have ah i have recently learned what it like to be on your side of it and i am sorry',
#  'so do you think you can forgive me',
#  'so do you think you can forgive me',
#  'oh hi mrs loreo is jennifer there',
#  'oh she is not home huh',
#  'look all my stuff is safe and dry and all hers is is is growing new stuff',
#  'see this is exactly the kind of thing that makes her think you guys love me more than you love her',
#  'see this is exactly the kind of thing that makes her think you guys love me more than you love her',
#  'oh my god does she really thinks that',
#  'oh my god does she really thinks that',
#  'well can you blame her',
#  'well can you blame her',
#  'well i do not know i i suppose we may have favored you unconsciously you were a medical marvel the doctor said your mother could',
#  'dad dad i do not want to hear about it',
#  'really',
#  'okay look monica came here for some memories and damnit we are gonna give her some',
#  'uh look buddy i came with that girl and i had this plan to kiss her at the new years countdown i am trying to win her over so i was wondering if',
#  'hey',
#  'manhattan does not have enough stores',
#  'you can',
#  'we are here',
#  'where have you been',
#  'oh my god phoebe look it is ross and that girl',
#  'no no look at that it is a line of ants they are working as a team',
#  'wow oh it looks like ross is breaking up with her',
#  'uff i hope he lets her down easy',
#  'come on phoebe look at that',
#  'that is a that is a second date that is what that is',
#  'look at that she just put her hand on his thigh',
#  'ohh phoebe this is all your fault now he loves her he is gonna marry her and this is all your fault',
#  'oh do not thank me thank the jerk that never showed up okay i gotta get to get to work',
#  'whew stood up too fast got a little head rush',
#  'like you would not believe wow this is a great place',
#  'like you would not believe wow this is a great place',
#  'monica what time is it',
#  'i am really getting tired of sneaking around',
#  'hey',
#  'you know we would have no interruptions and we could be naked the entire time',
#  'all weekend that is a whole lotta naked',
#  'all weekend that is a whole lotta naked',
#  'ohh i have always wanted to go to this culinary fair that they have in jersey',
#  'ohh i have always wanted to go to this culinary fair that they have in jersey',
#  'ok i am making a break for it i am going out the window',
#  'no no no do not i have been waiting for like forever to go out with lorraine just calm down',
#  'calm down calm down you set me up with the woman that i have dumped twice in the last five months',
#  'can you stop yelling you are making me nervous and i can not go when i am nervous',
#  'i am sorry i am sorry you are right come on do it do it go come on',
#  'i am sorry i am sorry you are right come on do it do it go come on',
#  'wow how do you know how to do that',
#  'remember that guy that gave me a bad review well i am getting my revenge',
#  'you cooked him',
#  'oh i cannot wait to read the front page of the post tomorrow',
#  'restaurant reviewer admits i was wrong about monica',
#  'the front page you really do live in your own little world do not you',
#  'the front page you really do live in your own little world do not you',
#  'of course i am',
#  'of course i am',
#  'the baby coming and i do not know what to do',
#  'oh can i throw up in my diaper genie',
#  'no sweetie you are gonna be fine',
#  'wait wait where are you going where are you going',
#  'hey',
#  'hey why are you all red and sweaty',
#  'i just bamboozled chandler which is not uh sexual thing that was a quick shower',
#  'okay we have a lot of options here a number of prototypes for you to try on',
#  'wow this looks great',
#  'yeah okay this one is a mushroom cap umm this one is made of bologna',
#  'and and and and and the toothpicks',
#  'and and and and and the toothpicks',
#  'hey who this little naked guy',
#  'aww look at the little thing',
#  'aww look at the little thing',
#  'who are those people',
#  'got me',
#  'got me',
#  'wow monica you look just like your grandmother how old was she there',
#  'ooh look look look look look i got monica naked',
#  'okay i have got some ones you wanna put them in her panties',
#  'no thanks mom',
#  'very good so good',
#  'i really really enjoyed it very exotic',
#  'well i just checked our messages and joshua did not call',
#  'i mean you would think he would be worried about me not showing up at his club',
#  'ugh you know what makes it so much worse ross is all happy in vermont',
#  'ugh you know what makes it so much worse ross is all happy in vermont',
#  'no',
#  'no',
#  'that was a test',
#  'that was a test',
#  'in a couple of hours i am gonna get really drunk and wanna call kathy and you guys are gonna have to stop me',
#  'in a couple of hours i am gonna get really drunk and wanna call kathy and you guys are gonna have to stop me',
#  'and then after that i am gonna get so drunk i am gonna wanna call janice',
#  'and then after that i am gonna get so drunk i am gonna wanna call janice',
#  'you should how is she',
#  'ohhh',
#  'ohhh',
#  'i think somebody needs another lap dance',
#  'ohh i mean it is just so realistic',
#  'pat the dog oh oh i get it',
#  'oh i probably should not so i will oh wow it is like it is raining',
#  'oh i probably should not so i will oh wow it is like it is raining',
#  'pretty cool huh',
#  'pretty cool huh',
#  'okay god you know if someone told me a week ago that i would be peeing in joey tribbiani apartment',
#  'yeah life pretty great is not it',
#  'good job joe well done top notch',
#  'you liked it you really liked it',
#  'you liked it you really liked it',
#  'oh ho ho yeah',
#  'oh ho ho yeah',
#  'which part exactly',
#  'which part exactly',
#  'i love the specifics the specifics were the best part',
#  'hey what about the scene with the kangaroo did did you like that part',
#  'i was surprised to see a kangaroo in a world war i epic',
#  'i was surprised to see a kangaroo in a world war i epic',
#  'you fell asleep',
#  'there was no kangaroo',
#  'they did not take any of my suggestions',
#  'they did not take any of my suggestions',
#  'do not go i am sorry i am so sorry',
#  'look this guy fell asleep he fell asleep too be mad at him',
#  'hey pheebs it is joey',
#  'hey joey',
#  'hey joey',
#  'ooh',
#  'ooh',
#  'i just saw someone on the that looks just like you on the subway',
#  'and i was gonna go over and say hi but then i figured he does not care if he looks like you',
#  'ohh they are having a great time with their aunt phoebe',
#  'kinda but i have just been having way too much fun',
#  'so you are not homesick yet',
#  'so you are not homesick yet',
#  'man that was great huh can you believe how long we threw that ball around',
#  'you know how did i get this reputation as a dropper okay i am',
#  'what that that is all the way cross town i am supposed to teach a graduate seminar there in ten minutes',
#  'what that that is all the way cross town i am supposed to teach a graduate seminar there in ten minutes',
#  'what that that is all the way cross town i am supposed to teach a graduate seminar there in ten minutes',
#  'move it move it move it hey i am the teacher',
#  'this game makes no sense',
#  'this game makes no sense',
#  'you know what you are just upset because you are losing',
#  'you know what you are just upset because you are losing',
#  'oh come on ross i think we are all losers here',
#  'oh come on ross i think we are all losers here',
#  'let me think let me think oh i do not care',
#  'choose you jackass',
#  'okay you picked the gimmie card you get all of ross points',
#  'what',
#  'this game is kinda fun',
#  'this game is kinda fun',
#  'you do not think it is a little crazy that you get all my points just cause you',
#  'you do not think it is a little crazy that you get all my points just cause you',
#  'i did not get it',
#  'oh',
#  'what do you think i would just use my son as as an excuse',
#  'what kind of father do you think i am',
#  'i am guess i am just done with the whole dating thing',
#  'it is one more thing in my life that is suddenly completely different',
#  'this is hard',
#  'this is hard',
#  'you owe me two zero bucks',
#  'wait wait chandler this is what you are havin for thanksgiving dinner',
#  'wait wait chandler this is what you are havin for thanksgiving dinner',
#  'what what what is it with you and this holiday',
#  'oh i hate this story',
#  'i have and i remember this part vividly a mouthful of pumpkin pie and this is the moment my parents choose to tell me they are getting divorced',
#  'oh my god',
#  'yes it is very difficult to appreciate a thanksgiving dinner once you have seen it in reverse',
#  'yes it is very difficult to appreciate a thanksgiving dinner once you have seen it in reverse',
#  'no you did not you said you would but you never did',
#  'oh hey rach i thought we said seven',
#  'what why',
#  'oh great that special bond again',
#  'oh great that special bond again',
#  'so what if i am close to my family are you gonna let that stand in the way of us',
#  'i can not figure this out',
#  'it is so hard',
#  'should i get her a tiffany cut or a princess cut or a ah ah',
#  'paper cut',
#  'you told me',
#  'well it is because i trust you you are one of my best friends and you walked in on me when i was looking at ring brochures',
#  'yeah well once again not knocking pays off i only wish you had not been on the toilet',
#  'how rude',
#  'how rude',
#  'how rude',
#  'oh i am sorry you wanna bite',
#  'oh i am sorry you wanna bite',
#  'that is right still no baby come on people please make some room',
#  'you like you have not done enough',
#  'god i have never been so uncomfortable in my entire life',
#  'oh my gosh joshua',
#  'ok here we go i do not think we should go out anymore',
#  'janice',
#  'all right well there you go stop it stop it stop it',
#  'how could you pick up a hitchhiker he could be a rape a rapist or a killer or something',
#  'do not you think i asked him that before he got in',
#  'you know what i am not talking to you you go back to sleep and you are you a rapist',
#  'no',
#  'i love the license plate game',
#  'i love the license plate game',
#  'ooh i will play i will play',
#  'no no you need your sleep night night shh',
#  'did you see that',
#  'that mail guy had no idea there was something going on between us',
#  'you know i love doing crossword puzzles with you honey',
#  'aww me too now let finish this and go to bed',
#  'aww me too now let finish this and go to bed',
#  'yes you are so smart i love you',
#  'i love you too',
#  'i love you too',
#  'oh i feel so stupid',
#  'i think about the other day with you guys and i was all oh paolo he is so great he makes me feel so oh god',
#  'i am so embarrassed',
#  'i am so embarrassed',
#  'i am so embarrassed i am the one he hit on',
#  'pheebs if i had never met him this never would have happened',
#  'pheebs if i had never met him this never would have happened',
#  'i am so sorry no i am sorry no i am sorry no i am sorry',
#  'no wait oh what are we sorry about',
#  'no wait oh what are we sorry about',
#  'i do not know right he is the pig',
#  'such a pig',
#  'such a pig',
#  'oh god he is such a pig',
#  'oh god he is such a pig',
#  'oh god he is such a pig',
#  'oh he is like a',
#  'oh he is like a',
#  'oh he is like a',
#  'he is like a big disgusting pig pig man',
#  'he is like a big disgusting pig pig man',
#  'he is like a big disgusting pig pig man',
#  'he is like a big disgusting pig pig man',
#  'yes good ok',
#  'or or we could go to the bank close our accounts and cut them off at the source',
#  'you are a genius',
#  'you are a genius',
#  'aww man now we will not be bank buddies',
#  'hey',
#  'hey',
#  'where',
#  'and thats not against your oath',
#  'and thats not against your oath',
#  'and thats not against your oath',
#  'no i know',
#  'i i am sorry but the moment i touch him i just wanna throw out my old oath and take a new dirty one',
#  'yeah yeah yeah like like when i am doing something exciting and i do not wanna get too excited',
#  'hey you guys check it out check it out guess which job i got',
#  'what',
#  'but you you said black why would he want his blue blazer black',
#  'but you you said black why would he want his blue blazer black',
#  'no you messed it up you are stupid',
#  'oh ah tour guide at the museum yeah ross got it for me',
#  'oh ah tour guide at the museum yeah ross got it for me',
#  'well how can you be a tour guide do not you have to be a dinosaur expert or something',
#  'well how can you be a tour guide do not you have to be a dinosaur expert or something',
#  'well how can you be a tour guide do not you have to be a dinosaur expert or something',
#  'why have you been following me',
#  'why have you been following me',
#  'i mean all week long everywhere i look there is you',
#  'i mean all week long everywhere i look there is you',
#  'you would not return my calls you sent back my letters',
#  'what',
#  'what',
#  'one more chance ursula please',
#  'that is kinda sad',
#  'that is kinda sad',
#  'got it',
#  'i do',
#  'you still work at the multiplex',
#  'oh like i would give up that job free popcorn and candy anytime i want i can get you free posters for your room',
#  'monica betting the apartment i do not know about this',
#  'rachel i have not missed one question the whole game i own this game look at my hand',
#  'why do you have the answers written on there',
#  'all right let do it',
#  'fine i am mentally unstable',
#  'fine i am mentally unstable',
#  'what',
#  'crack is not even an intravenous drug',
#  'crack is not even an intravenous drug',
#  'oh come on',
#  'ross please i found the magazines',
#  'well that does not mean she can not look nice',
#  'well that does not mean she can not look nice',
#  'well there you go',
#  'well there you go',
#  'you wanna go in the bedroom it is a little more comfortable',
#  'sure',
#  'okay oh wait umm did you send those contracts to milan',
#  'okay oh wait umm did you send those contracts to milan',
#  'if this is your idea of sexy talk',
#  'if this is your idea of sexy talk',
#  'okay please tell me that this is just one of your jokes that you do that i do not get',
#  'you know like the thing when you put the phone in your pants',
#  'tag',
#  'tag',
#  'i am serious',
#  'i am serious',
#  'this is not funny',
#  'this is not funny',
#  'rach i am sorry but you did not give me any contracts',
#  'rach i am sorry but you did not give me any contracts',
#  'yes i did and i put a little post it on it that said must go out today and underlined today three times and and then i put a little heart in the corner because i didnt want to seem too bossy',
#  'yes i did and i put a little post it on it that said must go out today and underlined today three times and and then i put a little heart in the corner because i didnt want to seem too bossy',
#  'you know what tag if we went down to the office you would see those contracts sitting on your desk',
#  'you know what tag if we went down to the office you would see those contracts sitting on your desk',
#  'no i would see you looking embarrassed because they are not on my desk',
#  'no i would see you looking embarrassed because they are not on my desk',
#  'no i would see you looking embarrassed because they are not on my desk',
#  'or maybe you would see me looking embarrassed because you are talking on the phone with your crotch',
#  'or maybe you would see me looking embarrassed because you are talking on the phone with your crotch',
#  'okay get your coat oh when did you unhook this nice work',
#  'oh yeah now everybody wants to be under this hat',
#  'what with all this sand',
#  'hi',
#  'you do',
#  'what',
#  'i mean look that that one night we had was fun and and certainly passionate but do not you think it is better if we just stayed friends',
#  'seriously what',
#  'well you are amazing',
#  'well you are amazing',
#  'oh no no no this is amazing',
#  'a tv as if it appears from nowhere that is the dream man how did you afford this stuff',
#  'oh you are the best friend anyone has ever had',
#  'oh no no no you are',
#  'oh no no no you are',
#  'you do this you give me the great advice and hey listen i was thinking about what you said yesterday about focusing on one woman i am gonna do that',
#  'you mean with casey',
#  'you mean with casey',
#  'i think somebody got a little crush on casey',
#  'how bout i fix you two up',
#  'how bout i fix you two up',
#  'what do you think',
#  'that all the pieces of my life are falling right into place',
#  'that all the pieces of my life are falling right into place',
#  'i am so sorry please stop freaking out',
#  'i am not freaking out',
#  'i am not freaking out',
#  'a woman named heldi called and said we were getting married but that happens everyday',
#  'honey we were at this beautiful place and i i i just put our names down for fun',
#  'right here',
#  'right here',
#  'right here',
#  'chandler please do not think i was trying to pressure you phoebe and rachel',
#  'chandler please do not think i was trying to pressure you phoebe and rachel',
#  'chandler please do not think i was trying to pressure you phoebe and rachel',
#  'phoebe and rachel',
#  'so the people that knew about our wedding before me were you phoebe and rachel heldi and apparently some band called starlight magic seven who are available by the way',
#  'it was a mistake please do not take this to mean anything because it does not',
#  'really',
#  'really',
#  'i am gonna go tell joey that that you are back i was really worried about you',
#  'yeah it is beautiful',
#  'yeah it is beautiful',
#  'i can not believe you are gonna ask monica to marry you',
#  'i know',
#  'thank god',
#  'ooh remember the time i uh i pinned you down and tickled you til you cried',
#  'we are probably too old to do that now',
#  'i will always remember that summer because it is when i got all of these freckles',
#  'it took you that long to figure it out huh',
#  'it took you that long to figure it out huh',
#  'i believe i read that somewhere',
#  'that only is not funny it is physically impossible',
#  'okay',
#  'depending on the species i would have to have a six foot long',
#  'it is not funny',
#  'i can not believe you put that on my alumni page',
#  'who cares nobody reads those things',
#  'you would better hope not because i just read what you put on your page today',
#  'oh oh oh i respectfully disagree',
#  'you really think it would be that different',
#  'you really think it would be that different',
#  'how could it not be',
#  'i mean pretty soon they are gonna be having kids and then they are just gonna be hanging out with other couples who have kids',
#  'and then maybe they are gonna have to leave the city to be near a volvo dealership',
#  'well things change',
#  'well things change',
#  'well things change',
#  'i do not want them to move to a volvo dealership',
#  'i do not want them to move to a volvo dealership',
#  'hey',
#  'hi hey',
#  'hi hey',
#  'well of course i do my good friend joey over here',
#  'well of course i do my good friend joey over here',
#  'oh i am sorry thank you chandler',
#  'oh i am sorry thank you chandler',
#  'yeah it is weird but the thing is need to find a date',
#  'yeah it is weird but the thing is need to find a date',
#  'hey',
#  'hi pheebs',
#  'hi pheebs',
#  'oh pheebs pheebs',
#  'oh pheebs pheebs',
#  'oh pheebs pheebs',
#  'ok thanks pheebs oh my god why have i never tasted these before',
#  'ok thanks pheebs oh my god why have i never tasted these before',
#  'all right well you are right these are the best oatmeal cookies i have ever had',
#  'paolo made a pass at me',
#  'hey oh listen i was just clearing some space for your stuff',
#  'oh thanks but listen i was just at monica and she and chandler had a big fight and they are not moving in',
#  'what do you mean they are not moving in they they are still moving in right',
#  'what do you mean they are not moving in they they are still moving in right',
#  'what over a stupid room',
#  'yeah i feel kinda bad for them but i am also really psyched cause i do not have to move in here',
#  'oh no yeah no that part great',
#  'oh no yeah no that part great',
#  'rachel did not you just light that',
#  'oh sure every sunday night i am telling myself i am quitting but every monday morning it is like',
#  'tell me about it',
#  'well then let just quit we will just quit let all quit',
#  'well then let just quit we will just quit let all quit',
#  'well then let just quit we will just quit let all quit',
#  'oh i never could do it',
#  'absolutely',
#  'we can help each other out',
#  'we could be like the patch sisters',
#  'oh you know we really should quit okay let quit',
#  'yes great give me those cigs give it give it',
#  'yes great give me those cigs give it give it',
#  'my late husband gave me that lighter i am not kidding',
#  'okay then',
#  'estelle you gotta get me some work i i lost my health insurance',
#  'why',
#  'well i think uhh someone out there may have been bad mouthing you all over town',
#  'bastard',
#  'hey',
#  'oh yeah why not',
#  'oh yeah why not',
#  'okay you uh you wanna hear something weird',
#  'i did not get the annulment',
#  'what',
#  'we are still married do not tell rachel see you later',
#  'oh poor little tooty is scared to death we should find his owner',
#  'during a blackout he would get trampled',
#  'during a blackout he would get trampled',
#  'hey pheebs',
#  'hey',
#  'hey',
#  'check it out how much of a man am i',
#  'wow nice manly and also kind of a slut',
#  'oh no i can not go i am practicing i got an audition to be the host of a new game show',
#  'all the time',
#  'rach are you okay',
#  'oh yeah i am not i am not hungry',
#  'oh yeah i am not i am not hungry',
#  'i have been talking to you for five minutes now about killing myself and no one even looked up from their desk',
#  'i got nothing',
#  'you know what it really creeps me out choosing other peoples sex clothes',
#  'sorry',
#  'i am so exited',
#  'i have been waiting for this for months',
#  'i got my hair coloured',
#  'i got my hair coloured',
#  'i got new sheets',
#  'i am making him a very fancy meal',
#  'well you are making him a frieze salad with goat cheese and pine nuts wild nuts wild rice roast asparagus and salmon au croup',
#  'i thought i was making him filet mignon',
#  'and then you realised if you bitched about it then you would stop cooking and you would have to make your famous baked potato and diet coke',
#  'and then you realised if you bitched about it then you would stop cooking and you would have to make your famous baked potato and diet coke',
#  'and then you realised if you bitched about it then you would stop cooking and you would have to make your famous baked potato and diet coke',
#  'wow i really get crabby when i cook',
#  'wow i really get crabby when i cook',
#  'no i can not talk to you i do not have a fancy ad in the yellow pages',
#  'look pheebs i just i wanna apologize for for saying that your method was stupid and and maybe ask you to be my teacher again',
#  'look pheebs i just i wanna apologize for for saying that your method was stupid and and maybe ask you to be my teacher again',
#  'you really think i am ready',
#  'uh huh',
#  'uh huh',
#  'wow cool',
#  'wow cool',
#  'wow cool',
#  'no',
#  'no',
#  'besides somebody had to ride in that other taxi with the rest of your luggage and your friends do not really seem to care too much that you are leaving',
#  'well we are not really that close okay so i guess this is uh good bye then',
#  'on no no it is not good bye i am not leaving until you get on that plane',
#  'oh yeah',
#  'ok trying to turn me on by making a mess',
#  'we really need to take those tests',
#  'but i do not wanna do it in a cup',
#  'these little women wow',
#  'oh yeah amy just burned jo manuscript i do not see how he could ever forgive her',
#  'what do you mean this might be your only chance',
#  'would you stop i am only two six i am not even thinking about babies yet',
#  'so forcing her to marry bobby is gonna make that happen',
#  'joey i am scared to death about this',
#  'but i really think i can do it i am just gonna need some help',
#  'you bet i am and to answer your earlier question we are straight up gangster rap',
#  'look rachel told me how much easier you have made all this on her why can not you do that for me',
#  'and you are my big brother',
#  'joey i can not stand the thought of having this baby with you mad at me',
#  'i want him to have his uncle',
#  'is my baby gonna have his uncle joey',
#  'of course he is gonna have his uncle joey',
#  'we are gonna be all right i mean even if we are not married this baby is gonna be so loved not just by us',
#  'we are gonna be all right i mean even if we are not married this baby is gonna be so loved not just by us',
#  'we are gonna be all right i mean even if we are not married this baby is gonna be so loved not just by us',
#  'that is right by his uncle too',
#  'that is right by his uncle too',
#  'and by you',
#  'and by you',
#  'dr farber we have got a bit of an emergency here jason costalano is choking on his retainer',
#  'oh god i will be right there bernice',
#  'look please please do not go anywhere okay',
#  'did you see how he was sweating when he walked out of there',
#  'what are you talking about',
#  'what are you talking about',
#  'mindy the guy is the devil he is satan in a smock',
#  'but the truth is at the end of the day i still really wanna be mrs dr barry farber d d s',
#  'oh god',
#  'oh god',
#  'oh god',
#  'i hope you can find some way to be happy for me and i hope you will still be my maid of honor',
#  'and i hope barry does not kill you and eat you in aruba',
#  'and i hope barry does not kill you and eat you in aruba',
#  'and i hope barry does not kill you and eat you in aruba',
#  'monica leave him alone',
#  'monica leave him alone',
#  'monica leave him alone',
#  'will you hurry up',
#  'will you hurry up',
#  'did you not hear me before when i told you that all of janine friends are dancers',
#  'did you not hear me before when i told you that all of janine friends are dancers',
#  'and that they are going to be drinking a lot',
#  'and that they are going to be drinking a lot',
#  'well you are whippin so slow can not you do it any faster',
#  'well you are whippin so slow can not you do it any faster',
#  'joey',
#  'come on',
#  'i do not wanna make any mistakes alright',
#  'this is the only dessert and if i screw it up everybody gonna be like oh remember that thanksgiving when rachel screwed up the trifle',
#  'ross if you do not tell them then i will',
#  'okay fine',
#  'what did you just say',
#  'you roll another hard eight and we get married here tonight',
#  'are you serious',
#  'yes i love you i have never loved anybody as much as i love you',
#  'i have never loved anybody as much as i love you',
#  'i have never loved anybody as much as i love you',
#  'i have never loved anybody as much as i love you',
#  'okay so if an eight comes up we take it as a sign and we do it',
#  'okay so if an eight comes up we take it as a sign and we do it',
#  'okay',
#  'okay come on let go all right',
#  'okay come on let go all right',
#  'okay come on let go all right',
#  'okay that is a four and where where is the other one',
#  'nobody move okay you look that way i will look this way',
#  'nobody move okay you look that way i will look this way',
#  'here it is here it is',
#  'i think so too',
#  'i think so too',
#  'god i forgot how much i love driving i have got to get my license renewed',
#  'you do not have a valid drivers license okay that is it pull over right now',
#  'what what are you doing are you okay that is not funny just stop horsing around',
#  'i am not horsing around okay i am porsching around',
#  'alright alright alright it is been fourteen and a half minutes and you still have not said one word oh god do something just make contact smile',
#  'there you go',
#  'oh no problem i',
#  'ah ah i forgot my jacket',
#  'you are so cute how did you get to be so cute',
#  'well my grandfather was swedish and my grandmother was actually a tiny little bunny',
#  'okay now you are even cuter',
#  'what',
#  'the weirdest thing happened at the coffee house i think i think phoebe was hitting on me',
#  'what are you talking about',
#  'i am telling you i think phoebe thinks i am foxy',
#  'that is not possible',
#  'ow',
#  'ow',
#  'oh you know i i can not hear that enough',
#  'i am sorry i think that you just misunderstood her',
#  'i am sorry i think that you just misunderstood her',
#  'no i did not misunderstand okay she was all over me she touched my bicep for crying out loud',
#  'no i did not misunderstand okay she was all over me she touched my bicep for crying out loud',
#  'this bicep',
#  'this bicep',
#  'you ordered a stripper for the shower that is totally inappropriate',
#  'what he is gonna be dressed as a baby oh hi mrs green',
#  'hi',
#  'i am so glad you could make it',
#  'yes thank you so much and again we are so sorry we could not feel worse about it',
#  'try there is my little girl',
#  'she is still mad',
#  'yeah i know is not it great one less person we have to make small talk with',
#  'phoebe sandra mad at you too it it does not bother you',
#  'hey check it out this is unbelievable joey has been holding his breath for almost four minutes',
#  'dude what are yo you trying to kill me',
#  'all right',
#  'westminster abbey',
#  'really to what',
#  'to put the camera away',
#  'was it my work were they mad was it jack did he yell',
#  'thank god',
#  'this sounds like a hernia you have to you you go to the doctor',
#  'no way',
#  'kay look if i have to go to the doctor for anything it is gonna be for this thing sticking out of my stomach',
#  'why did i have to start working out again',
#  'damn you one five s',
#  'yes santa coming',
#  'will the stable boy never get the princess',
#  'what do you think you are gonna do have sex with her right here on my couch',
#  'no the leather sticks to my ass',
#  'you know this is not fair',
#  'you know this is not fair',
#  'what makes you think that i am just gonna sleep with her and then blow her off',
#  'huh',
#  'can not you guys open your minds to the possibility that i actally like her and might want something real',
#  'can not you guys open your minds to the possibility that i actally like her and might want something real',
#  'look the truth is i have not felt this way about anyone since rachel ok',
#  'i did not think i could ever love again',
#  'i did not think i could ever love again',
#  'come on joe',
#  'hey guys this is tabatha i will see you tomorrow',
#  'it is like my favorite fairy tale come true the princess the stable boy and the lesbian',
#  'i had a really nice time tonight',
#  'so did i i am really glad monica asked us out',
#  'so did i i am really glad monica asked us out',
#  'you are sister you are sister asleep on the couch ohhh i saw her with you on the subway and now she is asleep on the couch',
#  'you are sister you are sister asleep on the couch ohhh i saw her with you on the subway and now she is asleep on the couch',
#  'hi',
#  'nice to meet you i wish you would told me we were having company i would fix myself up',
#  'i know i lied i did not want her to think i was a terrible mother i can not even see my own baby',
#  'oh oh it is beautiful i see it now',
#  'no i do not see it',
#  'that is it well i saw that ohh ohh oh thank you',
#  'wow i can not believe that is our baby',
#  'hi listen i am sorry about before',
#  'really',
#  'yeah oh yes',
#  'listen we do not have to make that a guest room we can think of something to do with the room together',
#  'that is a great idea we can easily think of a way for us both to enjoy the room',
#  'that is a great idea we can easily think of a way for us both to enjoy the room',
#  'what are you doing',
#  'brenda a bee',
#  'what',
#  'yes it is flown into your blouse and you would better undo your buttons lest it sting you',
#  'i think i know what going on here',
#  'you do',
#  'look i know it must be hard that your wife is a lesbian but it is wrong you are married',
#  'oh but look that is gonna leave a stain',
#  'rach hey it is fine you are at joey',
#  'really',
#  'i have never lived like this before',
#  'i know',
#  'oh this life oh okay no chandler is worse',
#  'man it must be so cool remembering stuff like that i do not have any past life memories',
#  'oh let not tell this story',
#  'oh let not tell this story',
#  'oh come on',
#  'oh no i know i know it is the one where joey got monica turkey stuck on his head',
#  'what joey got a turkey stuck on his head',
#  'what joey got a turkey stuck on his head',
#  'exactly so you did not did not mention anything to issac right',
#  'you tell of course you do issac issac hey issac issac hi you know we have not actually met',
#  'you dog',
#  'oh hey man i know does not matter how much we love em monogamy is too cruel a rule',
#  'aw no problem dude you know we got to look out for each other we are the same you and me',
#  'yeah we are',
#  'yeah we are',
#  'no we are not',
#  'oh i do not know man i have not talked to her in like ten years',
#  'oh i do not know man i have not talked to her in like ten years',
#  'oh hey how was your audition',
#  'nothing i am just practicing blowing you off because i am gonna be a big movie star',
#  'oh you got it',
#  'oh you got it',
#  'well no not yet but the audition went really good',
#  'what was it for',
#  'it is really classy',
#  'oh and the director is supposed to be the next next martin scorcese',
#  'oh and the director is supposed to be the next next martin scorcese',
#  'the next next',
#  'hello',
#  'they loved me',
#  'they want me to be totally naked in the movie',
#  'wow',
#  'i know my grandmother gonna see this',
#  'i know my grandmother gonna see this',
#  'elizabeth thank god i was just thinking about',
#  'you suck',
#  'what',
#  'well i lost',
#  'some little girl loaned her uniform to her nineteen year old sister who went down to the u s s',
#  'nimitz and sold over two zero zero zero boxes',
#  'nimitz and sold over two zero zero zero boxes',
#  'hey how would the interview go',
#  'oh i blew it i would not of even hired me',
#  'oh come here sweetie listen you are gonna go on like a thousand interviews before you get a job',
#  'that is not how that was supposed to come out',
#  'this is the worst christmas ever',
#  'this is the worst christmas ever',
#  'this is the worst christmas ever',
#  'i can not',
#  'it is too late',
#  'terry already hired that girl over there',
#  'look at her she is even got waitress experience',
#  'look at her she is even got waitress experience',
#  'last night she was teaching everybody how to make napkin swans',
#  'last night she was teaching everybody how to make napkin swans',
#  'last night she was teaching everybody how to make napkin swans',
#  'he forgot to leave his grip size',
#  'he did not get the goggles',
#  'do they wait for me to do this',
#  'what are you guys doing here',
#  'uhhhh he is not even wearing a jockstrap',
#  'yes and that would be a shutdown',
#  'shut out',
#  'where are you guys going come on one more game',
#  'uh it is two three zero in the morning',
#  'uh it is two three zero in the morning',
#  'yeah get out',
#  'yeah get out',
#  'you guys are always hanging out in my apartment',
#  'you guys are always hanging out in my apartment',
#  'oh yeah',
#  'oh yeah',
#  'aw me too',
#  'your eyes are very pretty',
#  'thank you very much oh thank you',
#  'man can you believe he is only had sex with one woman',
#  'i think it is great you know it is sweet it is romantic',
#  'i think it is great you know it is sweet it is romantic',
#  'really',
#  'no you kidding the guy a freak i judge him',
#  'no you kidding the guy a freak i judge him',
#  'oh that is attractive',
#  'oh i thought you were great in silence of the lambs',
#  'oh come on admit it all things considered you had fun tonight',
#  'fun where was the fun tell me specifically which part was the fun part where is my puck',
#  'the kid',
#  'the kid',
#  'oh yeah well i am rubber you are glue whatever you can not do it',
#  'oh yeah well i am rubber you are glue whatever you can not do it',
#  'yes how about c mere gimme give me my puck',
#  'yes how about c mere gimme give me my puck',
#  'hey hey no rough holding in my er',
#  'give me my puck',
#  'give me my puck',
#  'now that was fun',
#  'what we did was wrong oh god i just had sex with somebody that was not alive during the bicentennial',
#  'i just had sex',
#  'ethan focus how could you not tell me',
#  'well you never told me how old you were',
#  'well that is different my lie did not make one of us a felon in four eight states',
#  'well that is different my lie did not make one of us a felon in four eight states',
#  'well that is different my lie did not make one of us a felon in four eight states',
#  'what were you thinking',
#  'what were you thinking',
#  'i was not thinking i was too busy falling',
#  'i was not thinking i was too busy falling',
#  'i was not thinking i was too busy falling',
#  'do not say it',
#  'do not say it',
#  'really',
#  'really',
#  'sorry',
#  'sorry',
#  'sorry',
#  'well fall out of it',
#  'well fall out of it',
#  'you know you should not even be here it is a school night',
#  'you know you should not even be here it is a school night',
#  'you know you should not even be here it is a school night',
#  'oh god oh god i am like those women that you see with shiny guys named chad',
#  'oh god oh god i am like those women that you see with shiny guys named chad',
#  'i am joan collins',
#  'i am joan collins',
#  'chandler i am scared',
#  'yeah but i do not wanna die',
#  'no no it will be fun we can come back and we can haunt these guys',
#  'check out the ring',
#  'nice one and a half carat easy',
#  'nice one and a half carat easy',
#  'hi',
#  'hey hey pheebs',
#  'chandler gonna ask monica to marry him',
#  'oh i know i helped pick out the ring',
#  'oh i know i helped pick out the ring',
#  'you told her before you told us',
#  'amazingly that makes sense',
#  'amazingly that makes sense',
#  'you think',
#  'you think',
#  'oh yeah go for it man jump off the high dive stare down the barrel of the gun pee into the wind',
#  'yeah joe i assure you if i am staring down the barrel of a gun i am pretty much peeing every which way',
#  'yeah joe i assure you if i am staring down the barrel of a gun i am pretty much peeing every which way',
#  'i do not know what i am going to do',
#  'i called the company that sent and th they do not care',
#  'i called the company that sent and th they do not care',
#  'then i called nine one one and they laughed at me if this is not an emergency then what is',
#  'then i called nine one one and they laughed at me if this is not an emergency then what is',
#  'hey guys',
#  'hey',
#  'hey',
#  'i just wanted to thank you again for last night what a great party',
#  'i just wanted to thank you again for last night what a great party',
#  'and the guys from work had a blast',
#  'and the guys from work had a blast',
#  'and and another one had never been to a party before so',
#  'and and another one had never been to a party before so',
#  'so uh hey that uh that wedding ring huh man that is nice',
#  'yeah right',
#  'that ring when my grandmother first came to this country that ring and the clothes on her back were all she had with her',
#  'so you might say the ring is irreplaceable',
#  'oh absolutely it has been in my family for generations and every bride who has worn it has had a long and happy life',
#  'so you might say it is a magic ring',
#  'so you might say it is a magic ring',
#  'you you you had sex with ursula',
#  'uh a little bit she she she walked in and i thought she was you and i kissed her and',
#  'uh a little bit she she she walked in and i thought she was you and i kissed her and',
#  'you did not notice she was wearing different clothes',
#  'you did not notice she was wearing different clothes',
#  'you did not notice she was wearing different clothes',
#  'well i was just so excited to see you',
#  'well i was just so excited to see you',
#  'oh ew ew ew ugh you know what this is too weird',
#  'oh ew ew ew ugh you know what this is too weird',
#  'oh ew ew ew ugh you know what this is too weird',
#  'no no it is not',
#  'i do not want to lose you',
#  'it is it is like i was saying to ursula when i was making love to her and i thought she was you yeah it is too weird',
#  'so i guess this is it',
#  'so i guess this is it',
#  'yeah maybe it is for the best you smell just like her',
#  'ross it just would not have been feasible',
#  'but having a dove place the ring on your finger would have been no problem',
#  'but having a dove place the ring on your finger would have been no problem',
#  'it was really fun being married to you tonight',
#  'yeah and and it was the easiest four zero zero bucks i have ever made',
#  'yeah and and it was the easiest four zero zero bucks i have ever made',
#  'i know i know it was stupid',
#  'are you kidding',
#  'with the with the lilies and and the song and the stars',
#  'it was really wonderful',
#  'it was really wonderful',
#  'did you just make that up',
#  'and your breasts hmm',
#  'umm look you are coming on a little strong',
#  'what',
#  'oh my god',
#  'wow you do',
#  'whazzup',
#  'seriously dude three years ago',
#  'you do not trust him',
#  'you do not trust him',
#  ...]

# %%
from transformers import pipeline

question_answerer = pipeline("question-answering", model="../models/span_nz", tokenizer="../models/span_nz", device=device)
predictions = question_answerer(question=raw_datasets['validation']['question'], context=raw_datasets['validation']['context'])
predictions
# Out:
# [{'score': 0.9999858140945435, 'start': 0, 'end': 3, 'answer': 'hey'},
#  {'score': 0.4520484209060669,
#   'start': 24,
#   'end': 41,
#   'answer': 'that is the stuff'},
#  {'score': 0.2852475047111511,
#   'start': 74,
#   'end': 116,
#   'answer': 'you have embarrassed me enough for one day'},
#  {'score': 0.6674448251724243,
#   'start': 74,
#   'end': 116,
#   'answer': 'you have embarrassed me enough for one day'},
#  {'score': 0.992686927318573,
#   'start': 3,
#   'end': 18,
#   'answer': 'i embarrass you'},
#  {'score': 0.26844319701194763,
#   'start': 18,
#   'end': 54,
#   'answer': 'you insist on wearing that in public'},
#  {'score': 0.0586727000772953,
#   'start': 15,
#   'end': 54,
#   'answer': 'if you insist on wearing that in public'},
#  {'score': 0.21603237092494965,
#   'start': 11,
#   'end': 80,
#   'answer': 'you are gonna make me choose between you and the hat i choose the hat'},
#  {'score': 0.08288056403398514,
#   'start': 11,
#   'end': 80,
#   'answer': 'you are gonna make me choose between you and the hat i choose the hat'},
#  {'score': 0.9912657737731934,
#   'start': 0,
#   'end': 24,
#   'answer': 'how about you are moving'},
#  {'score': 0.8073731660842896,
#   'start': 0,
#   'end': 19,
#   'answer': 'great monica moving'},
#  {'score': 0.5514470934867859,
#   'start': 6,
#   'end': 19,
#   'answer': 'monica moving'},
#  {'score': 0.6238378882408142,
#   'start': 15,
#   'end': 53,
#   'answer': 'how come all your stuff is in this box'},
#  {'score': 0.9999858140945435, 'start': 0, 'end': 3, 'answer': 'hey'},
#  {'score': 0.9999858140945435, 'start': 0, 'end': 3, 'answer': 'hey'},
#  {'score': 0.9999858140945435, 'start': 0, 'end': 3, 'answer': 'hey'},
#  {'score': 0.9654868841171265,
#   'start': 28,
#   'end': 51,
#   'answer': 'you are the next caller'},
#  {'score': 0.505342960357666,
#   'start': 0,
#   'end': 63,
#   'answer': 'you were the next caller five hours ago you must be going crazy'},
#  {'score': 0.5801287889480591,
#   'start': 8,
#   'end': 21,
#   'answer': 'what going on'},
#  {'score': 0.9969523549079895,
#   'start': 0,
#   'end': 16,
#   'answer': 'she broke my arm'},
#  {'score': 0.9980646967887878,
#   'start': 0,
#   'end': 19,
#   'answer': 'he touched my fanny'},
#  {'score': 0.8891299962997437,
#   'start': 3,
#   'end': 25,
#   'answer': 'she touched mine first'},
#  {'score': 0.999356210231781,
#   'start': 0,
#   'end': 19,
#   'answer': 'he touched my fanny'},
#  {'score': 0.8732637763023376,
#   'start': 3,
#   'end': 25,
#   'answer': 'she touched mine first'},
#  {'score': 0.9977410435676575,
#   'start': 4,
#   'end': 21,
#   'answer': 'this girl is good'},
#  {'score': 0.9979328513145447,
#   'start': 4,
#   'end': 21,
#   'answer': 'this girl is good'},
#  {'score': 0.996129035949707,
#   'start': 0,
#   'end': 23,
#   'answer': 'look at you all jealous'},
#  {'score': 0.9201229810714722,
#   'start': 13,
#   'end': 47,
#   'answer': 'everyone else is happy she is done'},
#  {'score': 0.609410285949707,
#   'start': 5,
#   'end': 53,
#   'answer': 'my next song called phoebe buffay what can i say'},
#  {'score': 0.14396297931671143,
#   'start': 49,
#   'end': 84,
#   'answer': 'i should not have left you that way'},
#  {'score': 0.6824996471405029,
#   'start': 3,
#   'end': 52,
#   'answer': 'no one of those look for the hidden meaning songs'},
#  {'score': 0.9985928535461426,
#   'start': 0,
#   'end': 55,
#   'answer': 'i invented the game of cups as a way to give joey money'},
#  {'score': 0.8447176218032837,
#   'start': 4,
#   'end': 32,
#   'answer': 'now you want that money back'},
#  {'score': 0.9982906579971313,
#   'start': 0,
#   'end': 55,
#   'answer': 'i invented the game of cups as a way to give joey money'},
#  {'score': 0.8787115216255188,
#   'start': 4,
#   'end': 32,
#   'answer': 'now you want that money back'},
#  {'score': 0.9999525547027588, 'start': 0, 'end': 7, 'answer': 'exactly'},
#  {'score': 0.8425849080085754,
#   'start': 9,
#   'end': 30,
#   'answer': 'what kind of an idiot'},
#  {'score': 0.5317486524581909,
#   'start': 9,
#   'end': 49,
#   'answer': 'what kind of an idiot do you take me for'},
#  {'score': 0.8046450614929199,
#   'start': 4,
#   'end': 32,
#   'answer': 'now you want that money back'},
#  {'score': 0.9999003410339355, 'start': 0, 'end': 7, 'answer': 'exactly'},
#  {'score': 0.8838137984275818,
#   'start': 11,
#   'end': 59,
#   'answer': 'you lost your money but i won it fair and square'},
#  {'score': 0.7162854075431824,
#   'start': 5,
#   'end': 44,
#   'answer': 'here is a picture of scotty jared naked'},
#  {'score': 0.9026353359222412,
#   'start': 5,
#   'end': 44,
#   'answer': 'here is a picture of scotty jared naked'},
#  {'score': 0.9406414031982422,
#   'start': 4,
#   'end': 27,
#   'answer': 'he is wearing a sweater'},
#  {'score': 0.987269401550293,
#   'start': 17,
#   'end': 56,
#   'answer': 'there is such a thing as too many women'},
#  {'score': 0.47937795519828796,
#   'start': 6,
#   'end': 28,
#   'answer': 'did did did i wake you'},
#  {'score': 0.9956243634223938,
#   'start': 5,
#   'end': 20,
#   'answer': 'this is so nice'},
#  {'score': 0.977211594581604,
#   'start': 3,
#   'end': 25,
#   'answer': 'look at the little cat'},
#  {'score': 0.9505449533462524,
#   'start': 3,
#   'end': 25,
#   'answer': 'look at the little cat'},
#  {'score': 0.9850780367851257,
#   'start': 3,
#   'end': 25,
#   'answer': 'look at the little cat'},
#  {'score': 0.7032250761985779,
#   'start': 14,
#   'end': 46,
#   'answer': 'did you see my new china cabinet'},
#  {'score': 0.9029947519302368,
#   'start': 4,
#   'end': 29,
#   'answer': 'my father house does that'},
#  {'score': 0.6886114478111267,
#   'start': 11,
#   'end': 43,
#   'answer': 'how did it go tell me everything'},
#  {'score': 0.9827051758766174, 'start': 10, 'end': 19, 'answer': 'let do it'},
#  {'score': 0.9058992862701416,
#   'start': 9,
#   'end': 22,
#   'answer': 'what was that'},
#  {'score': 0.17561465501785278,
#   'start': 48,
#   'end': 79,
#   'answer': 'i thought you were in your room'},
#  {'score': 0.912749707698822,
#   'start': 3,
#   'end': 53,
#   'answer': 'i am picking you up for our date these are for you'},
#  {'score': 0.5896049737930298,
#   'start': 16,
#   'end': 36,
#   'answer': 'they are my favorite'},
#  {'score': 0.9996575713157654,
#   'start': 0,
#   'end': 16,
#   'answer': 'this is so great'},
#  {'score': 0.9995554089546204,
#   'start': 0,
#   'end': 16,
#   'answer': 'this is so great'},
#  {'score': 0.9997806549072266,
#   'start': 0,
#   'end': 16,
#   'answer': 'this is so great'},
#  {'score': 0.8431127667427063,
#   'start': 0,
#   'end': 46,
#   'answer': 'i actually feel like i am going on a real date'},
#  {'score': 0.8927937746047974,
#   'start': 3,
#   'end': 45,
#   'answer': 'a subscription to playboy my kind of woman'},
#  {'score': 0.7764975428581238,
#   'start': 10,
#   'end': 51,
#   'answer': 'this roommate of yours is he good looking'},
#  {'score': 0.6297305822372437, 'start': 0, 'end': 6, 'answer': 'hm mmm'},
#  {'score': 0.9809486865997314,
#   'start': 9,
#   'end': 35,
#   'answer': 'i am pretty sure he is gay'},
#  {'score': 0.11166683584451675,
#   'start': 25,
#   'end': 60,
#   'answer': 'why are you trying to ruin the game'},
#  {'score': 0.9977243542671204,
#   'start': 0,
#   'end': 23,
#   'answer': 'what are you doing here'},
#  {'score': 0.9972794651985168,
#   'start': 0,
#   'end': 36,
#   'answer': 'i i came to fill your ice cube trays'},
#  {'score': 0.9935947060585022,
#   'start': 0,
#   'end': 26,
#   'answer': 'my father is chuck magioni'},
#  {'score': 0.9983283877372742,
#   'start': 0,
#   'end': 26,
#   'answer': 'my father is chuck magioni'},
#  {'score': 0.595003068447113,
#   'start': 33,
#   'end': 63,
#   'answer': 'i i sold him a house last year'},
#  {'score': 0.9422259330749512,
#   'start': 24,
#   'end': 80,
#   'answer': 'i do not know where your father is and that is the truth'},
#  {'score': 0.97972172498703,
#   'start': 24,
#   'end': 80,
#   'answer': 'i do not know where your father is and that is the truth'},
#  {'score': 0.9994087219238281,
#   'start': 0,
#   'end': 16,
#   'answer': 'i am your mother'},
#  {'score': 0.2842395603656769,
#   'start': 51,
#   'end': 78,
#   'answer': 'i kinda felt all floopy and'},
#  {'score': 0.9449751973152161,
#   'start': 42,
#   'end': 67,
#   'answer': 'i think i should date her'},
#  {'score': 0.9962400794029236,
#   'start': 10,
#   'end': 36,
#   'answer': 'this can go on for a while'},
#  {'score': 0.07938679307699203,
#   'start': 127,
#   'end': 149,
#   'answer': 'see who she likes best'},
#  {'score': 0.9984386563301086,
#   'start': 0,
#   'end': 16,
#   'answer': 'that sounds fair'},
#  {'score': 0.9604619145393372,
#   'start': 0,
#   'end': 67,
#   'answer': 'maybe i will take her to that new french restaurant down the street'},
#  {'score': 0.9778572916984558,
#   'start': 0,
#   'end': 67,
#   'answer': 'maybe i will take her to that new french restaurant down the street'},
#  {'score': 0.9832171201705933,
#   'start': 0,
#   'end': 67,
#   'answer': 'maybe i will take her to that new french restaurant down the street'},
#  {'score': 0.9883173108100891,
#   'start': 0,
#   'end': 62,
#   'answer': 'i do not have the money to take her to a fancy place like that'},
#  {'score': 0.4861709475517273,
#   'start': 17,
#   'end': 41,
#   'answer': 'you really feel about it'},
#  {'score': 0.8750641345977783,
#   'start': 10,
#   'end': 23,
#   'answer': 'i lied before'},
#  {'score': 0.9386577010154724,
#   'start': 0,
#   'end': 41,
#   'answer': 'now you know how you really feel about it'},
#  {'score': 0.9961305260658264,
#   'start': 6,
#   'end': 33,
#   'answer': 'that is a risky little game'},
#  {'score': 0.9490002393722534,
#   'start': 0,
#   'end': 28,
#   'answer': 'are you really gonna do this'},
#  {'score': 0.026676015928387642,
#   'start': 28,
#   'end': 73,
#   'answer': 'i am gonna have a baby i am gonna have a baby'},
#  {'score': 0.7742882370948792,
#   'start': 51,
#   'end': 73,
#   'answer': 'i am gonna have a baby'},
#  {'score': 0.998832106590271,
#   'start': 3,
#   'end': 27,
#   'answer': 'it is still not the time'},
#  {'score': 0.9440842866897583,
#   'start': 0,
#   'end': 19,
#   'answer': 'chandler gone again'},
#  {'score': 0.9986544847488403,
#   'start': 0,
#   'end': 19,
#   'answer': 'chandler gone again'},
#  {'score': 0.9115198850631714,
#   'start': 10,
#   'end': 81,
#   'answer': 'why would you play hide and seek with someone you know is a flight risk'},
#  {'score': 0.009582934901118279,
#   'start': 28,
#   'end': 100,
#   'answer': 'it is time we we had a conversation about about where things are with us'},
#  {'score': 0.9325746297836304,
#   'start': 5,
#   'end': 31,
#   'answer': 'i i think i suggested that'},
#  {'score': 0.3228290379047394,
#   'start': 47,
#   'end': 89,
#   'answer': 'i i love umm you know hanging out with you'},
#  {'score': 0.22666287422180176,
#   'start': 47,
#   'end': 89,
#   'answer': 'i i love umm you know hanging out with you'},
#  {'score': 0.6226186752319336,
#   'start': 25,
#   'end': 50,
#   'answer': 'it is going somewhere fun'},
#  {'score': 0.015751643106341362,
#   'start': 71,
#   'end': 103,
#   'answer': 'the doctor let me feel it myself'},
#  {'score': 0.687019407749176,
#   'start': 39,
#   'end': 66,
#   'answer': 'it is getting real late now'},
#  {'score': 0.7769362926483154,
#   'start': 0,
#   'end': 27,
#   'answer': 'did you know this is not ma'},
#  {'score': 0.5753637552261353,
#   'start': 13,
#   'end': 24,
#   'answer': 'this is not'},
#  {'score': 0.858424723148346,
#   'start': 8,
#   'end': 25,
#   'answer': 'how long you been'},
#  {'score': 0.03177718073129654, 'start': 93, 'end': 98, 'answer': 'ships'},
#  {'score': 0.9851490259170532, 'start': 0, 'end': 10, 'answer': 'since then'},
#  {'score': 0.9995899200439453,
#   'start': 0,
#   'end': 19,
#   'answer': 'you are one to talk'},
#  {'score': 0.0009841385763138533,
#   'start': 0,
#   'end': 20,
#   'answer': 'joe your dad in love'},
#  {'score': 0.005048885475844145,
#   'start': 58,
#   'end': 88,
#   'answer': 'it is with two different women'},
#  {'score': 0.6610205173492432,
#   'start': 7,
#   'end': 39,
#   'answer': 'please tell me one of them is ma'},
#  {'score': 0.9510226249694824, 'start': 0, 'end': 10, 'answer': 'looks good'},
#  {'score': 0.9766190648078918,
#   'start': 10,
#   'end': 55,
#   'answer': 'you guys are selling the entertainment center'},
#  {'score': 0.7783951163291931,
#   'start': 10,
#   'end': 55,
#   'answer': 'you guys are selling the entertainment center'},
#  {'score': 0.9989898204803467, 'start': 0, 'end': 11, 'answer': 'you want it'},
#  {'score': 0.9390152096748352, 'start': 0, 'end': 5, 'answer': 'oh no'},
#  {'score': 0.6271969079971313,
#   'start': 11,
#   'end': 53,
#   'answer': 'five zero zero zero dollars are you insane'},
#  {'score': 0.9950994253158569,
#   'start': 4,
#   'end': 43,
#   'answer': 'the ad alone cost three zero zero bucks'},
#  {'score': 0.9988420605659485,
#   'start': 15,
#   'end': 69,
#   'answer': 'i am changing it to five zero bucks or your best offer'},
#  {'score': 0.7492595314979553,
#   'start': 0,
#   'end': 63,
#   'answer': 'what kind of profit is that and you call yourself an accountant'},
#  {'score': 0.9162425398826599,
#   'start': 0,
#   'end': 63,
#   'answer': 'what kind of profit is that and you call yourself an accountant'},
#  {'score': 0.9720979332923889, 'start': 0, 'end': 4, 'answer': 'nooo'},
#  {'score': 0.7778364419937134,
#   'start': 0,
#   'end': 63,
#   'answer': 'what kind of profit is that and you call yourself an accountant'},
#  {'score': 0.9689423441886902, 'start': 0, 'end': 4, 'answer': 'nooo'},
#  {'score': 0.015773776918649673,
#   'start': 68,
#   'end': 141,
#   'answer': 'we were so angry at each other was because there are still feelings there'},
#  {'score': 0.9992125034332275,
#   'start': 0,
#   'end': 32,
#   'answer': 'we are gonna give it another try'},
#  {'score': 0.9072110056877136,
#   'start': 0,
#   'end': 58,
#   'answer': 'what about her whining and her constant need for attention'},
#  {'score': 0.9916911125183105,
#   'start': 17,
#   'end': 45,
#   'answer': 'you are so capable of change'},
#  {'score': 0.9993672966957092,
#   'start': 0,
#   'end': 32,
#   'answer': 'we are gonna give it another try'},
#  {'score': 0.9946457743644714,
#   'start': 9,
#   'end': 29,
#   'answer': 'he hums when he pees'},
#  {'score': 0.9939632415771484,
#   'start': 9,
#   'end': 29,
#   'answer': 'he hums when he pees'},
#  {'score': 0.9741361141204834,
#   'start': 0,
#   'end': 39,
#   'answer': 'it makes him miss the bowl but whatever'},
#  {'score': 0.9995055198669434,
#   'start': 0,
#   'end': 32,
#   'answer': 'we are gonna give it another try'},
#  {'score': 0.9992591142654419,
#   'start': 0,
#   'end': 32,
#   'answer': 'we are gonna give it another try'},
#  {'score': 0.43675559759140015,
#   'start': 13,
#   'end': 40,
#   'answer': 'even if they break up again'},
#  {'score': 0.4855118989944458,
#   'start': 0,
#   'end': 20,
#   'answer': 'you are so efficient'},
#  {'score': 0.9970107078552246, 'start': 0, 'end': 6, 'answer': 'let go'},
#  {'score': 0.9852232933044434,
#   'start': 9,
#   'end': 30,
#   'answer': 'we need something old'},
#  {'score': 0.9759895205497742,
#   'start': 9,
#   'end': 30,
#   'answer': 'we need something old'},
#  {'score': 0.9544365406036377,
#   'start': 10,
#   'end': 66,
#   'answer': 'i have condom in my wallet i have had since i was twelve'},
#  {'score': 0.9994442462921143,
#   'start': 0,
#   'end': 14,
#   'answer': 'that will work'},
#  {'score': 0.9325703978538513,
#   'start': 9,
#   'end': 40,
#   'answer': 'we just need something borrowed'},
#  {'score': 0.6459370255470276,
#   'start': 9,
#   'end': 40,
#   'answer': 'we just need something borrowed'},
#  {'score': 0.7048265933990479,
#   'start': 0,
#   'end': 19,
#   'answer': 'here just take this'},
#  {'score': 0.9994797706604004,
#   'start': 0,
#   'end': 16,
#   'answer': 'that is stealing'},
#  {'score': 0.9992634057998657,
#   'start': 0,
#   'end': 15,
#   'answer': 'it is brilliant'},
#  {'score': 0.5041084289550781,
#   'start': 0,
#   'end': 49,
#   'answer': 'goodbye mike we will see you at the wedding fella'},
#  {'score': 0.49847909808158875,
#   'start': 5,
#   'end': 38,
#   'answer': 'you are welcome glad i could help'},
#  {'score': 0.2231607288122177,
#   'start': 21,
#   'end': 71,
#   'answer': 'i especially would not want you to think i was gay'},
#  {'score': 0.8176517486572266,
#   'start': 40,
#   'end': 117,
#   'answer': 'i should have considered your feelings before i went home with you that night'},
#  {'score': 0.6268890500068665,
#   'start': 40,
#   'end': 117,
#   'answer': 'i should have considered your feelings before i went home with you that night'},
#  {'score': 0.9211546778678894,
#   'start': 10,
#   'end': 71,
#   'answer': 'i have recently learned what it like to be on your side of it'},
#  {'score': 0.3166876435279846,
#   'start': 40,
#   'end': 117,
#   'answer': 'i should have considered your feelings before i went home with you that night'},
#  {'score': 0.826771080493927,
#   'start': 10,
#   'end': 71,
#   'answer': 'i have recently learned what it like to be on your side of it'},
#  {'score': 0.4065908193588257,
#   'start': 6,
#   'end': 33,
#   'answer': 'mrs loreo is jennifer there'},
#  {'score': 0.9839565753936768,
#   'start': 3,
#   'end': 18,
#   'answer': 'she is not home'},
#  {'score': 0.0008055644575506449,
#   'start': 38,
#   'end': 73,
#   'answer': 'all hers is is is growing new stuff'},
#  {'score': 0.0006824411684647202, 'start': 5, 'end': 8, 'answer': 'all'},
#  {'score': 0.00380311137996614,
#   'start': 59,
#   'end': 98,
#   'answer': 'you guys love me more than you love her'},
#  {'score': 0.010880238376557827,
#   'start': 49,
#   'end': 98,
#   'answer': 'her think you guys love me more than you love her'},
#  {'score': 0.738069474697113,
#   'start': 10,
#   'end': 37,
#   'answer': 'does she really thinks that'},
#  {'score': 0.0022569673601537943,
#   'start': 38,
#   'end': 73,
#   'answer': 'all hers is is is growing new stuff'},
#  {'score': 0.002005939371883869,
#   'start': 59,
#   'end': 98,
#   'answer': 'you guys love me more than you love her'},
#  {'score': 0.41103851795196533,
#   'start': 95,
#   'end': 128,
#   'answer': 'the doctor said your mother could'},
#  {'score': 0.9880584478378296,
#   'start': 8,
#   'end': 38,
#   'answer': 'i do not want to hear about it'},
#  {'score': 0.9678144454956055,
#   'start': 8,
#   'end': 38,
#   'answer': 'i do not want to hear about it'},
#  {'score': 0.000841206347104162,
#   'start': 38,
#   'end': 73,
#   'answer': 'all hers is is is growing new stuff'},
#  {'score': 0.11496991664171219,
#   'start': 95,
#   'end': 122,
#   'answer': 'i am trying to win her over'},
#  {'score': 0.9999858140945435, 'start': 0, 'end': 3, 'answer': 'hey'},
#  {'score': 0.9980393648147583,
#   'start': 0,
#   'end': 37,
#   'answer': 'manhattan does not have enough stores'},
#  {'score': 0.8925922513008118,
#   'start': 5,
#   'end': 40,
#   'answer': 'i think i can help you get over him'},
#  {'score': 0.9993430376052856, 'start': 0, 'end': 11, 'answer': 'we are here'},
#  {'score': 0.9973714351654053,
#   'start': 0,
#   'end': 19,
#   'answer': 'where have you been'},
#  {'score': 0.7540009617805481,
#   'start': 22,
#   'end': 46,
#   'answer': 'it is ross and that girl'},
#  {'score': 0.8769075274467468,
#   'start': 19,
#   'end': 66,
#   'answer': 'it is a line of ants they are working as a team'},
#  {'score': 0.9637071490287781,
#   'start': 7,
#   'end': 49,
#   'answer': 'it looks like ross is breaking up with her'},
#  {'score': 0.9522201418876648,
#   'start': 7,
#   'end': 49,
#   'answer': 'it looks like ross is breaking up with her'},
#  {'score': 0.7023873329162598,
#   'start': 8,
#   'end': 27,
#   'answer': 'phoebe look at that'},
#  {'score': 0.6951923966407776,
#   'start': 0,
#   'end': 31,
#   'answer': 'that is a that is a second date'},
#  {'score': 0.9265672564506531,
#   'start': 13,
#   'end': 47,
#   'answer': 'she just put her hand on his thigh'},
#  {'score': 0.35185372829437256,
#   'start': 11,
#   'end': 72,
#   'answer': 'this is all your fault now he loves her he is gonna marry her'},
#  {'score': 0.5555502772331238,
#   'start': 19,
#   'end': 54,
#   'answer': 'thank the jerk that never showed up'},
#  {'score': 0.7260302901268005,
#   'start': 0,
#   'end': 22,
#   'answer': 'whew stood up too fast'},
#  {'score': 0.9919886589050293,
#   'start': 0,
#   'end': 38,
#   'answer': 'do you wanna come in for some lemonade'},
#  {'score': 0.9732858538627625,
#   'start': 31,
#   'end': 52,
#   'answer': 'this is a great place'},
#  {'score': 0.7768325805664062,
#   'start': 7,
#   'end': 22,
#   'answer': 'what time is it'},
#  {'score': 0.9859281778335571,
#   'start': 0,
#   'end': 44,
#   'answer': 'i am really getting tired of sneaking around'},
#  {'score': 0.9964638352394104,
#   'start': 14,
#   'end': 49,
#   'answer': 'if we went away for a whole weekend'},
#  {'score': 0.8633803129196167,
#   'start': 9,
#   'end': 77,
#   'answer': 'we would have no interruptions and we could be naked the entire time'},
#  {'score': 0.9969300031661987,
#   'start': 14,
#   'end': 49,
#   'answer': 'if we went away for a whole weekend'},
#  {'score': 0.44774141907691956,
#   'start': 44,
#   'end': 77,
#   'answer': 'we could be naked the entire time'},
#  {'score': 0.10303189605474472,
#   'start': 56,
#   'end': 77,
#   'answer': 'you have a chef thing'},
#  {'score': 0.9183337092399597,
#   'start': 4,
#   'end': 77,
#   'answer': 'i have always wanted to go to this culinary fair that they have in jersey'},
#  {'score': 0.027943192049860954,
#   'start': 39,
#   'end': 97,
#   'answer': 'the woman that i have dumped twice in the last five months'},
#  {'score': 0.9112816452980042,
#   'start': 3,
#   'end': 55,
#   'answer': 'i am making a break for it i am going out the window'},
#  {'score': 0.003108186414465308,
#   'start': 39,
#   'end': 97,
#   'answer': 'the woman that i have dumped twice in the last five months'},
#  {'score': 0.19296368956565857,
#   'start': 21,
#   'end': 46,
#   'answer': 'you are making me nervous'},
#  {'score': 0.00630700821056962,
#   'start': 39,
#   'end': 97,
#   'answer': 'the woman that i have dumped twice in the last five months'},
#  {'score': 0.7724062204360962,
#   'start': 21,
#   'end': 81,
#   'answer': 'you are making me nervous and i can not go when i am nervous'},
#  {'score': 0.9234362244606018,
#   'start': 4,
#   'end': 34,
#   'answer': 'how do you know how to do that'},
#  {'score': 0.39286085963249207,
#   'start': 49,
#   'end': 72,
#   'answer': 'i am getting my revenge'},
#  {'score': 0.9993477463722229,
#   'start': 0,
#   'end': 14,
#   'answer': 'you cooked him'},
#  {'score': 0.926689088344574,
#   'start': 0,
#   'end': 51,
#   'answer': 'restaurant reviewer admits i was wrong about monica'},
#  {'score': 0.928022563457489,
#   'start': 0,
#   'end': 51,
#   'answer': 'restaurant reviewer admits i was wrong about monica'},
#  {'score': 0.9878517985343933,
#   'start': 3,
#   'end': 60,
#   'answer': 'i cannot wait to read the front page of the post tomorrow'},
#  {'score': 0.8768090605735779,
#   'start': 0,
#   'end': 51,
#   'answer': 'restaurant reviewer admits i was wrong about monica'},
#  {'score': 0.972358226776123,
#   'start': 7,
#   'end': 55,
#   'answer': 'you are gonna stay with me as long as i need you'},
#  {'score': 0.9766654968261719,
#   'start': 0,
#   'end': 14,
#   'answer': 'of course i am'},
#  {'score': 0.9413837790489197,
#   'start': 0,
#   'end': 44,
#   'answer': 'the baby coming and i do not know what to do'},
#  {'score': 0.9828953742980957,
#   'start': 0,
#   'end': 44,
#   'answer': 'the baby coming and i do not know what to do'},
#  {'score': 0.9465926885604858,
#   'start': 11,
#   'end': 32,
#   'answer': 'you are gonna be fine'},
#  {'score': 0.46610257029533386,
#   'start': 10,
#   'end': 49,
#   'answer': 'where are you going where are you going'},
#  {'score': 0.9999858140945435, 'start': 0, 'end': 3, 'answer': 'hey'},
#  {'score': 0.9814134836196899,
#   'start': 4,
#   'end': 34,
#   'answer': 'why are you all red and sweaty'},
#  {'score': 0.12304303795099258,
#   'start': 0,
#   'end': 26,
#   'answer': 'i just bamboozled chandler'},
#  {'score': 0.08509732782840729,
#   'start': 35,
#   'end': 75,
#   'answer': 'a number of prototypes for you to try on'},
#  {'score': 0.996658444404602,
#   'start': 4,
#   'end': 20,
#   'answer': 'this looks great'},
#  {'score': 0.9970472455024719,
#   'start': 4,
#   'end': 20,
#   'answer': 'this looks great'},
#  {'score': 0.9941979050636292,
#   'start': 41,
#   'end': 68,
#   'answer': 'this one is made of bologna'},
#  {'score': 0.5858736038208008,
#   'start': 0,
#   'end': 34,
#   'answer': 'and and and and and the toothpicks'},
#  {'score': 0.5982096195220947,
#   'start': 4,
#   'end': 29,
#   'answer': 'who this little naked guy'},
#  {'score': 0.9989209175109863,
#   'start': 0,
#   'end': 33,
#   'answer': 'that little naked guy would be me'},
#  {'score': 0.9869827628135681,
#   'start': 4,
#   'end': 28,
#   'answer': 'look at the little thing'},
#  {'score': 0.9994766712188721,
#   'start': 0,
#   'end': 20,
#   'answer': 'who are those people'},
#  {'score': 0.9993355870246887,
#   'start': 0,
#   'end': 20,
#   'answer': 'who are those people'},
#  {'score': 0.9979128241539001, 'start': 0, 'end': 6, 'answer': 'got me'},
#  {'score': 0.9828010201454163,
#   'start': 11,
#   'end': 68,
#   'answer': 'you look just like your grandmother how old was she there'},
#  {'score': 0.34891873598098755,
#   'start': 4,
#   'end': 47,
#   'answer': 'look look look look look i got monica naked'},
#  {'score': 0.8178375959396362,
#   'start': 5,
#   'end': 59,
#   'answer': 'i have got some ones you wanna put them in her panties'},
#  {'score': 0.8721721172332764,
#   'start': 5,
#   'end': 59,
#   'answer': 'i have got some ones you wanna put them in her panties'},
#  {'score': 0.8495317697525024,
#   'start': 0,
#   'end': 17,
#   'answer': 'very good so good'},
#  {'score': 0.9921917915344238,
#   'start': 0,
#   'end': 38,
#   'answer': 'i really really enjoyed it very exotic'},
#  {'score': 0.698243260383606,
#   'start': 5,
#   'end': 56,
#   'answer': 'i just checked our messages and joshua did not call'},
#  {'score': 0.8733564615249634,
#   'start': 5,
#   'end': 56,
#   'answer': 'i just checked our messages and joshua did not call'},
#  {'score': 0.9262775182723999,
#   'start': 5,
#   'end': 56,
#   'answer': 'i just checked our messages and joshua did not call'},
#  {'score': 0.48636099696159363,
#   'start': 13,
#   'end': 69,
#   'answer': 'what makes it so much worse ross is all happy in vermont'},
#  {'score': 0.8490742444992065,
#   'start': 40,
#   'end': 86,
#   'answer': 'i think i am just gonna go home and call kathy'},
#  {'score': 0.9214872121810913,
#   'start': 5,
#   'end': 30,
#   'answer': 'if you think it will help'},
#  {'score': 0.9330586791038513,
#   'start': 40,
#   'end': 86,
#   'answer': 'i think i am just gonna go home and call kathy'},
#  {'score': 0.8438338041305542,
#   'start': 5,
#   'end': 30,
#   'answer': 'if you think it will help'},
#  {'score': 0.15248601138591766,
#   'start': 0,
#   'end': 20,
#   'answer': 'in a couple of hours'},
#  {'score': 0.473733514547348,
#   'start': 9,
#   'end': 43,
#   'answer': 'after that i am gonna get so drunk'},
#  {'score': 0.25861045718193054,
#   'start': 64,
#   'end': 108,
#   'answer': 'kathy and you guys are gonna have to stop me'},
#  {'score': 0.28108707070350647,
#   'start': 9,
#   'end': 43,
#   'answer': 'after that i am gonna get so drunk'},
#  {'score': 0.4753877818584442,
#   'start': 9,
#   'end': 72,
#   'answer': 'after that i am gonna get so drunk i am gonna wanna call janice'},
#  {'score': 0.28033730387687683,
#   'start': 44,
#   'end': 72,
#   'answer': 'i am gonna wanna call janice'},
#  {'score': 0.858978271484375,
#   'start': 0,
#   'end': 21,
#   'answer': 'you should how is she'},
#  {'score': 0.982986330986023,
#   'start': 0,
#   'end': 40,
#   'answer': 'i think somebody needs another lap dance'},
#  {'score': 0.9920007586479187,
#   'start': 11,
#   'end': 34,
#   'answer': 'it is just so realistic'},
#  {'score': 0.688555896282196, 'start': 0, 'end': 11, 'answer': 'pat the dog'},
#  {'score': 0.9453099966049194,
#   'start': 10,
#   'end': 35,
#   'answer': 'do you ready for a refill'},
#  {'score': 0.6650102138519287,
#   'start': 42,
#   'end': 66,
#   'answer': 'it is like it is raining'},
#  {'score': 0.9831292033195496,
#   'start': 42,
#   'end': 66,
#   'answer': 'it is like it is raining'},
#  {'score': 0.709288477897644, 'start': 0, 'end': 11, 'answer': 'pretty cool'},
#  {'score': 0.0019051817944273353,
#   'start': 53,
#   'end': 98,
#   'answer': 'i would be peeing in joey tribbiani apartment'},
#  {'score': 0.0015861017163842916,
#   'start': 89,
#   'end': 98,
#   'answer': 'apartment'},
#  {'score': 0.8690811991691589,
#   'start': 0,
#   'end': 32,
#   'answer': 'good job joe well done top notch'},
#  {'score': 0.7467687726020813,
#   'start': 0,
#   'end': 32,
#   'answer': 'good job joe well done top notch'},
#  {'score': 0.9209629893302917,
#   'start': 0,
#   'end': 32,
#   'answer': 'you liked it you really liked it'},
#  {'score': 0.9870251417160034,
#   'start': 0,
#   'end': 32,
#   'answer': 'you liked it you really liked it'},
#  {'score': 0.9490175843238831,
#   'start': 0,
#   'end': 13,
#   'answer': 'oh ho ho yeah'},
#  {'score': 0.9775063395500183,
#   'start': 0,
#   'end': 32,
#   'answer': 'you liked it you really liked it'},
#  {'score': 0.7623360753059387,
#   'start': 0,
#   'end': 13,
#   'answer': 'oh ho ho yeah'},
#  {'score': 0.9511560797691345,
#   'start': 0,
#   'end': 53,
#   'answer': 'i love the specifics the specifics were the best part'},
#  {'score': 0.42421600222587585,
#   'start': 47,
#   'end': 69,
#   'answer': 'did you like that part'},
#  {'score': 0.6946731209754944,
#   'start': 47,
#   'end': 69,
#   'answer': 'did you like that part'},
#  {'score': 0.9505534172058105,
#   'start': 0,
#   'end': 55,
#   'answer': 'i was surprised to see a kangaroo in a world war i epic'},
#  {'score': 0.9992620944976807,
#   'start': 0,
#   'end': 15,
#   'answer': 'you fell asleep'},
#  {'score': 0.9993853569030762,
#   'start': 0,
#   'end': 15,
#   'answer': 'you fell asleep'},
#  {'score': 0.999009370803833,
#   'start': 0,
#   'end': 15,
#   'answer': 'you fell asleep'},
#  {'score': 0.9808923006057739,
#   'start': 0,
#   'end': 39,
#   'answer': 'they did not take any of my suggestions'},
#  {'score': 0.9996135234832764,
#   'start': 0,
#   'end': 15,
#   'answer': 'you fell asleep'},
#  {'score': 0.8465157151222229,
#   'start': 5,
#   'end': 58,
#   'answer': 'this guy fell asleep he fell asleep too be mad at him'},
#  {'score': 0.6117243766784668, 'start': 11, 'end': 21, 'answer': 'it is joey'},
#  {'score': 0.7864341139793396,
#   'start': 0,
#   'end': 21,
#   'answer': 'hey pheebs it is joey'},
#  {'score': 0.9967314004898071, 'start': 0, 'end': 8, 'answer': 'hey joey'},
#  {'score': 0.9982249140739441,
#   'start': 0,
#   'end': 64,
#   'answer': 'i just saw someone on the that looks just like you on the subway'},
#  {'score': 0.9982249140739441,
#   'start': 0,
#   'end': 64,
#   'answer': 'i just saw someone on the that looks just like you on the subway'},
#  {'score': 0.9877943396568298,
#   'start': 0,
#   'end': 64,
#   'answer': 'i just saw someone on the that looks just like you on the subway'},
#  {'score': 0.9983147382736206,
#   'start': 0,
#   'end': 64,
#   'answer': 'i just saw someone on the that looks just like you on the subway'},
#  {'score': 0.9977806806564331,
#   'start': 4,
#   'end': 55,
#   'answer': 'they are having a great time with their aunt phoebe'},
#  {'score': 0.9874566197395325,
#   'start': 10,
#   'end': 50,
#   'answer': 'i have just been having way too much fun'},
#  {'score': 0.964005708694458,
#   'start': 10,
#   'end': 50,
#   'answer': 'i have just been having way too much fun'},
#  {'score': 0.5089719891548157,
#   'start': 0,
#   'end': 27,
#   'answer': 'so you are not homesick yet'},
#  {'score': 0.5947377681732178,
#   'start': 39,
#   'end': 73,
#   'answer': 'how long we threw that ball around'},
#  {'score': 0.370956689119339,
#   'start': 13,
#   'end': 51,
#   'answer': 'did i get this reputation as a dropper'},
#  {'score': 0.9924066662788391,
#   'start': 6,
#   'end': 52,
#   'answer': 'does anyone know where the freeman building is'},
#  {'score': 0.8370329141616821,
#   'start': 5,
#   'end': 39,
#   'answer': 'it is the new building on avenue a'},
#  {'score': 0.3385513126850128,
#   'start': 41,
#   'end': 103,
#   'answer': 'i am supposed to teach a graduate seminar there in ten minutes'},
#  {'score': 0.4452839195728302,
#   'start': 0,
#   'end': 44,
#   'answer': 'move it move it move it hey i am the teacher'},
#  {'score': 0.5576109886169434,
#   'start': 26,
#   'end': 76,
#   'answer': 'i am entitled to use my angel pass for a free turn'},
#  {'score': 0.9971737265586853,
#   'start': 0,
#   'end': 24,
#   'answer': 'this game makes no sense'},
#  {'score': 0.9957452416419983,
#   'start': 0,
#   'end': 24,
#   'answer': 'this game makes no sense'},
#  {'score': 0.9675365090370178,
#   'start': 14,
#   'end': 55,
#   'answer': 'you are just upset because you are losing'},
#  {'score': 0.9879063963890076,
#   'start': 14,
#   'end': 55,
#   'answer': 'you are just upset because you are losing'},
#  {'score': 0.6300405263900757,
#   'start': 16,
#   'end': 46,
#   'answer': 'i think we are all losers here'},
#  {'score': 0.9972641468048096,
#   'start': 0,
#   'end': 24,
#   'answer': 'this game makes no sense'},
#  {'score': 0.977695107460022,
#   'start': 0,
#   'end': 29,
#   'answer': 'either it makes no difference'},
#  {'score': 0.7846626043319702,
#   'start': 5,
#   'end': 58,
#   'answer': 'you picked the gimmie card you get all of ross points'},
#  {'score': 0.9701864719390869,
#   'start': 5,
#   'end': 58,
#   'answer': 'you picked the gimmie card you get all of ross points'},
#  {'score': 0.9562055468559265,
#   'start': 5,
#   'end': 58,
#   'answer': 'you picked the gimmie card you get all of ross points'},
#  {'score': 0.9990212321281433,
#   'start': 0,
#   'end': 22,
#   'answer': 'this game is kinda fun'},
#  {'score': 0.9942185282707214,
#   'start': 5,
#   'end': 58,
#   'answer': 'you picked the gimmie card you get all of ross points'},
#  {'score': 0.40349632501602173,
#   'start': 43,
#   'end': 79,
#   'answer': 'you get all my points just cause you'},
#  {'score': 0.9988672733306885,
#   'start': 0,
#   'end': 16,
#   'answer': 'i did not get it'},
#  {'score': 0.7770781517028809,
#   'start': 3,
#   'end': 61,
#   'answer': 'the off broadway play people said you were pretty but dumb'},
#  {'score': 0.5702828168869019,
#   'start': 18,
#   'end': 57,
#   'answer': 'i would just use my son as as an excuse'},
#  {'score': 0.4857494831085205,
#   'start': 5,
#   'end': 57,
#   'answer': 'do you think i would just use my son as as an excuse'},
#  {'score': 0.967494785785675,
#   'start': 11,
#   'end': 53,
#   'answer': 'i am just done with the whole dating thing'},
#  {'score': 0.8941010236740112,
#   'start': 11,
#   'end': 53,
#   'answer': 'i am just done with the whole dating thing'},
#  {'score': 0.960257887840271,
#   'start': 11,
#   'end': 53,
#   'answer': 'i am just done with the whole dating thing'},
#  {'score': 0.9992884993553162,
#   'start': 0,
#   'end': 12,
#   'answer': 'this is hard'},
#  {'score': 0.9955355525016785,
#   'start': 0,
#   'end': 25,
#   'answer': 'you owe me two zero bucks'},
#  {'score': 0.1170886680483818,
#   'start': 86,
#   'end': 147,
#   'answer': 'your grilled cheese fixin and your family size bag of funyuns'},
#  {'score': 0.9553861618041992,
#   'start': 19,
#   'end': 69,
#   'answer': 'this is what you are havin for thanksgiving dinner'},
#  {'score': 0.9536332488059998,
#   'start': 19,
#   'end': 69,
#   'answer': 'this is what you are havin for thanksgiving dinner'},
#  {'score': 0.9876800775527954,
#   'start': 3,
#   'end': 20,
#   'answer': 'i hate this story'},
#  {'score': 0.15172769129276276,
#   'start': 70,
#   'end': 143,
#   'answer': 'this is the moment my parents choose to tell me they are getting divorced'},
#  {'score': 0.010654865764081478,
#   'start': 118,
#   'end': 143,
#   'answer': 'they are getting divorced'},
#  {'score': 0.020530620589852333,
#   'start': 118,
#   'end': 143,
#   'answer': 'they are getting divorced'},
#  {'score': 0.002679126337170601,
#   'start': 39,
#   'end': 93,
#   'answer': 'a thanksgiving dinner once you have seen it in reverse'},
#  {'score': 0.4934770166873932,
#   'start': 3,
#   'end': 51,
#   'answer': 'you did not you said you would but you never did'},
#  {'score': 0.8537740111351013,
#   'start': 12,
#   'end': 35,
#   'answer': 'i thought we said seven'},
#  {'score': 0.9615455269813538,
#   'start': 25,
#   'end': 36,
#   'answer': 'let skip it'},
#  {'score': 0.5538857579231262,
#   'start': 8,
#   'end': 64,
#   'answer': 'you and your sister seem to have umm a very special bond'},
#  {'score': 0.9400591850280762,
#   'start': 9,
#   'end': 32,
#   'answer': 'that special bond again'},
#  {'score': 0.3216492831707001,
#   'start': 8,
#   'end': 34,
#   'answer': 'if i am close to my family'},
#  {'score': 0.9971737861633301,
#   'start': 0,
#   'end': 25,
#   'answer': 'i can not figure this out'},
#  {'score': 0.9994645714759827,
#   'start': 0,
#   'end': 13,
#   'answer': 'it is so hard'},
#  {'score': 0.9996228218078613,
#   'start': 0,
#   'end': 13,
#   'answer': 'it is so hard'},
#  {'score': 0.9784771203994751, 'start': 0, 'end': 9, 'answer': 'paper cut'},
#  {'score': 0.9996103048324585, 'start': 0, 'end': 11, 'answer': 'you told me'},
#  {'score': 0.5517212152481079,
#   'start': 66,
#   'end': 122,
#   'answer': 'you walked in on me when i was looking at ring brochures'},
#  {'score': 0.5061893463134766,
#   'start': 21,
#   'end': 42,
#   'answer': 'not knocking pays off'},
#  {'score': 0.7768296599388123,
#   'start': 11,
#   'end': 53,
#   'answer': 'we were just gonna see if you wanted to go'},
#  {'score': 0.7155582308769226,
#   'start': 8,
#   'end': 51,
#   'answer': 'we do not because we got the other pl place'},
#  {'score': 0.9989145994186401, 'start': 0, 'end': 8, 'answer': 'how rude'},
#  {'score': 0.9985827207565308, 'start': 0, 'end': 8, 'answer': 'how rude'},
#  {'score': 0.9958981871604919,
#   'start': 14,
#   'end': 28,
#   'answer': 'you wanna bite'},
#  {'score': 0.8689976334571838,
#   'start': 36,
#   'end': 64,
#   'answer': 'people please make some room'},
#  {'score': 0.9812968969345093,
#   'start': 0,
#   'end': 33,
#   'answer': 'you like you have not done enough'},
#  {'score': 0.9976679086685181,
#   'start': 4,
#   'end': 56,
#   'answer': 'i have never been so uncomfortable in my entire life'},
#  {'score': 0.7232859134674072,
#   'start': 0,
#   'end': 17,
#   'answer': 'oh my gosh joshua'},
#  {'score': 0.9028325080871582,
#   'start': 14,
#   'end': 53,
#   'answer': 'i do not think we should go out anymore'},
#  {'score': 0.9686553478240967,
#   'start': 14,
#   'end': 53,
#   'answer': 'i do not think we should go out anymore'},
#  {'score': 0.94945228099823,
#   'start': 14,
#   'end': 53,
#   'answer': 'i do not think we should go out anymore'},
#  {'score': 0.38218387961387634,
#   'start': 0,
#   'end': 34,
#   'answer': 'how could you pick up a hitchhiker'},
#  {'score': 0.46768710017204285,
#   'start': 0,
#   'end': 50,
#   'answer': 'do not you think i asked him that before he got in'},
#  {'score': 0.017653323709964752,
#   'start': 35,
#   'end': 87,
#   'answer': 'he could be a rape a rapist or a killer or something'},
#  {'score': 0.5056806802749634,
#   'start': 38,
#   'end': 83,
#   'answer': 'you go back to sleep and you are you a rapist'},
#  {'score': 0.9641983509063721,
#   'start': 14,
#   'end': 36,
#   'answer': 'the license plate game'},
#  {'score': 0.9984869956970215,
#   'start': 0,
#   'end': 29,
#   'answer': 'i love the license plate game'},
#  {'score': 0.884038507938385,
#   'start': 4,
#   'end': 27,
#   'answer': 'i will play i will play'},
#  {'score': 0.7699230313301086,
#   'start': 6,
#   'end': 37,
#   'answer': 'you need your sleep night night'},
#  {'score': 0.7022203207015991,
#   'start': 0,
#   'end': 65,
#   'answer': 'that mail guy had no idea there was something going on between us'},
#  {'score': 0.9094420671463013,
#   'start': 0,
#   'end': 65,
#   'answer': 'that mail guy had no idea there was something going on between us'},
#  {'score': 0.6727035641670227,
#   'start': 9,
#   'end': 48,
#   'answer': 'i love doing crossword puzzles with you'},
#  {'score': 0.8872284293174744,
#   'start': 9,
#   'end': 54,
#   'answer': 'i love doing crossword puzzles with you honey'},
#  {'score': 0.5140638947486877,
#   'start': 15,
#   'end': 44,
#   'answer': 'let finish this and go to bed'},
#  {'score': 0.36592575907707214,
#   'start': 4,
#   'end': 31,
#   'answer': 'you are so smart i love you'},
#  {'score': 0.6712207198143005, 'start': 21, 'end': 31, 'answer': 'i love you'},
#  {'score': 0.9991046190261841,
#   'start': 0,
#   'end': 14,
#   'answer': 'i love you too'},
#  {'score': 0.9893513321876526,
#   'start': 3,
#   'end': 19,
#   'answer': 'i feel so stupid'},
#  {'score': 0.9932998418807983,
#   'start': 3,
#   'end': 19,
#   'answer': 'i feel so stupid'},
#  {'score': 0.9992688894271851,
#   'start': 0,
#   'end': 19,
#   'answer': 'i am so embarrassed'},
#  {'score': 0.8487617373466492,
#   'start': 7,
#   'end': 60,
#   'answer': 'if i had never met him this never would have happened'},
#  {'score': 0.9996337890625,
#   'start': 0,
#   'end': 19,
#   'answer': 'i am so embarrassed'},
#  {'score': 0.9997122287750244,
#   'start': 0,
#   'end': 19,
#   'answer': 'i am so embarrassed'},
#  {'score': 0.7666100859642029,
#   'start': 7,
#   'end': 60,
#   'answer': 'if i had never met him this never would have happened'},
#  {'score': 0.5362060070037842,
#   'start': 7,
#   'end': 60,
#   'answer': 'if i had never met him this never would have happened'},
#  {'score': 0.30994662642478943,
#   'start': 42,
#   'end': 55,
#   'answer': 'no i am sorry'},
#  {'score': 0.9432854056358337,
#   'start': 11,
#   'end': 34,
#   'answer': 'what are we sorry about'},
#  {'score': 0.7651248574256897,
#   'start': 20,
#   'end': 33,
#   'answer': 'he is the pig'},
#  {'score': 0.5411020517349243,
#   'start': 0,
#   'end': 33,
#   'answer': 'i do not know right he is the pig'},
#  {'score': 0.9984982013702393, 'start': 0, 'end': 10, 'answer': 'such a pig'},
#  {'score': 0.7140871286392212,
#   'start': 20,
#   'end': 33,
#   'answer': 'he is the pig'},
#  {'score': 0.9979774951934814, 'start': 0, 'end': 10, 'answer': 'such a pig'},
#  {'score': 0.9962570071220398,
#   'start': 7,
#   'end': 23,
#   'answer': 'he is such a pig'},
#  {'score': 0.6741954684257507,
#   'start': 20,
#   'end': 33,
#   'answer': 'he is the pig'},
#  {'score': 0.9552890062332153, 'start': 0, 'end': 10, 'answer': 'such a pig'},
#  {'score': 0.9949219822883606,
#   'start': 7,
#   'end': 23,
#   'answer': 'he is such a pig'},
#  {'score': 0.8870269656181335,
#   'start': 20,
#   'end': 33,
#   'answer': 'he is the pig'},
#  {'score': 0.9984304904937744, 'start': 0, 'end': 10, 'answer': 'such a pig'},
#  {'score': 0.996161162853241,
#   'start': 7,
#   'end': 23,
#   'answer': 'he is such a pig'},
#  {'score': 0.992942214012146,
#   'start': 0,
#   'end': 39,
#   'answer': 'he is like a big disgusting pig pig man'},
#  {'score': 0.9922306537628174,
#   'start': 0,
#   'end': 39,
#   'answer': 'he is like a big disgusting pig pig man'},
#  {'score': 0.11893458664417267,
#   'start': 15,
#   'end': 79,
#   'answer': 'go to the bank close our accounts and cut them off at the source'},
#  {'score': 0.0349191352725029,
#   'start': 6,
#   'end': 65,
#   'answer': 'we could go to the bank close our accounts and cut them off'},
#  {'score': 0.9997285604476929,
#   'start': 0,
#   'end': 16,
#   'answer': 'you are a genius'},
#  {'score': 0.6149654388427734,
#   'start': 8,
#   'end': 39,
#   'answer': 'now we will not be bank buddies'},
#  {'score': 0.9999858140945435, 'start': 0, 'end': 3, 'answer': 'hey'},
#  {'score': 0.9999858140945435, 'start': 0, 'end': 3, 'answer': 'hey'},
#  {'score': 0.99855637550354, 'start': 56, 'end': 65, 'answer': 'i bit him'},
#  {'score': 0.8795618414878845, 'start': 56, 'end': 65, 'answer': 'i bit him'},
#  {'score': 0.9974807500839233,
#   'start': 0,
#   'end': 13,
#   'answer': 'on the touchy'},
#  {'score': 0.5618370771408081,
#   'start': 0,
#   'end': 31,
#   'answer': 'and thats not against your oath'},
#  {'score': 0.6420450210571289,
#   'start': 0,
#   'end': 31,
#   'answer': 'and thats not against your oath'},
#  {'score': 0.3905624747276306,
#   'start': 53,
#   'end': 99,
#   'answer': 'throw out my old oath and take a new dirty one'},
#  {'score': 0.9555132985115051,
#   'start': 5,
#   'end': 70,
#   'answer': 'next time your massaging him you should try and distract yourself'},
#  {'score': 0.5572865605354309,
#   'start': 39,
#   'end': 60,
#   'answer': 'guess which job i got'},
#  {'score': 0.9787284731864929,
#   'start': 18,
#   'end': 58,
#   'answer': 'donald trump wants his blue blazer black'},
#  {'score': 0.9926491379737854,
#   'start': 18,
#   'end': 58,
#   'answer': 'donald trump wants his blue blazer black'},
#  {'score': 0.2556588649749756,
#   'start': 4,
#   'end': 62,
#   'answer': 'you you said black why would he want his blue blazer black'},
#  {'score': 0.6988117098808289,
#   'start': 3,
#   'end': 34,
#   'answer': 'you messed it up you are stupid'},
#  {'score': 0.783584713935852,
#   'start': 3,
#   'end': 27,
#   'answer': 'what job did you get joe'},
#  {'score': 0.7009541392326355,
#   'start': 36,
#   'end': 54,
#   'answer': 'ross got it for me'},
#  {'score': 0.6523061394691467,
#   'start': 3,
#   'end': 27,
#   'answer': 'what job did you get joe'},
#  {'score': 0.8499239087104797,
#   'start': 36,
#   'end': 54,
#   'answer': 'ross got it for me'},
#  {'score': 0.3795999586582184,
#   'start': 5,
#   'end': 32,
#   'answer': 'how can you be a tour guide'},
#  {'score': 0.9400688409805298,
#   'start': 0,
#   'end': 30,
#   'answer': 'why have you been following me'},
#  {'score': 0.7072230577468872,
#   'start': 21,
#   'end': 51,
#   'answer': 'everywhere i look there is you'},
#  {'score': 0.9873231649398804,
#   'start': 0,
#   'end': 30,
#   'answer': 'why have you been following me'},
#  {'score': 0.7369158267974854,
#   'start': 7,
#   'end': 51,
#   'answer': 'all week long everywhere i look there is you'},
#  {'score': 0.4659442901611328,
#   'start': 0,
#   'end': 54,
#   'answer': 'you would not return my calls you sent back my letters'},
#  {'score': 0.9955741167068481,
#   'start': 0,
#   'end': 30,
#   'answer': 'why have you been following me'},
#  {'score': 0.681354284286499,
#   'start': 0,
#   'end': 54,
#   'answer': 'you would not return my calls you sent back my letters'},
#  {'score': 0.7094843983650208,
#   'start': 0,
#   'end': 54,
#   'answer': 'you would not return my calls you sent back my letters'},
#  {'score': 0.0019124019891023636,
#   'start': 82,
#   'end': 133,
#   'answer': 'she comes in early to eat her breakfast at her desk'},
#  {'score': 0.9994878172874451,
#   'start': 0,
#   'end': 17,
#   'answer': 'that is kinda sad'},
#  {'score': 0.0587717704474926,
#   'start': 98,
#   'end': 140,
#   'answer': 'while i distract her you get in the office'},
#  {'score': 0.9916500449180603,
#   'start': 0,
#   'end': 21,
#   'answer': 'you know where i work'},
#  {'score': 0.9988362789154053,
#   'start': 0,
#   'end': 31,
#   'answer': 'you still work at the multiplex'},
#  {'score': 0.09803549200296402,
#   'start': 8,
#   'end': 55,
#   'answer': 'i would give up that job free popcorn and candy'},
#  {'score': 0.32370126247406006,
#   'start': 7,
#   'end': 53,
#   'answer': 'betting the apartment i do not know about this'},
#  {'score': 0.48571425676345825,
#   'start': 7,
#   'end': 68,
#   'answer': 'i have not missed one question the whole game i own this game'},
#  {'score': 0.8925962448120117,
#   'start': 0,
#   'end': 44,
#   'answer': 'why do you have the answers written on there'},
#  {'score': 0.4656863212585449,
#   'start': 0,
#   'end': 53,
#   'answer': 'monica betting the apartment i do not know about this'},
#  {'score': 0.027446826919913292,
#   'start': 75,
#   'end': 105,
#   'answer': 'mr geller is mentally unstable'},
#  {'score': 0.9951913952827454,
#   'start': 5,
#   'end': 27,
#   'answer': 'i am mentally unstable'},
#  {'score': 0.7460805177688599,
#   'start': 4,
#   'end': 61,
#   'answer': 'based on the fact that mr geller is intravenous drug user'},
#  {'score': 0.6706777811050415,
#   'start': 4,
#   'end': 61,
#   'answer': 'based on the fact that mr geller is intravenous drug user'},
#  {'score': 0.9461994171142578,
#   'start': 7,
#   'end': 23,
#   'answer': 'heroin and crack'},
#  {'score': 0.6815922856330872,
#   'start': 0,
#   'end': 80,
#   'answer': 'now it also says here that you lied about your sexual preference before marriage'},
#  {'score': 0.30097725987434387,
#   'start': 17,
#   'end': 80,
#   'answer': 'here that you lied about your sexual preference before marriage'},
#  {'score': 0.9992009997367859,
#   'start': 0,
#   'end': 41,
#   'answer': 'i thought it was gonna be a closed casket'},
#  {'score': 0.9845654368400574,
#   'start': 24,
#   'end': 45,
#   'answer': 'she can not look nice'},
#  {'score': 0.9770844578742981,
#   'start': 0,
#   'end': 36,
#   'answer': 'i am moving out like we talked about'},
#  {'score': 0.03700482100248337,
#   'start': 140,
#   'end': 167,
#   'answer': 'help me to grow or whatever'},
#  {'score': 0.8829336166381836,
#   'start': 0,
#   'end': 59,
#   'answer': 'you wanna go in the bedroom it is a little more comfortable'},
#  {'score': 0.9825760126113892,
#   'start': 0,
#   'end': 59,
#   'answer': 'you wanna go in the bedroom it is a little more comfortable'},
#  {'score': 0.9717874526977539,
#   'start': 0,
#   'end': 59,
#   'answer': 'you wanna go in the bedroom it is a little more comfortable'},
#  {'score': 0.9999312162399292, 'start': 0, 'end': 4, 'answer': 'sure'},
#  {'score': 0.9287774562835693,
#   'start': 17,
#   'end': 54,
#   'answer': 'did you send those contracts to milan'},
#  {'score': 0.5204389095306396,
#   'start': 0,
#   'end': 33,
#   'answer': 'if this is your idea of sexy talk'},
#  {'score': 0.6668887138366699,
#   'start': 25,
# ...
#   'start': 0,
#   'end': 40,
#   'answer': 'terry already hired that girl over there'},
#  {'score': 0.994915246963501,
#   'start': 12,
#   'end': 47,
#   'answer': 'she is even got waitress experience'},
#  {'score': 0.8377587795257568,
#   'start': 0,
#   'end': 62,
#   'answer': 'last night she was teaching everybody how to make napkin swans'},
#  {'score': 0.9950170516967773,
#   'start': 0,
#   'end': 32,
#   'answer': 'he forgot to leave his grip size'},
#  {'score': 0.9990158677101135,
#   'start': 0,
#   'end': 26,
#   'answer': 'he did not get the goggles'},
#  {'score': 0.7438429594039917,
#   'start': 0,
#   'end': 30,
#   'answer': 'do they wait for me to do this'},
#  {'score': 0.998262882232666,
#   'start': 0,
#   'end': 28,
#   'answer': 'what are you guys doing here'},
#  {'score': 0.9953200221061707,
#   'start': 6,
#   'end': 40,
#   'answer': 'he is not even wearing a jockstrap'},
#  {'score': 0.6945785284042358,
#   'start': 8,
#   'end': 32,
#   'answer': 'that would be a shutdown'},
#  {'score': 0.4184252619743347,
#   'start': 4,
#   'end': 32,
#   'answer': 'and that would be a shutdown'},
#  {'score': 0.7186801433563232,
#   'start': 0,
#   'end': 46,
#   'answer': 'where are you guys going come on one more game'},
#  {'score': 0.9874043464660645,
#   'start': 0,
#   'end': 46,
#   'answer': 'where are you guys going come on one more game'},
#  {'score': 0.9986030459403992,
#   'start': 3,
#   'end': 38,
#   'answer': 'it is two three zero in the morning'},
#  {'score': 0.9619606733322144,
#   'start': 0,
#   'end': 46,
#   'answer': 'where are you guys going come on one more game'},
#  {'score': 0.9970760345458984,
#   'start': 3,
#   'end': 38,
#   'answer': 'it is two three zero in the morning'},
#  {'score': 0.8438119888305664, 'start': 5, 'end': 12, 'answer': 'get out'},
#  {'score': 0.9994950294494629,
#   'start': 0,
#   'end': 47,
#   'answer': 'you guys are always hanging out in my apartment'},
#  {'score': 0.9985951781272888,
#   'start': 0,
#   'end': 13,
#   'answer': 'one more game'},
#  {'score': 0.9759380221366882, 'start': 0, 'end': 7, 'answer': 'oh yeah'},
#  {'score': 0.9401735067367554,
#   'start': 0,
#   'end': 68,
#   'answer': 'he says that walking with you makes this strange city feel like home'},
#  {'score': 0.9995487332344055,
#   'start': 0,
#   'end': 25,
#   'answer': 'your eyes are very pretty'},
#  {'score': 0.9993345141410828,
#   'start': 0,
#   'end': 25,
#   'answer': 'your eyes are very pretty'},
#  {'score': 0.8829591274261475,
#   'start': 20,
#   'end': 53,
#   'answer': 'he is only had sex with one woman'},
#  {'score': 0.7545557022094727,
#   'start': 20,
#   'end': 53,
#   'answer': 'he is only had sex with one woman'},
#  {'score': 0.45266541838645935,
#   'start': 29,
#   'end': 55,
#   'answer': 'it is sweet it is romantic'},
#  {'score': 0.5988028645515442,
#   'start': 41,
#   'end': 55,
#   'answer': 'it is romantic'},
#  {'score': 0.6753501892089844,
#   'start': 20,
#   'end': 53,
#   'answer': 'he is only had sex with one woman'},
#  {'score': 0.4321573078632355,
#   'start': 3,
#   'end': 42,
#   'answer': 'you kidding the guy a freak i judge him'},
#  {'score': 0.9974451661109924,
#   'start': 3,
#   'end': 21,
#   'answer': 'that is attractive'},
#  {'score': 0.9592428207397461,
#   'start': 3,
#   'end': 51,
#   'answer': 'i thought you were great in silence of the lambs'},
#  {'score': 0.7164682149887085,
#   'start': 11,
#   'end': 61,
#   'answer': 'admit it all things considered you had fun tonight'},
#  {'score': 0.7103176712989807,
#   'start': 11,
#   'end': 61,
#   'answer': 'admit it all things considered you had fun tonight'},
#  {'score': 0.5069419741630554,
#   'start': 43,
#   'end': 87,
#   'answer': 'which part was the fun part where is my puck'},
#  {'score': 0.9942300915718079,
#   'start': 6,
#   'end': 20,
#   'answer': 'the kid has it'},
#  {'score': 0.6672531962394714,
#   'start': 21,
#   'end': 36,
#   'answer': 'that is my puck'},
#  {'score': 0.9992647171020508,
#   'start': 0,
#   'end': 41,
#   'answer': 'i found it finders keepers losers weepers'},
#  {'score': 0.9916240572929382,
#   'start': 10,
#   'end': 28,
#   'answer': 'gimme back my puck'},
#  {'score': 0.9999722242355347, 'start': 0, 'end': 2, 'answer': 'no'},
#  {'score': 0.5086466670036316,
#   'start': 8,
#   'end': 33,
#   'answer': 'no rough holding in my er'},
#  {'score': 0.9855532646179199,
#   'start': 10,
#   'end': 28,
#   'answer': 'gimme back my puck'},
#  {'score': 0.999976634979248, 'start': 0, 'end': 2, 'answer': 'no'},
#  {'score': 0.7094969153404236,
#   'start': 0,
#   'end': 16,
#   'answer': 'now that was fun'},
#  {'score': 0.25942263007164,
#   'start': 0,
#   'end': 21,
#   'answer': 'what we did was wrong'},
#  {'score': 0.9994460344314575,
#   'start': 0,
#   'end': 14,
#   'answer': 'i just had sex'},
#  {'score': 0.3840617537498474,
#   'start': 0,
#   'end': 37,
#   'answer': 'ethan focus how could you not tell me'},
#  {'score': 0.9819861054420471,
#   'start': 5,
#   'end': 39,
#   'answer': 'you never told me how old you were'},
#  {'score': 0.9031171202659607,
#   'start': 12,
#   'end': 37,
#   'answer': 'how could you not tell me'},
#  {'score': 0.8056517243385315,
#   'start': 5,
#   'end': 39,
#   'answer': 'you never told me how old you were'},
#  {'score': 0.3766483664512634,
#   'start': 23,
#   'end': 81,
#   'answer': 'my lie did not make one of us a felon in four eight states'},
#  {'score': 0.470211386680603,
#   'start': 12,
#   'end': 37,
#   'answer': 'how could you not tell me'},
#  {'score': 0.1673848181962967,
#   'start': 23,
#   'end': 81,
#   'answer': 'my lie did not make one of us a felon in four eight states'},
#  {'score': 0.9211681485176086,
#   'start': 12,
#   'end': 37,
#   'answer': 'how could you not tell me'},
#  {'score': 0.17550046741962433,
#   'start': 23,
#   'end': 81,
#   'answer': 'my lie did not make one of us a felon in four eight states'},
#  {'score': 0.9971712827682495,
#   'start': 0,
#   'end': 22,
#   'answer': 'what were you thinking'},
#  {'score': 0.9222663044929504,
#   'start': 0,
#   'end': 41,
#   'answer': 'i was not thinking i was too busy falling'},
#  {'score': 0.9908758997917175,
#   'start': 0,
#   'end': 13,
#   'answer': 'do not say it'},
#  {'score': 0.9322176575660706,
#   'start': 0,
#   'end': 41,
#   'answer': 'i was not thinking i was too busy falling'},
#  {'score': 0.998270571231842,
#   'start': 0,
#   'end': 16,
#   'answer': 'in love with you'},
#  {'score': 0.7281243801116943,
#   'start': 12,
#   'end': 37,
#   'answer': 'how could you not tell me'},
#  {'score': 0.11242716759443283,
#   'start': 23,
#   'end': 81,
#   'answer': 'my lie did not make one of us a felon in four eight states'},
#  {'score': 0.993511974811554,
#   'start': 0,
#   'end': 22,
#   'answer': 'what were you thinking'},
#  {'score': 0.9366672039031982,
#   'start': 29,
#   'end': 100,
#   'answer': 'i just had sex with somebody that was not alive during the bicentennial'},
#  {'score': 0.4431855380535126,
#   'start': 12,
#   'end': 37,
#   'answer': 'how could you not tell me'},
#  {'score': 0.9673008322715759,
#   'start': 29,
#   'end': 100,
#   'answer': 'i just had sex with somebody that was not alive during the bicentennial'},
#  {'score': 0.974735677242279,
#   'start': 12,
#   'end': 37,
#   'answer': 'how could you not tell me'},
#  {'score': 0.9561553597450256,
#   'start': 9,
#   'end': 57,
#   'answer': 'you should not even be here it is a school night'},
#  {'score': 0.7267886996269226,
#   'start': 29,
#   'end': 100,
#   'answer': 'i just had sex with somebody that was not alive during the bicentennial'},
#  {'score': 0.9699575304985046,
#   'start': 14,
#   'end': 75,
#   'answer': 'i am like those women that you see with shiny guys named chad'},
#  {'score': 0.9526407122612,
#   'start': 29,
#   'end': 100,
#   'answer': 'i just had sex with somebody that was not alive during the bicentennial'},
#  {'score': 0.9955013990402222,
#   'start': 14,
#   'end': 75,
#   'answer': 'i am like those women that you see with shiny guys named chad'},
#  {'score': 0.9889733791351318,
#   'start': 9,
#   'end': 27,
#   'answer': 'i do not wanna die'},
#  {'score': 0.9943628907203674,
#   'start': 9,
#   'end': 27,
#   'answer': 'i do not wanna die'},
#  {'score': 0.6459065079689026,
#   'start': 6,
#   'end': 65,
#   'answer': 'it will be fun we can come back and we can haunt these guys'},
#  {'score': 0.990188479423523,
#   'start': 0,
#   'end': 18,
#   'answer': 'check out the ring'},
#  {'score': 0.9854867458343506,
#   'start': 0,
#   'end': 18,
#   'answer': 'check out the ring'},
#  {'score': 0.990574300289154,
#   'start': 0,
#   'end': 30,
#   'answer': 'nice one and a half carat easy'},
#  {'score': 0.9999819993972778, 'start': 0, 'end': 2, 'answer': 'hi'},
#  {'score': 0.9982702732086182,
#   'start': 0,
#   'end': 38,
#   'answer': 'chandler gonna ask monica to marry him'},
#  {'score': 0.9968252778053284,
#   'start': 0,
#   'end': 38,
#   'answer': 'chandler gonna ask monica to marry him'},
#  {'score': 0.9989278316497803,
#   'start': 0,
#   'end': 38,
#   'answer': 'chandler gonna ask monica to marry him'},
#  {'score': 0.9934329986572266,
#   'start': 10,
#   'end': 36,
#   'answer': 'i helped pick out the ring'},
#  {'score': 0.9208627343177795,
#   'start': 0,
#   'end': 31,
#   'answer': 'you told her before you told us'},
#  {'score': 0.5655592083930969,
#   'start': 46,
#   'end': 112,
#   'answer': 'i say you go in there and be the most committed guy there ever was'},
#  {'score': 0.881787896156311,
#   'start': 10,
#   'end': 26,
#   'answer': 'that makes sense'},
#  {'score': 0.8791188597679138,
#   'start': 46,
#   'end': 112,
#   'answer': 'i say you go in there and be the most committed guy there ever was'},
#  {'score': 0.9735428690910339,
#   'start': 0,
#   'end': 26,
#   'answer': 'amazingly that makes sense'},
#  {'score': 0.08912168443202972,
#   'start': 22,
#   'end': 44,
#   'answer': 'jump off the high dive'},
#  {'score': 0.011642714031040668,
#   'start': 22,
#   'end': 44,
#   'answer': 'jump off the high dive'},
#  {'score': 0.12390601634979248,
#   'start': 22,
#   'end': 62,
#   'answer': 'if i am staring down the barrel of a gun'},
#  {'score': 0.9920983910560608,
#   'start': 0,
#   'end': 35,
#   'answer': 'i do not know what i am going to do'},
#  {'score': 0.9654979705810547,
#   'start': 0,
#   'end': 54,
#   'answer': 'i called the company that sent and th they do not care'},
#  {'score': 0.018764041364192963,
#   'start': 31,
#   'end': 90,
#   'answer': 'they laughed at me if this is not an emergency then what is'},
#  {'score': 0.9940551519393921,
#   'start': 0,
#   'end': 54,
#   'answer': 'i called the company that sent and th they do not care'},
#  {'score': 0.03471158817410469,
#   'start': 5,
#   'end': 49,
#   'answer': 'i called nine one one and they laughed at me'},
#  {'score': 0.9980092644691467, 'start': 0, 'end': 8, 'answer': 'hey guys'},
#  {'score': 0.9975515604019165, 'start': 0, 'end': 8, 'answer': 'hey guys'},
#  {'score': 0.9999858140945435, 'start': 0, 'end': 3, 'answer': 'hey'},
#  {'score': 0.2345646470785141,
#   'start': 37,
#   'end': 66,
#   'answer': 'last night what a great party'},
#  {'score': 0.9452030062675476,
#   'start': 4,
#   'end': 34,
#   'answer': 'the guys from work had a blast'},
#  {'score': 0.2974783480167389,
#   'start': 48,
#   'end': 66,
#   'answer': 'what a great party'},
#  {'score': 0.7450061440467834,
#   'start': 4,
#   'end': 34,
#   'answer': 'the guys from work had a blast'},
#  {'score': 0.9864902496337891,
#   'start': 9,
#   'end': 62,
#   'answer': 'one of them had never been to a bachelor party before'},
#  {'score': 0.6594341993331909,
#   'start': 8,
#   'end': 52,
#   'answer': 'another one had never been to a party before'},
#  {'score': 0.5897043943405151,
#   'start': 10,
#   'end': 56,
#   'answer': 'that uh that wedding ring huh man that is nice'},
#  {'score': 0.9450464248657227,
#   'start': 44,
#   'end': 56,
#   'answer': 'that is nice'},
#  {'score': 0.26438748836517334,
#   'start': 79,
#   'end': 111,
#   'answer': 'i might want to get one of those'},
#  {'score': 0.43342623114585876,
#   'start': 17,
#   'end': 42,
#   'answer': 'the ring is irreplaceable'},
#  {'score': 0.3781653940677643,
#   'start': 59,
#   'end': 116,
#   'answer': 'every bride who has worn it has had a long and happy life'},
#  {'score': 0.29594510793685913,
#   'start': 59,
#   'end': 116,
#   'answer': 'every bride who has worn it has had a long and happy life'},
#  {'score': 0.6818235516548157,
#   'start': 0,
#   'end': 35,
#   'answer': 'so you might say it is a magic ring'},
#  {'score': 0.9045879244804382,
#   'start': 0,
#   'end': 31,
#   'answer': 'you you you had sex with ursula'},
#  {'score': 0.8629729747772217,
#   'start': 0,
#   'end': 31,
#   'answer': 'you you you had sex with ursula'},
#  {'score': 0.20066197216510773,
#   'start': 42,
#   'end': 63,
#   'answer': 'i thought she was you'},
#  {'score': 0.9600410461425781,
#   'start': 0,
#   'end': 31,
#   'answer': 'you you you had sex with ursula'},
#  {'score': 0.3326973617076874,
#   'start': 42,
#   'end': 80,
#   'answer': 'i thought she was you and i kissed her'},
#  {'score': 0.7503383755683899,
#   'start': 19,
#   'end': 52,
#   'answer': 'she was wearing different clothes'},
#  {'score': 0.881548285484314,
#   'start': 0,
#   'end': 31,
#   'answer': 'you you you had sex with ursula'},
#  {'score': 0.40914231538772583,
#   'start': 42,
#   'end': 80,
#   'answer': 'i thought she was you and i kissed her'},
#  {'score': 0.7994154691696167,
#   'start': 0,
#   'end': 31,
#   'answer': 'you you you had sex with ursula'},
#  {'score': 0.33452844619750977,
#   'start': 42,
#   'end': 84,
#   'answer': 'i thought she was you and i kissed her and'},
#  {'score': 0.9393041133880615,
#   'start': 30,
#   'end': 47,
#   'answer': 'this is too weird'},
#  {'score': 0.9575155973434448,
#   'start': 30,
#   'end': 47,
#   'answer': 'this is too weird'},
#  {'score': 0.9952942728996277,
#   'start': 0,
#   'end': 25,
#   'answer': 'i do not want to lose you'},
#  {'score': 0.2648414671421051,
#   'start': 74,
#   'end': 116,
#   'answer': 'i thought she was you yeah it is too weird'},
#  {'score': 0.21810849010944366,
#   'start': 74,
#   'end': 116,
#   'answer': 'i thought she was you yeah it is too weird'},
#  {'score': 0.5604737997055054, 'start': 11, 'end': 21, 'answer': 'this is it'},
#  {'score': 0.41964516043663025,
#   'start': 3,
#   'end': 21,
#   'answer': 'i guess this is it'},
#  {'score': 0.9962401390075684,
#   'start': 5,
#   'end': 41,
#   'answer': 'it just would not have been feasible'},
#  {'score': 0.9961135387420654,
#   'start': 5,
#   'end': 41,
#   'answer': 'it just would not have been feasible'},
#  {'score': 0.7249687910079956,
#   'start': 4,
#   'end': 74,
#   'answer': 'having a dove place the ring on your finger would have been no problem'},
#  {'score': 0.8589206337928772,
#   'start': 0,
#   'end': 46,
#   'answer': 'it was really fun being married to you tonight'},
#  {'score': 0.9570149779319763,
#   'start': 0,
#   'end': 46,
#   'answer': 'it was really fun being married to you tonight'},
#  {'score': 0.7777796983718872,
#   'start': 13,
#   'end': 69,
#   'answer': 'it was the easiest four zero zero bucks i have ever made'},
#  {'score': 0.9458803534507751,
#   'start': 14,
#   'end': 27,
#   'answer': 'it was stupid'},
#  {'score': 0.6798335909843445,
#   'start': 14,
#   'end': 27,
#   'answer': 'it was stupid'},
#  {'score': 0.7438564300537109,
#   'start': 0,
#   'end': 55,
#   'answer': 'with the with the lilies and and the song and the stars'},
#  {'score': 0.6375827193260193,
#   'start': 0,
#   'end': 55,
#   'answer': 'with the with the lilies and and the song and the stars'},
#  {'score': 0.9994003176689148,
#   'start': 0,
#   'end': 23,
#   'answer': 'it was really wonderful'},
#  {'score': 0.5590595602989197,
#   'start': 0,
#   'end': 25,
#   'answer': 'did you just make that up'},
#  {'score': 0.7925446033477783,
#   'start': 0,
#   'end': 16,
#   'answer': 'and your breasts'},
#  {'score': 0.9646350741386414,
#   'start': 9,
#   'end': 42,
#   'answer': 'you are coming on a little strong'},
#  {'score': 0.9976932406425476,
#   'start': 0,
#   'end': 34,
#   'answer': 'i write erotic novels for children'},
#  {'score': 0.9959263801574707,
#   'start': 0,
#   'end': 34,
#   'answer': 'i write erotic novels for children'},
#  {'score': 0.6504480242729187,
#   'start': 45,
#   'end': 58,
#   'answer': 'i have a ph d'},
#  {'score': 0.9932368397712708, 'start': 0, 'end': 7, 'answer': 'whazzup'},
#  {'score': 0.9967979192733765, 'start': 0, 'end': 7, 'answer': 'whazzup'},
#  {'score': 0.25465118885040283,
#   'start': 33,
#   'end': 80,
#   'answer': 'make sure nothing happens between him and molly'},
#  {'score': 0.9977954626083374,
#   'start': 0,
#   'end': 20,
#   'answer': 'you do not trust him'},
#  ...]

# %%
import evaluate

def findEvalMetrics(true_labels, predictions):
    bleu = evaluate.load("bleu")
    results_bleu1 = bleu.compute(predictions=predictions, references=true_labels,max_order = 1)
    results_bleu2 = bleu.compute(predictions=predictions, references=true_labels,max_order = 2)
    results_bleu3 = bleu.compute(predictions=predictions, references=true_labels,max_order = 3)
    results_bleu4 = bleu.compute(predictions=predictions, references=true_labels,max_order = 4)

    results_bleu=[results_bleu1, results_bleu2, results_bleu3, results_bleu4]

    meteor = evaluate.load("meteor")
    results_meteor = meteor.compute(predictions=predictions, references=true_labels)

    return [results_bleu,results_meteor]

# %%
# true_labels = [x['text'][0] if x['text'][0] != '' else 'null' for x in raw_datasets['validation']['answers']]
true_labels = [x['text'][0] for x in raw_datasets['validation']['answers']]
true_labels
# Out:
# ['hey',
#  'check this out huh yeah that is the stuff',
#  'you are not really gonna buy that are you do not you think you have embarrassed me enough for one day',
#  'you have embarrassed me enough for one day',
#  'i embarrass you',
#  'you insist on wearing that in public',
#  'if you insist on wearing that in public you know you are gonna spend the rest of the afternoon all by yourself',
#  'you are gonna make me choose between you and the hat',
#  'if you are gonna make me choose between you and the hat i choose the hat',
#  'you are moving',
#  'monica moving',
#  'monica moving',
#  'all your stuff is in this box',
#  'hey',
#  'hey',
#  'hey',
#  'you are the next caller',
#  'you were the next caller five hours ago',
#  'what going on',
#  'she broke my arm',
#  'he touched my fanny',
#  'she touched mine first',
#  'he touched my fanny',
#  'no she touched mine first',
#  'this girl is good',
#  'this girl is good',
#  'look at you all jealous',
#  'everyone else is happy she is done',
#  'my next song called phoebe buffay what can i say',
#  'i really loved when we were singing partners and i should not have left you that way',
#  'one of those look for the hidden meaning songs',
#  'i invented the game of cups as a way to give joey money',
#  'now you want that money back',
#  'i invented the game of cups as a way to give joey money',
#  'now you want that money back',
#  'exactly',
#  'what kind of an idiot do you take me for',
#  'what kind of an idiot do you take me for',
#  'now you want that money back',
#  'exactly',
#  'i won it fair and square',
#  'look here is a picture of scotty jared naked',
#  'here is a picture of scotty jared naked',
#  'he is wearing a sweater',
#  'there is such a thing as too many women',
#  'did did did i wake you',
#  'this is so nice',
#  'look at the little cat',
#  'look at the little cat',
#  'look at the little cat',
#  'my new china cabinet',
#  'my father house does that',
#  'how did it go tell me everything',
#  'let do it',
#  'what was that',
#  'what are you doing here i thought you were in your room',
#  'these are for you',
#  'they are my favorite',
#  'this is so great',
#  'this is so great',
#  'this is so great',
#  'i actually feel like i am going on a real date',
#  'a subscription to playboy my kind of woman',
#  'so this roommate of yours is he good looking',
#  'hm mmm',
#  'i am pretty sure he is gay',
#  'why are you trying to ruin the game',
#  'what are you doing here',
#  'i i came to fill your ice cube trays',
#  'my father is chuck magioni',
#  'my father is chuck magioni',
#  'no no that is just chuck magioni',
#  'i do not know where your father is',
#  'i do not know where your father is',
#  'i am your mother',
#  'i wanted to tell you yesterday but i just i kinda felt all floopy',
#  'let let look at this objectively i think i should date her',
#  'this can go on for a while',
#  'we will each go out with her one more time and and well see who she likes best',
#  'that sounds fair',
#  'maybe i will take her to that new french restaurant down the street',
#  'maybe i will take her to that new french restaurant down the street',
#  'maybe i will take her to that new french restaurant down the street',
#  'i do not have the money to take her to a fancy place like that',
#  'now you know how you really feel about it',
#  'i lied before',
#  'now you know how you really feel about it',
#  'that is a risky little game',
#  'are you really gonna do this',
#  'i am gonna have a baby i am gonna have a baby i am gonna have a baby',
#  'i am gonna have a baby i am gonna have a baby i am gonna have a baby',
#  'it is still not the time',
#  'chandler gone again',
#  'chandler gone again',
#  'why would you play hide and seek with someone you know is a flight risk',
#  'i think it is time we we had a conversation about about where things are with us',
#  'i i think i suggested that',
#  'i i i like you and i i love umm you know hanging out with you',
#  'i i i like you and i i love umm you know hanging out with you',
#  'it is going somewhere fun',
#  'julie cervix is dilated a seven centimeters that is about four fingers the doctor let me feel it myself',
#  'gotta go i miss you too i love you but it is getting real late now',
#  'this is not ma',
#  'did you know this is not ma',
#  'so how long you been',
#  'remember when you were a little kid i used to take you to the navy yard and show you the big ships',
#  'since then',
#  'you are one to talk',
#  'your dad in love big time and the worst part of it is it is with two different women',
#  'your dad in love big time and the worst part of it is it is with two different women',
#  'please tell me one of them is ma',
#  'looks good',
#  'you guys are selling the entertainment center',
#  'you guys are selling the entertainment center',
#  'you want it',
#  'oh no',
#  'gepeto five zero zero zero dollars',
#  'the ad alone cost three zero zero bucks',
#  'i am changing it to five zero bucks or your best offer',
#  'what kind of profit is that',
#  'you call yourself an accountant',
#  'nooo',
#  'you call yourself an accountant',
#  'nooo',
#  'we realized that the reason we were so angry at each other was because there are still feelings there',
#  'we are gonna give it another try',
#  'what about her whining and her constant need for attention',
#  'you are so capable of change',
#  'we are gonna give it another try',
#  'he hums when he pees',
#  'he hums when he pees',
#  'it makes him miss the bowl',
#  'we are gonna give it another try',
#  'we are gonna give it another try',
#  'let him in your sad men club',
#  'you are so efficient i love you',
#  'let go',
#  'we need something old',
#  'we need something old',
#  'i have condom in my wallet i have had since i was twelve',
#  'that will work',
#  'now we just need something borrowed',
#  'now we just need something borrowed',
#  'here just take this',
#  'that is stealing',
#  'it is brilliant',
#  'we will see you at the wedding',
#  'i could help',
#  'i especially would not want you to think i was gay',
#  'i should have considered your feelings before i went home with you that night',
#  'i should have considered your feelings before i went home with you that night',
#  'i have recently learned what it like to be on your side of it and i am sorry',
#  'i should have considered your feelings before i went home with you that night',
#  'i have recently learned what it like to be on your side of it and i am sorry',
#  'oh hi mrs loreo is jennifer there',
#  'she is not home',
#  'all my stuff is safe and dry and all hers is is is growing new stuff',
#  'all my stuff is safe and dry and all hers is is is growing new stuff',
#  'this is exactly the kind of thing that makes her think you guys love me more than you love her',
#  'this is exactly the kind of thing that makes her think you guys love me more than you love her',
#  'does she really thinks that',
#  'all my stuff is safe and dry and all hers is is is growing new stuff',
#  'this is exactly the kind of thing that makes her think you guys love me more than you love her',
#  'you were a medical marvel',
#  'i do not want to hear about it',
#  'i do not want to hear about it',
#  'all my stuff is safe and dry and all hers is is is growing new stuff',
#  'i had this plan to kiss her at the new years countdown i am trying to win her over',
#  'hey',
#  'manhattan does not have enough stores',
#  'i can help you get over him',
#  'we are here',
#  'where have you been',
#  'it is ross and that girl',
#  'look at that it is a line of ants they are working as a team',
#  'it looks like ross is breaking up with her',
#  'it looks like ross is breaking up with her',
#  'look at that',
#  'that is a that is a second date that is what that is',
#  'she just put her hand on his thigh',
#  'this is all your fault now he loves her he is gonna marry her and this is all your fault',
#  'the jerk that never showed up',
#  'stood up too fast got a little head rush',
#  'do you wanna come in for some lemonade',
#  'this is a great place',
#  'monica what time is it',
#  'i am really getting tired of sneaking around',
#  'we went away for a whole weekend',
#  'we would have no interruptions and we could be naked the entire time',
#  'what if we went away for a whole weekend',
#  'we would have no interruptions and we could be naked the entire time',
#  'you have a chef thing',
#  'go to this culinary fair that they have in jersey',
#  'you set me up with the woman that i have dumped twice in the last five months',
#  'i am making a break for it i am going out the window',
#  'you set me up with the woman that i have dumped twice in the last five months',
#  'can you stop yelling you are making me nervous and i can not go when i am nervous',
#  'you set me up with the woman that i have dumped twice in the last five months',
#  'can you stop yelling you are making me nervous and i can not go when i am nervous',
#  'how do you know how to do that',
#  'i am getting my revenge',
#  'you cooked him',
#  'restaurant reviewer admits i was wrong about monica',
#  'restaurant reviewer admits i was wrong about monica',
#  'i cannot wait to read the front page of the post tomorrow',
#  'restaurant reviewer admits i was wrong about monica',
#  'you are gonna stay with me as long as i need you',
#  'of course i am',
#  'the baby coming and i do not know what to do',
#  'the baby coming and i do not know what to do',
#  'you are gonna be fine',
#  'where are you going where are you going',
#  'hey',
#  'why are you all red and sweaty',
#  'i just bamboozled chandler',
#  'we have a lot of options here a number of prototypes for you to try on',
#  'this looks great',
#  'this looks great',
#  'this one is made of bologna',
#  'and and and and and the toothpicks',
#  'who this little naked guy',
#  'that little naked guy would be me',
#  'look at the little thing',
#  'who are those people',
#  'who are those people',
#  'got me',
#  'you look just like your grandmother',
#  'i got monica naked',
#  'i have got some ones you wanna put them in her panties',
#  'i have got some ones you wanna put them in her panties',
#  'very good so good',
#  'i really really enjoyed it very exotic',
#  'joshua did not call',
#  'joshua did not call',
#  'joshua did not call',
#  'ross is all happy in vermont',
#  'i think i am just gonna go home and call kathy',
#  'well if you think it will help',
#  'i think i am just gonna go home and call kathy',
#  'well if you think it will help',
#  'in a couple of hours i am gonna get really drunk and wanna call kathy',
#  'and then after that i am gonna get so drunk i am gonna wanna call janice',
#  'in a couple of hours i am gonna get really drunk and wanna call kathy and you guys are gonna have to stop me',
#  'and then after that i am gonna get so drunk i am gonna wanna call janice',
#  'i am gonna wanna call janice',
#  'and then after that i am gonna get so drunk i am gonna wanna call janice',
#  'you should',
#  'somebody needs another lap dance',
#  'it is just so realistic',
#  'i get it',
#  'do you ready for a refill',
#  'it is like it is raining',
#  'it is like it is raining',
#  'pretty cool',
#  'if someone told me a week ago that i would be peeing in joey tribbiani apartment',
#  'if someone told me a week ago that i would be peeing in joey tribbiani apartment',
#  'good job joe well done top notch',
#  'good job joe well done top notch',
#  'you liked it you really liked it',
#  'you liked it you really liked it',
#  'yeah',
#  'you liked it you really liked it',
#  'yeah',
#  'i love the specifics the specifics were the best part',
#  'the scene with the kangaroo',
#  'the scene with the kangaroo',
#  'see a kangaroo in a world war i epic',
#  'you fell asleep',
#  'you fell asleep',
#  'you fell asleep',
#  'they did not take any of my suggestions',
#  'you fell asleep',
#  'this guy fell asleep he fell asleep too',
#  'hey pheebs',
#  'hey pheebs it is joey',
#  'hey joey',
#  'i just saw someone on the that looks just like you on the subway',
#  'i just saw someone on the that looks just like you on the subway',
#  'i just saw someone on the that looks just like you on the subway',
#  'i just saw someone on the that looks just like you on the subway',
#  'they are having a great time with their aunt phoebe',
#  'i have just been having way too much fun',
#  'i have just been having way too much fun',
#  'you are not homesick yet',
#  'that was great huh can you believe how long we threw that ball around',
#  'how did i get this reputation as a dropper',
#  'does anyone know where the freeman building is',
#  'yeah it is the new building on avenue a',
#  'that that is all the way cross town i am supposed to teach a graduate seminar there in ten minutes',
#  'move it move it move it',
#  'i am entitled to use my angel pass for a free turn',
#  'this game makes no sense',
#  'this game makes no sense',
#  'you are just upset because you are losing',
#  'you are just upset because you are losing',
#  'i think we are all losers here',
#  'this game makes no sense',
#  'either it makes no difference',
#  'you get all of ross points',
#  'you get all of ross points',
#  'you get all of ross points',
#  'this game is kinda fun',
#  'you get all of ross points',
#  'you do not think it is a little crazy that you get all my points just cause you',
#  'i did not get it',
#  'the off broadway play people said you were pretty but dumb',
#  'do you think i would just use my son as as an excuse',
#  'you think i would just use my son as as an excuse',
#  'i am just done with the whole dating thing',
#  'i am guess i am just done with the whole dating thing',
#  'i am guess i am just done with the whole dating thing',
#  'this is hard',
#  'you owe me two zero bucks',
#  'chandler here you go got your traditional thanksgiving feast you got your tomato soup your grilled cheese fixin and your family size bag of funyuns',
#  'this is what you are havin for thanksgiving dinner',
#  'this is what you are havin for thanksgiving dinner',
#  'i hate this story',
#  'this is the moment my parents choose to tell me they are getting divorced',
#  'this is the moment my parents choose to tell me they are getting divorced',
#  'this is the moment my parents choose to tell me they are getting divorced',
#  'it is very difficult to appreciate a thanksgiving dinner once you have seen it in reverse',
#  'you said you would but you never did',
#  'hey rach i thought we said seven',
#  'let skip it',
#  'you you and your sister seem to have umm a very special bond',
#  'that special bond again',
#  'i am close to my family are you gonna let that stand in the way of us',
#  'i can not figure this out',
#  'it is so hard',
#  'it is so hard',
#  'paper cut',
#  'you told me',
#  'you walked in on me when i was looking at ring brochures',
#  'once again not knocking pays off',
#  'we were just gonna see if you wanted to go',
#  'we do not because we got the other pl place',
#  'how rude',
#  'how rude',
#  'you wanna bite',
#  'still no baby',
#  'like you have not done enough',
#  'i have never been so uncomfortable in my entire life',
#  'joshua',
#  'i do not think we should go out anymore',
#  'i do not think we should go out anymore',
#  'i do not think we should go out anymore',
#  'how could you pick up a hitchhiker he could be a rape a rapist or a killer or something',
#  'do not you think i asked him that before he got in',
#  'how could you pick up a hitchhiker he could be a rape a rapist or a killer or something',
#  'are you a rapist',
#  'you know the license plate game',
#  'i love the license plate game',
#  'i will play i will play',
#  'you need your sleep',
#  'that mail guy had no idea there was something going on between us',
#  'that mail guy had no idea there was something going on between us',
#  'i love doing crossword puzzles with you honey',
#  'i love doing crossword puzzles with you',
#  'now let finish this and go to bed',
#  'you are so smart i love you',
#  'you are so smart i love you',
#  'i love you too',
#  'i feel so stupid',
#  'i feel so stupid',
#  'i am so embarrassed',
#  'if i had never met him this never would have happened',
#  'i am so embarrassed',
#  'i am so embarrassed',
#  'if i had never met him this never would have happened',
#  'if i had never met him this never would have happened',
#  'i am so sorry no i am sorry no i am sorry no i am sorry',
#  'what are we sorry about',
#  'he is the pig',
#  'he is the pig',
#  'such a pig',
#  'he is the pig',
#  'such a pig',
#  'he is such a pig',
#  'he is the pig',
#  'such a pig',
#  'he is such a pig',
#  'he is the pig',
#  'such a pig',
#  'he is such a pig',
#  'he is like a big disgusting pig pig man',
#  'he is like a big disgusting pig pig man',
#  'we could go to the bank close our accounts and cut them off at the source',
#  'we could go to the bank close our accounts and cut them off at the source',
#  'you are a genius',
#  'now we will not be bank buddies',
#  'hey',
#  'hey',
#  'i bit him',
#  'i bit him',
#  'on the touchy',
#  'thats not against your oath',
#  'thats not against your oath',
#  'the moment i touch him i just wanna throw out my old oath and take a new dirty one',
#  'next time your massaging him you should try and distract yourself',
#  'which job i got',
#  'donald trump wants his blue blazer black',
#  'donald trump wants his blue blazer black',
#  'you you said black why would he want his blue blazer black',
#  'you messed it up you are stupid',
#  'what job did you get joe',
#  'tour guide at the museum yeah ross got it for me',
#  'what job did you get joe',
#  'tour guide at the museum yeah ross got it for me',
#  'how can you be a tour guide',
#  'why have you been following me',
#  'all week long everywhere i look there is you',
#  'why have you been following me',
#  'all week long everywhere i look there is you',
#  'you would not return my calls you sent back my letters',
#  'why have you been following me',
#  'you would not return my calls you sent back my letters',
#  'you would not return my calls you sent back my letters',
#  'his assistant betty she comes in early to eat her breakfast at her desk',
#  'that is kinda sad',
#  'while i distract her you get in the office',
#  'you know where i work',
#  'you still work at the multiplex',
#  'free popcorn and candy anytime i want',
#  'betting the apartment',
#  'i have not missed one question the whole game i own this game',
#  'do you have the answers written on there',
#  'betting the apartment',
#  'you are seeking an annulment on the grounds that mr geller is mentally unstable',
#  'i am mentally unstable',
#  'mr geller is intravenous drug user',
#  'mr geller is intravenous drug user',
#  'uh yes heroin and crack',
#  'it also says here that you lied about your sexual preference before marriage',
#  'you lied about your sexual preference before marriage',
#  'i thought it was gonna be a closed casket',
#  'that does not mean she can not look nice',
#  'i am moving out',
#  'i just think it would be good for me you know help me to grow or whatever',
#  'you wanna go in the bedroom it is a little more comfortable',
#  'you wanna go in the bedroom it is a little more comfortable',
#  'you wanna go in the bedroom it is a little more comfortable',
#  'sure',
#  'did you send those contracts to milan',
#  'if this is your idea of sexy talk',
#  'this is just one of your jokes that you do that i do not get',
#  'you put the phone in your pants',
#  'i am serious',
#  'this is not funny',
#  'i am serious',
#  'this is not funny',
#  'i am serious',
#  'this is not funny',
#  'those contracts absolutely had to go out today',
#  'you did not give me any contracts',
#  'you did not give me any contracts',
#  'yes i did and i put a little post it on it that said must go out today and underlined today three times',
#  'you never gave them to me',
#  'if we went down to the office you would see those contracts sitting on your desk',
#  'you never gave them to me',
#  'if we went down to the office you would see those contracts sitting on your desk',
#  'they are not on my desk',
#  'i would see you looking embarrassed because they are not on my desk',
#  'maybe you would see me looking embarrassed because you are talking on the phone with your crotch',
#  'when did you unhook this nice work',
#  'now everybody wants to be under this hat',
#  'what with all this sand',
#  'hi',
#  'i know why you are here',
#  'ross and rachel rachel and ross that is been one heck of a see saw has not it',
#  'do not you think it is better if we just stayed friends',
#  'that that one night we had was fun and and certainly passionate but do not you think it is better if we just stayed friends',
#  'i just thought it would make me feel good to do something nice for my friend',
#  'you are amazing',
#  'this is amazing',
#  'a tv as if it appears from nowhere that is the dream',
#  'you are the best friend anyone has ever had',
#  'you are the best friend anyone has ever had',
#  'you do this you give me the great advice',
#  'you do this you give me the great advice',
#  'i was thinking about what you said yesterday about focusing on one woman i am gonna do that',
#  'you mean with casey',
#  'i think somebody got a little crush on casey',
#  'i think somebody got a little crush on casey',
#  'i fix you two up',
#  'i fix you two up',
#  'how bout i fix you two up',
#  'that all the pieces of my life are falling right into place',
#  'stop freaking out',
#  'stop freaking out',
#  'i am not freaking out',
#  'a woman named heldi called and said we were getting married but that happens everyday',
#  'i i i just put our names down for fun',
#  'i i i just put our names down for fun',
#  'what the harm in that',
#  'right here',
#  'what the harm in that',
#  'right here',
#  'please do not think i was trying to pressure you',
#  'so the people that knew about our wedding before me were you phoebe and rachel heldi and apparently some band called starlight magic seven who are available by the way',
#  'so the people that knew about our wedding before me were you phoebe and rachel heldi and apparently some band called starlight magic seven who are available by the way',
#  'it was a mistake please do not take this to mean anything because it does not',
#  'please do not take this to mean anything because it does not',
#  'okay',
#  'you are back',
#  'so did heldi show you the place',
#  'yeah it is beautiful',
#  'you are gonna ask monica to marry you',
#  'you are gonna ask monica to marry you',
#  'i am all done',
#  'remember the time i uh i pinned you down and tickled you til you cried',
#  'we are probably too old to do that now',
#  'i will always remember that summer because it is when i got all of these freckles',
#  'i will always remember that summer because that is when i realized that we are related',
#  'it took you that long to figure it out',
#  'i believe i read that somewhere',
#  'you put that on my alumni page',
#  'you put that on my alumni page',
#  'you put that on my alumni page',
#  'you put that on my alumni page',
#  'you put that on my alumni page',
#  'i can not believe you put that on my alumni page',
#  'you put that on my alumni page',
#  'you put that on my alumni page',
#  'you are friend getting married it is gotta change things',
#  'you really think it would be that different',
#  'you really think it would be that different',
#  'pretty soon they are gonna be having kids and then they are just gonna be hanging out with other couples who have kids',
#  'and then maybe they are gonna have to leave the city to be near a volvo dealership',
#  'pretty soon they are gonna be having kids and then they are just gonna be hanging out with other couples who have kids',
#  'and then maybe they are gonna have to leave the city to be near a volvo dealership',
#  'things change',
#  'maybe they are gonna have to leave the city to be near a volvo dealership',
#  'i do not want them to move to a volvo dealership',
#  'hey',
#  'hey',
#  'hi hey',
#  'do you guys know any cute guys',
#  'well of course i do my good friend joey over here',
#  'do you guys know any cute guys',
#  'well of course i do my good friend joey over here',
#  'does ralph mumble when you are not paying attention',
#  'yeah it is weird',
#  'hey',
#  'hey',
#  'hi pheebs',
#  'rachel can we talk for a sec',
#  'well sure just a sec though cause paolo on his way over',
#  'ok um ok um',
#  'i never tasted these before',
#  'these are the best oatmeal cookies i have ever had',
#  'these are the best oatmeal cookies i have ever had',
#  'paolo made a pass at me',
#  'i was just clearing some space for your stuff',
#  'she and chandler had a big fight and they are not moving in',
#  'they are not moving in',
#  'they are not moving in',
#  'they just had a big blowout over what to do with my room',
#  'i do not have to move in here',
#  'i do not have to move in here',
#  'that part great',
#  'did not you just light that',
#  'every sunday night i am telling myself i am quitting but every monday morning it is like',
#  'every sunday night i am telling myself i am quitting but every monday morning it is like',
#  'i have actually been thinking about quitting lately',
#  'every sunday night i am telling myself i am quitting',
#  'let just quit we will just quit let all quit',
#  'i never could do it',
#  'we can help each other out',
#  'we can help each other out',
#  'we could be like the patch sisters',
#  'let quit',
#  'we really should quit okay let quit',
#  'great',
#  'my late husband gave me that lighter',
#  'my late husband gave me that lighter i am not kidding',
#  'i i lost my health insurance',
#  'first thing we gotta do damage control',
#  'someone out there may have been bad mouthing you all over town',
#  'someone out there may have been bad mouthing you all over town',
#  'hey',
#  'do you guys wanna go see a movie',
#  'oh yeah why not',
#  'we are still married',
#  'we are still married',
#  'i did not get the annulment',
#  'we are still married',
#  'poor little tooty is scared to death',
#  'why do not we just put poor little tooty out in the hall',
#  'during a blackout he would get trampled',
#  'hey pheebs',
#  'hey pheebs',
#  'hey',
#  'how much of a man am i',
#  'nice manly and also kind of a slut',
#  'i got an audition to be the host of a new game show',
#  'me and him do stuff all the time without you',
#  'well umm',
#  'i am coming over and i am bringing chinese food',
#  'i am not hungry',
#  'i have been talking to you for five minutes now about killing myself and no one even looked up from their desk',
#  'i got nothing',
#  'it really creeps me out choosing other peoples sex clothes',
#  'it really creeps me out choosing other peoples sex clothes',
#  'this',
#  'this',
#  'this',
#  'i got my hair coloured',
#  'this',
#  'this',
#  'you are making him a frieze salad with goat cheese and pine nuts wild nuts wild rice roast asparagus and salmon au croup',
#  'you are making him a frieze salad with goat cheese and pine nuts wild nuts wild rice roast asparagus and salmon au croup',
#  'you are making him a frieze salad with goat cheese and pine nuts wild nuts wild rice roast asparagus and salmon au croup',
#  'i thought i was making him filet mignon',
#  'you bitched about it',
#  'if you bitched about it then you would stop cooking and you would have to make your famous baked potato and diet coke',
#  'i really get crabby when i cook',
#  'saying that your method was stupid',
#  'i can not talk to you',
#  'i wanna apologize for for saying that your method was stupid',
#  'you really think i am ready',
#  'you really think i am ready',
#  'uh huh',
#  'you really think i am ready',
#  'uh huh',
#  'cool',
#  'was the chord at least right before down',
#  'no',
#  'your friends do not really seem to care too much that you are leaving',
#  'this is uh good bye then',
#  'i guess this is uh good bye then',
#  'i missed you today',
#  'trying to turn me on by making a mess',
#  'tomorrow we are doing those fertility tests and until then you need to keep your tadpoles in the tank',
#  'i do not wanna do it in a cup',
#  'these little women',
#  'amy just burned jo manuscript',
#  'what do you mean this might be your only chance',
#  'what do you mean this might be your only chance',
#  'forcing her to marry bobby',
#  'this',
#  'this',
#  'we are straight up gangster rap',
#  'rachel told me how much easier you have made all this on her why can not you do that for me',
#  'rachel told me how much easier you have made all this on her why can not you do that for me',
#  'i can not stand the thought of having this baby with you mad at me',
#  'i can not stand the thought of having this baby with you mad at me',
#  'i can not stand the thought of having this baby with you mad at me',
#  'is my baby gonna have his uncle joey',
#  'is my baby gonna have his uncle joey',
#  'of course he is gonna have his uncle joey',
#  'we are gonna be all right i mean even if we are not married this baby is gonna be so loved not just by us',
#  'even if we are not married this baby is gonna be so loved not just by us',
#  'by his uncle too',
#  'even if we are not married this baby is gonna be so loved not just by us',
#  'and by you',
#  'we have got a bit of an emergency here jason costalano is choking on his retainer',
#  'we have got a bit of an emergency here jason costalano is choking on his retainer',
#  'please do not go anywhere',
#  'he was sweating when he walked out of there',
#  'i am pretty sure i am still gonna marry him',
#  'the guy is the devil he is satan in a smock',
#  'the guy is the devil he is satan in a smock',
#  'i still really wanna be mrs dr barry farber d d s',
#  'i am pretty sure i am still gonna marry him',
#  'the guy is the devil he is satan in a smock',
#  'i still really wanna be mrs dr barry farber d d s',
#  'oh god',
#  'i am pretty sure i am still gonna marry him',
#  'the guy is the devil he is satan in a smock',
#  'i still really wanna be mrs dr barry farber d d s',
#  'please do not pick your teeth out here',
#  'if you are gonna put your feet up why do not you sit on the',
#  'leave him alone',
#  'will you hurry up',
#  'you are whippin so slow can not you do it any faster',
#  'will you hurry up',
#  'you are whippin so slow can not you do it any faster',
#  'will you hurry up',
#  'you are whippin so slow can not you do it any faster',
#  'will you hurry up',
#  'you are whippin so slow can not you do it any faster',
#  'you are whippin so slow can not you do it any faster',
#  'you are whippin so slow can not you do it any faster',
#  'you are whippin so slow can not you do it any faster',
#  'this is the only dessert and if i screw it up everybody gonna be like oh remember that thanksgiving when rachel screwed up the trifle',
#  'you do not tell them',
#  'if you do not tell them then i will',
#  'what did you just say',
#  'you roll another hard eight and we get married here tonight',
#  'you roll another hard eight and we get married here tonight',
#  'i love you i have never loved anybody as much as i love you',
#  'you roll another hard eight and we get married here tonight',
#  'i love you i have never loved anybody as much as i love you',
#  'i have never loved anybody as much as i love you',
#  'i have never loved anybody as much as i love you',
#  'if an eight comes up we take it as a sign and we do it',
#  'if an eight comes up we take it as a sign and we do it',
#  'if an eight comes up we take it as a sign and we do it',
#  'what do you say',
#  'okay',
#  'that is a four and where where is the other one',
#  'where where is the other one',
#  'it went under the table',
#  'here it is here it is',
#  'that could be a four or a five it is your call',
#  'it is a four',
#  'i love driving',
#  'you do not have a valid drivers license',
#  'what what are you doing',
#  'i am porsching around',
#  'it is been fourteen and a half minutes and you still have not said one word',
#  'there you go',
#  'thank you so much for letting me stay here',
#  'i forgot my jacket',
#  'you are so cute how did you get to be so cute',
#  'you are so cute how did you get to be so cute',
#  'now you are even cuter',
#  'that is a popular opinion today i must say',
#  'phoebe was hitting on me',
#  'phoebe was hitting on me',
#  'phoebe thinks i am foxy',
#  'phoebe thinks i am foxy',
#  'i think phoebe thinks i am foxy',
#  'that is not possible',
#  'phoebe just always thought you were you were charming in a in a sexless kind of way',
#  'i i can not hear that enough',
#  'you just misunderstood her',
#  'i think that you just misunderstood her',
#  'she was all over me she touched my bicep for crying out loud',
#  'she touched my bicep for crying out loud',
#  'this bicep',
#  'you ordered a stripper for the shower that is totally inappropriate',
#  'that is totally inappropriate',
#  'hi',
#  'you could make it',
#  'you could make it',
#  'there is my little girl',
#  'she is still mad',
#  'is not it great one less person we have to make small talk with',
#  'sandra mad at you too it it does not bother you',
#  'this is unbelievable joey has been holding his breath for almost four minutes',
#  'what are yo you trying to kill me',
#  'westminster abbey',
#  'westminster abbey',
#  'they are thinking of changing the name of this place',
#  'put the camera away',
#  'was it my work were they mad was it jack did he yell',
#  'nobody yelled jack just was calling to make sure that you were getting better',
#  'this sounds like a hernia',
#  'this sounds like a hernia you have to you you go to the doctor',
#  'if i have to go to the doctor for anything it is gonna be for this thing sticking out of my stomach',
#  'why did i have to start working out again',
#  'why did i have to start working out again',
#  'santa coming',
#  'will the stable boy never get the princess',
#  'have sex with her right here on my couch',
#  'the leather sticks to my ass',
#  'this is not fair',
#  'what makes you think that i am just gonna sleep with her and then blow her off',
#  'what makes you think that i am just gonna sleep with her and then blow her off',
#  'what makes you think that i am just gonna sleep with her and then blow her off',
#  'what makes you think that i am just gonna sleep with her and then blow her off',
#  'can not you guys open your minds to the possibility that i actally like her and might want something real',
#  'i have not felt this way about anyone since rachel',
#  'i have not felt this way about anyone since rachel',
#  'i did not think i could ever love again',
#  'i did not think i could ever love again',
#  'hey guys this is tabatha',
#  'it is like my favorite fairy tale come true the princess the stable boy and the lesbian',
#  'i had a really nice time tonight',
#  'i had a really nice time tonight',
#  'monica asked us out',
#  'my sister visiting and i think she is asleep on the couch',
#  'you are sister asleep on the couch',
#  'hi',
#  'i wish you would told me we were having company i would fix myself up',
#  'i lied i did not want her to think i was a terrible mother i can not even see my own baby',
#  'it is beautiful i see it now',
#  'i do not see it',
#  'i saw that',
#  'i can not believe that is our baby',
#  'i am sorry about before',
#  'i am sorry too',
#  'i am sorry about before',
#  'we can think of something to do with the room together',
#  'we do not have to make that a guest room we can think of something to do with the room together',
#  'that is a great idea we can easily think of a way for us both to enjoy the room',
#  'what are you doing',
#  'a bee',
#  'a bee',
#  'it is flown into your blouse and you would better undo your buttons lest it sting you',
#  'you would better undo your buttons lest it sting you',
#  'i think i know what going on here',
#  'it is wrong',
#  'that is gonna leave a stain',
#  'it is fine you are at joey',
#  'it is fine',
#  'i have never lived like this before',
#  'i have never lived like this before',
#  'chandler is worse',
#  'i do not have any past life memories',
#  'i know monica worst thanksgiving',
#  'tell this story',
#  'let not tell this story',
#  'i know i know it is the one where joey got monica turkey stuck on his head',
#  'joey got monica turkey stuck on his head',
#  'joey got a turkey stuck on his head',
#  'you did not did not mention anything to issac right',
#  'i tell issac everything',
#  'you dog',
#  'monogamy is too cruel a rule',
#  'we are the same you and me',
#  'we are the same you and me',
#  'we are the same you and me',
#  'we are the same you and me',
#  'she is directing the new al pacino movie you gotta get me an audition',
#  'i have not talked to her in like ten years',
#  'how was your audition',
#  'i am gonna be a big movie star',
#  'i am gonna be a big movie star',
#  'you got it',
#  'the audition went really good',
#  'the audition went really good',
#  'it is really classy',
#  'it is really classy',
#  'the director is supposed to be the next next martin scorcese',
#  'the director is supposed to be the next next martin scorcese',
#  'hello',
#  'they loved me',
#  'they want me to be totally naked in the movie',
#  'they want me to be totally naked in the movie',
#  'they want me to be totally naked in the movie',
#  'my grandmother gonna see this',
#  'ross wait',
#  'you suck',
#  'you suck',
#  'i lost',
#  'i lost',
#  'some little girl loaned her uniform to her nineteen year old sister who went down to the u s s',
#  'nimitz and sold over two zero zero zero boxes',
#  'hey',
#  'i blew it',
#  'i blew it',
#  'that is not how that was supposed to come out',
#  'i lost',
#  'i blew it',
#  'this is the worst christmas ever',
#  'maybe you should just you know stay here at the coffee house',
#  'it is too late',
#  'terry already hired that girl over there',
#  'terry already hired that girl over there',
#  'she is even got waitress experience',
#  'terry already hired that girl over there',
#  'she is even got waitress experience',
#  'last night she was teaching everybody how to make napkin swans',
#  'he forgot to leave his grip size',
#  'he did not get the goggles',
#  'they wait for me to do this',
#  'what are you guys doing here',
#  'he is not even wearing a jockstrap',
#  'that would be a shutdown',
#  'yes and that would be a shutdown',
#  'where are you guys going',
#  'come on one more game',
#  'it is two three zero in the morning',
#  'come on one more game',
#  'it is two three zero in the morning',
#  'get out',
#  'you guys are always hanging out in my apartment',
#  'one more game',
#  'oh yeah',
#  'he says that walking with you makes this strange city feel like home',
#  'your eyes are very pretty',
#  'your eyes are very pretty',
#  'he is only had sex with one woman',
#  'he is only had sex with one woman',
#  'i think it is great you know it is sweet it is romantic',
#  'i think it is great you know it is sweet it is romantic',
#  'he is only had sex with one woman',
#  'the guy a freak',
#  'that is attractive',
#  'i thought you were great in silence of the lambs',
#  'all things considered you had fun tonight',
#  'all things considered you had fun tonight',
#  'where is my puck',
#  'the kid has it',
#  'that is my puck',
#  'i found it finders keepers losers weepers',
#  'gimme back my puck',
#  'no',
#  'no rough holding in my er',
#  'gimme back my puck',
#  'no',
#  'now that was fun',
#  'what we did was wrong oh god i just had sex with somebody that was not alive during the bicentennial',
#  'i just had sex',
#  'you not tell me',
#  'you never told me how old you were',
#  'how could you not tell me',
#  'you never told me how old you were',
#  'my lie did not make one of us a felon in four eight states',
#  'how could you not tell me',
#  'my lie did not make one of us a felon in four eight states',
#  'how could you not tell me',
#  'my lie did not make one of us a felon in four eight states',
#  'what were you thinking',
#  'i was not thinking i was too busy falling',
#  'say it',
#  'i was too busy falling',
#  'in love with you',
#  'how could you not tell me',
#  'my lie did not make one of us a felon in four eight states',
#  'what were you thinking',
#  'i just had sex with somebody that was not alive during the bicentennial',
#  'how could you not tell me',
#  'i just had sex with somebody that was not alive during the bicentennial',
#  'how could you not tell me',
#  'you should not even be here it is a school night',
#  'i just had sex with somebody that was not alive during the bicentennial',
#  'i am like those women that you see with shiny guys named chad',
#  'i just had sex with somebody that was not alive during the bicentennial',
#  'i am like those women that you see with shiny guys named chad',
#  'i do not wanna die',
#  'i do not wanna die',
#  'it will be fun we can come back and we can haunt these guys',
#  'check out the ring',
#  'check out the ring',
#  'nice one and a half carat easy',
#  'hi',
#  'chandler gonna ask monica to marry him',
#  'chandler gonna ask monica to marry him',
#  'chandler gonna ask monica to marry him',
#  'i know i helped pick out the ring',
#  'you told her before you told us',
#  'you have a fear of commitment so i say you go in there and be the most committed guy there ever was',
#  'that makes sense',
#  'you have a fear of commitment so i say you go in there and be the most committed guy there ever was',
#  'that makes sense',
#  'go for it man jump off the high dive stare down the barrel of the gun pee into the wind',
#  'stare down the barrel of the gun pee into the wind',
#  'if i am staring down the barrel of a gun i am pretty much peeing every which way',
#  'i do not know what i am going to do',
#  'i called the company that sent and th they do not care',
#  'then i called nine one one and they laughed at me',
#  'i called the company that sent and th they do not care',
#  'then i called nine one one and they laughed at me',
#  'hey guys',
#  'hey guys',
#  'hey',
#  'what a great party',
#  'the guys from work had a blast',
#  'what a great party',
#  'the guys from work had a blast',
#  'one of them had never been to a bachelor party before',
#  'and and another one had never been to a party before',
#  'that wedding ring huh man that is nice',
#  'that wedding ring huh man that is nice',
#  'i was thinking i might want to pick one of those babies up for myself i might want to get one of those',
#  'the ring is irreplaceable',
#  'every bride who has worn it has had a long and happy life',
#  'every bride who has worn it has had a long and happy life',
#  'it is a magic ring',
#  'you you you had sex with ursula',
#  'you you you had sex with ursula',
#  'i thought she was you and i kissed her and',
#  'you you you had sex with ursula',
#  'i thought she was you and i kissed her and',
#  'you did not notice she was wearing different clothes',
#  'you you you had sex with ursula',
#  'a little bit',
#  'you you you had sex with ursula',
#  'a little bit',
#  'this is too weird',
#  'this is too weird',
#  'i do not want to lose you',
#  'i was making love to her and i thought she was you yeah it is too weird',
#  'i was making love to her and i thought she was you yeah it is too weird',
#  'so i guess this is it',
#  'so i guess this is it',
#  'it just would not have been feasible',
#  'it just would not have been feasible',
#  'having a dove place the ring on your finger would have been no problem',
#  'it was really fun being married to you tonight',
#  'it was really fun being married to you tonight',
#  'it was the easiest four zero zero bucks i have ever made',
#  'it was stupid',
#  'it was stupid',
#  'with the with the lilies and and the song and the stars',
#  'with the with the lilies and and the song and the stars',
#  'it was really wonderful',
#  'did you just make that up',
#  'your breasts',
#  'you are coming on a little strong',
#  'i write erotic novels for children',
#  'i write erotic novels for children',
#  'i have a ph d',
#  'whazzup',
#  'whazzup',
#  'can you just keep an eye on joey make sure nothing happens between him and molly',
#  'you do not trust him',
#  ...]

# %%
# pred_labels = [x['answer'] if len(x['answer'].split()) != 1 else 'null' for x in predictions]
# pred_labels = [x['answer'] if len(x['answer'].split()) != 1 else '' for x in predictions]
pred_labels = [x['answer'] for x in predictions]
pred_labels
# Out:
# ['hey',
#  'that is the stuff',
#  'you have embarrassed me enough for one day',
#  'you have embarrassed me enough for one day',
#  'i embarrass you',
#  'you insist on wearing that in public',
#  'if you insist on wearing that in public',
#  'you are gonna make me choose between you and the hat i choose the hat',
#  'you are gonna make me choose between you and the hat i choose the hat',
#  'how about you are moving',
#  'great monica moving',
#  'monica moving',
#  'how come all your stuff is in this box',
#  'hey',
#  'hey',
#  'hey',
#  'you are the next caller',
#  'you were the next caller five hours ago you must be going crazy',
#  'what going on',
#  'she broke my arm',
#  'he touched my fanny',
#  'she touched mine first',
#  'he touched my fanny',
#  'she touched mine first',
#  'this girl is good',
#  'this girl is good',
#  'look at you all jealous',
#  'everyone else is happy she is done',
#  'my next song called phoebe buffay what can i say',
#  'i should not have left you that way',
#  'no one of those look for the hidden meaning songs',
#  'i invented the game of cups as a way to give joey money',
#  'now you want that money back',
#  'i invented the game of cups as a way to give joey money',
#  'now you want that money back',
#  'exactly',
#  'what kind of an idiot',
#  'what kind of an idiot do you take me for',
#  'now you want that money back',
#  'exactly',
#  'you lost your money but i won it fair and square',
#  'here is a picture of scotty jared naked',
#  'here is a picture of scotty jared naked',
#  'he is wearing a sweater',
#  'there is such a thing as too many women',
#  'did did did i wake you',
#  'this is so nice',
#  'look at the little cat',
#  'look at the little cat',
#  'look at the little cat',
#  'did you see my new china cabinet',
#  'my father house does that',
#  'how did it go tell me everything',
#  'let do it',
#  'what was that',
#  'i thought you were in your room',
#  'i am picking you up for our date these are for you',
#  'they are my favorite',
#  'this is so great',
#  'this is so great',
#  'this is so great',
#  'i actually feel like i am going on a real date',
#  'a subscription to playboy my kind of woman',
#  'this roommate of yours is he good looking',
#  'hm mmm',
#  'i am pretty sure he is gay',
#  'why are you trying to ruin the game',
#  'what are you doing here',
#  'i i came to fill your ice cube trays',
#  'my father is chuck magioni',
#  'my father is chuck magioni',
#  'i i sold him a house last year',
#  'i do not know where your father is and that is the truth',
#  'i do not know where your father is and that is the truth',
#  'i am your mother',
#  'i kinda felt all floopy and',
#  'i think i should date her',
#  'this can go on for a while',
#  'see who she likes best',
#  'that sounds fair',
#  'maybe i will take her to that new french restaurant down the street',
#  'maybe i will take her to that new french restaurant down the street',
#  'maybe i will take her to that new french restaurant down the street',
#  'i do not have the money to take her to a fancy place like that',
#  'you really feel about it',
#  'i lied before',
#  'now you know how you really feel about it',
#  'that is a risky little game',
#  'are you really gonna do this',
#  'i am gonna have a baby i am gonna have a baby',
#  'i am gonna have a baby',
#  'it is still not the time',
#  'chandler gone again',
#  'chandler gone again',
#  'why would you play hide and seek with someone you know is a flight risk',
#  'it is time we we had a conversation about about where things are with us',
#  'i i think i suggested that',
#  'i i love umm you know hanging out with you',
#  'i i love umm you know hanging out with you',
#  'it is going somewhere fun',
#  'the doctor let me feel it myself',
#  'it is getting real late now',
#  'did you know this is not ma',
#  'this is not',
#  'how long you been',
#  'ships',
#  'since then',
#  'you are one to talk',
#  'joe your dad in love',
#  'it is with two different women',
#  'please tell me one of them is ma',
#  'looks good',
#  'you guys are selling the entertainment center',
#  'you guys are selling the entertainment center',
#  'you want it',
#  'oh no',
#  'five zero zero zero dollars are you insane',
#  'the ad alone cost three zero zero bucks',
#  'i am changing it to five zero bucks or your best offer',
#  'what kind of profit is that and you call yourself an accountant',
#  'what kind of profit is that and you call yourself an accountant',
#  'nooo',
#  'what kind of profit is that and you call yourself an accountant',
#  'nooo',
#  'we were so angry at each other was because there are still feelings there',
#  'we are gonna give it another try',
#  'what about her whining and her constant need for attention',
#  'you are so capable of change',
#  'we are gonna give it another try',
#  'he hums when he pees',
#  'he hums when he pees',
#  'it makes him miss the bowl but whatever',
#  'we are gonna give it another try',
#  'we are gonna give it another try',
#  'even if they break up again',
#  'you are so efficient',
#  'let go',
#  'we need something old',
#  'we need something old',
#  'i have condom in my wallet i have had since i was twelve',
#  'that will work',
#  'we just need something borrowed',
#  'we just need something borrowed',
#  'here just take this',
#  'that is stealing',
#  'it is brilliant',
#  'goodbye mike we will see you at the wedding fella',
#  'you are welcome glad i could help',
#  'i especially would not want you to think i was gay',
#  'i should have considered your feelings before i went home with you that night',
#  'i should have considered your feelings before i went home with you that night',
#  'i have recently learned what it like to be on your side of it',
#  'i should have considered your feelings before i went home with you that night',
#  'i have recently learned what it like to be on your side of it',
#  'mrs loreo is jennifer there',
#  'she is not home',
#  'all hers is is is growing new stuff',
#  'all',
#  'you guys love me more than you love her',
#  'her think you guys love me more than you love her',
#  'does she really thinks that',
#  'all hers is is is growing new stuff',
#  'you guys love me more than you love her',
#  'the doctor said your mother could',
#  'i do not want to hear about it',
#  'i do not want to hear about it',
#  'all hers is is is growing new stuff',
#  'i am trying to win her over',
#  'hey',
#  'manhattan does not have enough stores',
#  'i think i can help you get over him',
#  'we are here',
#  'where have you been',
#  'it is ross and that girl',
#  'it is a line of ants they are working as a team',
#  'it looks like ross is breaking up with her',
#  'it looks like ross is breaking up with her',
#  'phoebe look at that',
#  'that is a that is a second date',
#  'she just put her hand on his thigh',
#  'this is all your fault now he loves her he is gonna marry her',
#  'thank the jerk that never showed up',
#  'whew stood up too fast',
#  'do you wanna come in for some lemonade',
#  'this is a great place',
#  'what time is it',
#  'i am really getting tired of sneaking around',
#  'if we went away for a whole weekend',
#  'we would have no interruptions and we could be naked the entire time',
#  'if we went away for a whole weekend',
#  'we could be naked the entire time',
#  'you have a chef thing',
#  'i have always wanted to go to this culinary fair that they have in jersey',
#  'the woman that i have dumped twice in the last five months',
#  'i am making a break for it i am going out the window',
#  'the woman that i have dumped twice in the last five months',
#  'you are making me nervous',
#  'the woman that i have dumped twice in the last five months',
#  'you are making me nervous and i can not go when i am nervous',
#  'how do you know how to do that',
#  'i am getting my revenge',
#  'you cooked him',
#  'restaurant reviewer admits i was wrong about monica',
#  'restaurant reviewer admits i was wrong about monica',
#  'i cannot wait to read the front page of the post tomorrow',
#  'restaurant reviewer admits i was wrong about monica',
#  'you are gonna stay with me as long as i need you',
#  'of course i am',
#  'the baby coming and i do not know what to do',
#  'the baby coming and i do not know what to do',
#  'you are gonna be fine',
#  'where are you going where are you going',
#  'hey',
#  'why are you all red and sweaty',
#  'i just bamboozled chandler',
#  'a number of prototypes for you to try on',
#  'this looks great',
#  'this looks great',
#  'this one is made of bologna',
#  'and and and and and the toothpicks',
#  'who this little naked guy',
#  'that little naked guy would be me',
#  'look at the little thing',
#  'who are those people',
#  'who are those people',
#  'got me',
#  'you look just like your grandmother how old was she there',
#  'look look look look look i got monica naked',
#  'i have got some ones you wanna put them in her panties',
#  'i have got some ones you wanna put them in her panties',
#  'very good so good',
#  'i really really enjoyed it very exotic',
#  'i just checked our messages and joshua did not call',
#  'i just checked our messages and joshua did not call',
#  'i just checked our messages and joshua did not call',
#  'what makes it so much worse ross is all happy in vermont',
#  'i think i am just gonna go home and call kathy',
#  'if you think it will help',
#  'i think i am just gonna go home and call kathy',
#  'if you think it will help',
#  'in a couple of hours',
#  'after that i am gonna get so drunk',
#  'kathy and you guys are gonna have to stop me',
#  'after that i am gonna get so drunk',
#  'after that i am gonna get so drunk i am gonna wanna call janice',
#  'i am gonna wanna call janice',
#  'you should how is she',
#  'i think somebody needs another lap dance',
#  'it is just so realistic',
#  'pat the dog',
#  'do you ready for a refill',
#  'it is like it is raining',
#  'it is like it is raining',
#  'pretty cool',
#  'i would be peeing in joey tribbiani apartment',
#  'apartment',
#  'good job joe well done top notch',
#  'good job joe well done top notch',
#  'you liked it you really liked it',
#  'you liked it you really liked it',
#  'oh ho ho yeah',
#  'you liked it you really liked it',
#  'oh ho ho yeah',
#  'i love the specifics the specifics were the best part',
#  'did you like that part',
#  'did you like that part',
#  'i was surprised to see a kangaroo in a world war i epic',
#  'you fell asleep',
#  'you fell asleep',
#  'you fell asleep',
#  'they did not take any of my suggestions',
#  'you fell asleep',
#  'this guy fell asleep he fell asleep too be mad at him',
#  'it is joey',
#  'hey pheebs it is joey',
#  'hey joey',
#  'i just saw someone on the that looks just like you on the subway',
#  'i just saw someone on the that looks just like you on the subway',
#  'i just saw someone on the that looks just like you on the subway',
#  'i just saw someone on the that looks just like you on the subway',
#  'they are having a great time with their aunt phoebe',
#  'i have just been having way too much fun',
#  'i have just been having way too much fun',
#  'so you are not homesick yet',
#  'how long we threw that ball around',
#  'did i get this reputation as a dropper',
#  'does anyone know where the freeman building is',
#  'it is the new building on avenue a',
#  'i am supposed to teach a graduate seminar there in ten minutes',
#  'move it move it move it hey i am the teacher',
#  'i am entitled to use my angel pass for a free turn',
#  'this game makes no sense',
#  'this game makes no sense',
#  'you are just upset because you are losing',
#  'you are just upset because you are losing',
#  'i think we are all losers here',
#  'this game makes no sense',
#  'either it makes no difference',
#  'you picked the gimmie card you get all of ross points',
#  'you picked the gimmie card you get all of ross points',
#  'you picked the gimmie card you get all of ross points',
#  'this game is kinda fun',
#  'you picked the gimmie card you get all of ross points',
#  'you get all my points just cause you',
#  'i did not get it',
#  'the off broadway play people said you were pretty but dumb',
#  'i would just use my son as as an excuse',
#  'do you think i would just use my son as as an excuse',
#  'i am just done with the whole dating thing',
#  'i am just done with the whole dating thing',
#  'i am just done with the whole dating thing',
#  'this is hard',
#  'you owe me two zero bucks',
#  'your grilled cheese fixin and your family size bag of funyuns',
#  'this is what you are havin for thanksgiving dinner',
#  'this is what you are havin for thanksgiving dinner',
#  'i hate this story',
#  'this is the moment my parents choose to tell me they are getting divorced',
#  'they are getting divorced',
#  'they are getting divorced',
#  'a thanksgiving dinner once you have seen it in reverse',
#  'you did not you said you would but you never did',
#  'i thought we said seven',
#  'let skip it',
#  'you and your sister seem to have umm a very special bond',
#  'that special bond again',
#  'if i am close to my family',
#  'i can not figure this out',
#  'it is so hard',
#  'it is so hard',
#  'paper cut',
#  'you told me',
#  'you walked in on me when i was looking at ring brochures',
#  'not knocking pays off',
#  'we were just gonna see if you wanted to go',
#  'we do not because we got the other pl place',
#  'how rude',
#  'how rude',
#  'you wanna bite',
#  'people please make some room',
#  'you like you have not done enough',
#  'i have never been so uncomfortable in my entire life',
#  'oh my gosh joshua',
#  'i do not think we should go out anymore',
#  'i do not think we should go out anymore',
#  'i do not think we should go out anymore',
#  'how could you pick up a hitchhiker',
#  'do not you think i asked him that before he got in',
#  'he could be a rape a rapist or a killer or something',
#  'you go back to sleep and you are you a rapist',
#  'the license plate game',
#  'i love the license plate game',
#  'i will play i will play',
#  'you need your sleep night night',
#  'that mail guy had no idea there was something going on between us',
#  'that mail guy had no idea there was something going on between us',
#  'i love doing crossword puzzles with you',
#  'i love doing crossword puzzles with you honey',
#  'let finish this and go to bed',
#  'you are so smart i love you',
#  'i love you',
#  'i love you too',
#  'i feel so stupid',
#  'i feel so stupid',
#  'i am so embarrassed',
#  'if i had never met him this never would have happened',
#  'i am so embarrassed',
#  'i am so embarrassed',
#  'if i had never met him this never would have happened',
#  'if i had never met him this never would have happened',
#  'no i am sorry',
#  'what are we sorry about',
#  'he is the pig',
#  'i do not know right he is the pig',
#  'such a pig',
#  'he is the pig',
#  'such a pig',
#  'he is such a pig',
#  'he is the pig',
#  'such a pig',
#  'he is such a pig',
#  'he is the pig',
#  'such a pig',
#  'he is such a pig',
#  'he is like a big disgusting pig pig man',
#  'he is like a big disgusting pig pig man',
#  'go to the bank close our accounts and cut them off at the source',
#  'we could go to the bank close our accounts and cut them off',
#  'you are a genius',
#  'now we will not be bank buddies',
#  'hey',
#  'hey',
#  'i bit him',
#  'i bit him',
#  'on the touchy',
#  'and thats not against your oath',
#  'and thats not against your oath',
#  'throw out my old oath and take a new dirty one',
#  'next time your massaging him you should try and distract yourself',
#  'guess which job i got',
#  'donald trump wants his blue blazer black',
#  'donald trump wants his blue blazer black',
#  'you you said black why would he want his blue blazer black',
#  'you messed it up you are stupid',
#  'what job did you get joe',
#  'ross got it for me',
#  'what job did you get joe',
#  'ross got it for me',
#  'how can you be a tour guide',
#  'why have you been following me',
#  'everywhere i look there is you',
#  'why have you been following me',
#  'all week long everywhere i look there is you',
#  'you would not return my calls you sent back my letters',
#  'why have you been following me',
#  'you would not return my calls you sent back my letters',
#  'you would not return my calls you sent back my letters',
#  'she comes in early to eat her breakfast at her desk',
#  'that is kinda sad',
#  'while i distract her you get in the office',
#  'you know where i work',
#  'you still work at the multiplex',
#  'i would give up that job free popcorn and candy',
#  'betting the apartment i do not know about this',
#  'i have not missed one question the whole game i own this game',
#  'why do you have the answers written on there',
#  'monica betting the apartment i do not know about this',
#  'mr geller is mentally unstable',
#  'i am mentally unstable',
#  'based on the fact that mr geller is intravenous drug user',
#  'based on the fact that mr geller is intravenous drug user',
#  'heroin and crack',
#  'now it also says here that you lied about your sexual preference before marriage',
#  'here that you lied about your sexual preference before marriage',
#  'i thought it was gonna be a closed casket',
#  'she can not look nice',
#  'i am moving out like we talked about',
#  'help me to grow or whatever',
#  'you wanna go in the bedroom it is a little more comfortable',
#  'you wanna go in the bedroom it is a little more comfortable',
#  'you wanna go in the bedroom it is a little more comfortable',
#  'sure',
#  'did you send those contracts to milan',
#  'if this is your idea of sexy talk',
#  'this is just one of your jokes that you do that',
#  'like the thing when you put the phone in your pants',
#  'i am serious',
#  'this is not funny',
#  'i am serious',
#  'this is not funny',
#  'i am serious',
#  'this is not funny',
#  'those contracts absolutely had to go out today',
#  'you did not give me any contracts',
#  'you did not give me any contracts',
#  'i didnt want to seem too bossy',
#  'you never gave them to me',
#  'those contracts sitting on your desk',
#  'you never gave them to me',
#  'those contracts sitting on your desk',
#  'i would see you looking embarrassed because they are not on my desk',
#  'i would see you looking embarrassed because they are not on my desk',
#  'you are talking on the phone with your crotch',
#  'when did you unhook this nice work',
#  'now everybody wants to be under this hat',
#  'what with all this sand',
#  'hi',
#  'i know why you are here',
#  'that is been one heck of a see saw has not it',
#  'look that that one night we had was fun and and certainly passionate',
#  'do not you think it is better if we just stayed friends',
#  'do something nice for my friend',
#  'you are amazing',
#  'this is amazing',
#  'how did you afford this stuff',
#  'you are the best friend anyone has ever had',
#  'you are the best friend anyone has ever had',
#  'you said yesterday about focusing on one woman i am gonna do that',
#  'you do this you give me the great advice',
#  'you said yesterday about focusing on one woman i am gonna do that',
#  'you mean with casey',
#  'i think somebody got a little crush on casey',
#  'i think somebody got a little crush on casey',
#  'how bout i fix you two up',
#  'how bout i fix you two up',
#  'how bout i fix you two up',
#  'that all the pieces of my life are falling right into place',
#  'stop freaking out',
#  'stop freaking out',
#  'i am not freaking out',
#  'a woman named heldi called',
#  'we were at this beautiful place',
#  'i i i just put our names down for fun',
#  'what the harm in that',
#  'right here',
#  'what the harm in that',
#  'right here',
#  'please do not think i was trying to pressure you phoebe and rachel',
#  'some band called starlight magic seven who are available by the way',
#  'the people that knew about our wedding before me',
#  'it was a mistake',
#  'please do not take this to mean anything because it does not',
#  'okay',
#  'i am gonna go tell joey that that you are back',
#  'did heldi show you the place',
#  'it is beautiful',
#  'you are gonna ask monica to marry you',
#  'you are gonna ask monica to marry you',
#  'i am all done',
#  'remember the time',
#  'we are probably too old to do that',
#  'when i got all of these freckles',
#  'that is when i realized that we are related',
#  'it took you that long to figure it out',
#  'i read that somewhere',
#  'you put that on my alumni page',
#  'you put that on my alumni page',
#  'you put that on my alumni page',
#  'you put that on my alumni page',
#  'you put that on my alumni page',
#  'you put that on my alumni page',
#  'you put that on my alumni page',
#  'you put that on my alumni page',
#  'you are friend getting married it is gotta change things',
#  'you really think it would be that different',
#  'you really think it would be that different',
#  'they are just gonna be hanging out with other couples who have kids',
#  'leave the city to be near a volvo dealership',
#  'and then they are just gonna be hanging out with other couples who have kids',
#  'they are gonna have to leave the city to be near a volvo dealership',
#  'things change',
#  'leave the city to be near a volvo dealership',
#  'i do not want them to move to a volvo dealership',
#  'hey',
#  'hey',
#  'hi hey',
#  'do you guys know any cute guys',
#  'i do my good friend joey over here',
#  'do you guys know any cute guys',
#  'i do my good friend joey over here',
#  'does ralph mumble when you are not paying attention',
#  'the thing is need to find a date',
#  'hey',
#  'hey',
#  'hi pheebs',
#  'can we talk for a sec',
#  'cause paolo on his way over',
#  'oh ok um ok um',
#  'why have i never tasted these before',
#  'these are the best oatmeal cookies i have ever had',
#  'these are the best oatmeal cookies i have ever had',
#  'paolo made a pass at me',
#  'i was just clearing some space for your stuff',
#  'she and chandler had a big fight and they are not moving in',
#  'she and chandler had a big fight and they are not moving in',
#  'they are not moving in',
#  'they just had a big blowout over what to do with my room',
#  'i am also really psyched cause i do not have to move in here',
#  'i am also really psyched cause i do not have to move in here',
#  'that part great',
#  'did not you just light that',
#  'every monday morning it is like',
#  'every monday morning it is like',
#  'i have actually been thinking about quitting lately',
#  'every monday morning it is like',
#  'we will just quit',
#  'i never could do it',
#  'we can help each other out',
#  'we can help each other out',
#  'we could be like the patch sisters',
#  'we really should quit',
#  'we really should quit okay let quit',
#  'give me those cigs give it give it',
#  'my late husband gave me that lighter',
#  'my late husband gave me that lighter i am not kidding',
#  'you gotta get me some work i i lost my health insurance',
#  'first thing we gotta do damage control',
#  'someone out there may have been bad mouthing you all over town',
#  'someone out there may have been bad mouthing you all over town',
#  'hey',
#  'do you guys wanna go see a movie',
#  'oh yeah why not',
#  'we are still married do not tell rachel see you later',
#  'we are still married do not tell rachel see you later',
#  'i did not get the annulment',
#  'we are still married',
#  'poor little tooty is scared to death we should find his owner',
#  'why do not we just put poor little tooty out in the hall',
#  'during a blackout he would get trampled',
#  'hey pheebs',
#  'hey pheebs',
#  'hey',
#  'how much of a man am i',
#  'nice manly and also kind of a slut',
#  'i got an audition to be the host of a new game show',
#  'do stuff all the time without you and you do not get all upset',
#  'yeah well umm',
#  'i am coming over and i am bringing chinese food',
#  'i am not hungry',
#  'i have been talking to you for five minutes now about killing myself',
#  'i got nothing',
#  'it really creeps me out choosing other peoples sex clothes',
#  'it really creeps me out choosing other peoples sex clothes',
#  'i have been waiting for this for months',
#  'i have been waiting for this for months',
#  'i have been waiting for this for months',
#  'i got my hair coloured',
#  'i have been waiting for this for months',
#  'i have been waiting for this for months',
#  'wild rice roast asparagus and salmon au croup',
#  'wild rice roast asparagus and salmon au croup',
#  'wild rice roast asparagus and salmon au croup',
#  'i thought i was making him filet mignon',
#  'you would have to make your famous baked potato and diet coke',
#  'you would have to make your famous baked potato and diet coke',
#  'i really get crabby when i cook',
#  'your method was stupid and and maybe ask you to be my teacher again',
#  'i do not have a fancy ad in the yellow pages',
#  'your method was stupid and and maybe ask you to be my teacher again',
#  'you really think i am ready',
#  'you really think i am ready',
#  'uh huh',
#  'you really think i am ready',
#  'uh huh',
#  'wow cool',
#  'was the chord at least right before down',
#  'no',
#  'your friends do not really seem to care too much that you are leaving',
#  'we are not really that close',
#  'we are not really that close',
#  'i missed you today',
#  'trying to turn me on by making a mess',
#  'tomorrow we are doing those fertility tests',
#  'i do not wanna do it in a cup',
#  'these little women',
#  'amy just burned jo manuscript i do not see how he could ever forgive her',
#  'this might be your only chance',
#  'this might be your only chance',
#  'forcing her to marry bobby is gonna make that happen',
#  'i am scared to death about this',
#  'i am scared to death about this',
#  'we are straight up gangster rap',
#  'how much easier you have made all this on her',
#  'why can not you do that for me',
#  'i can not stand the thought of having this baby with you mad at me',
#  'i can not stand the thought of having this baby with you mad at me',
#  'i can not stand the thought of having this baby with you mad at me',
#  'is my baby gonna have his uncle joey',
#  'is my baby gonna have his uncle joey',
#  'he is gonna have his uncle joey',
#  'this baby is gonna be so loved not just by us',
#  'this baby is gonna be so loved not just by us',
#  'that is right by his uncle too',
#  'even if we are not married this baby is gonna be so loved',
#  'and by you',
#  'jason costalano is choking on his retainer',
#  'jason costalano is choking on his retainer',
#  'please do not go anywhere',
#  'did you see how he was sweating when he walked out of there',
#  'i am pretty sure i am still gonna marry him',
#  'mindy the guy is the devil he is satan in a smock',
#  'mindy the guy is the devil he is satan in a smock',
#  'i still really wanna be mrs dr barry farber d d s',
#  'i am pretty sure i am still gonna marry him',
#  'mindy the guy is the devil he is satan in a smock',
#  'i still really wanna be mrs dr barry farber d d s',
#  'oh god',
#  'i am pretty sure i am still gonna marry him',
#  'mindy the guy is the devil he is satan in a smock',
#  'mrs dr barry farber d d s',
#  'please do not pick your teeth out here',
#  'if you are gonna put your feet up why do not you sit on the',
#  'leave him alone',
#  'will you hurry up',
#  'you are whippin so slow can not you do it any faster',
#  'will you hurry up',
#  'you are whippin so slow can not you do it any faster',
#  'will you hurry up',
#  'can not you do it any faster',
#  'will you hurry up',
#  'you are whippin so slow',
#  'you are whippin so slow can not you do it any faster',
#  'you are whippin so slow can not you do it any faster',
#  'you are whippin so slow can not you do it any faster',
#  'remember that thanksgiving when rachel screwed up the trifle',
#  'if you do not tell them then i will',
#  'if you do not tell them then i will',
#  'what did you just say',
#  'you roll another hard eight and we get married here tonight',
#  'you roll another hard eight and we get married here tonight',
#  'i love you i have never loved anybody as much as i love you',
#  'you roll another hard eight and we get married here tonight',
#  'i have never loved anybody as much as i love you',
#  'i have never loved anybody as much as i love you',
#  'i have never loved anybody as much as i love you',
#  'if an eight comes up we take it as a sign and we do it',
#  'if an eight comes up we take it as a sign and we do it',
#  'if an eight comes up we take it as a sign and we do it',
#  'what do you say',
#  'okay',
#  'that is a four and where where is the other one',
#  'that is a four and where where is the other one',
#  'it went under the table',
#  'here it is here it is',
#  'that could be a four or a five it is your call',
#  'it is a four',
#  'i forgot how much i love driving i have got to get my license renewed',
#  'you do not have a valid drivers license',
#  'what what are you doing are you okay that is not funny',
#  'i am not horsing around okay i am porsching around',
#  'do something just make contact smile',
#  'there you go',
#  'thank you so much for letting me stay here',
#  'i forgot my jacket',
#  'you are so cute how did you get to be so cute',
#  'you are so cute how did you get to be so cute',
#  'now you are even cuter',
#  'that is a popular opinion today',
#  'i think phoebe was hitting on me',
#  'i think i think phoebe was hitting on me',
#  'i think phoebe thinks i am foxy',
#  'i think phoebe thinks i am foxy',
#  'i think phoebe thinks i am foxy',
#  'that is not possible',
#  'phoebe just always thought you were you were charming in a in a sexless',
#  'i can not hear that enough',
#  'you just misunderstood her',
#  'you just misunderstood her',
#  'she was all over me she touched my bicep for crying out loud',
#  'she was all over me she touched my bicep for crying out loud',
#  'this bicep',
#  'you ordered a stripper for the shower that is totally inappropriate',
#  'you ordered a stripper for the shower that is totally inappropriate',
#  'hi',
#  'you could make it',
#  'i am so glad you could make it',
#  'there is my little girl',
#  'she is still mad',
#  'is not it great one less person we have to make small talk with',
#  'it does not bother you',
#  'this is unbelievable joey has been holding his breath for almost four minutes',
#  'what are yo you trying to kill me',
#  'westminster abbey',
#  'westminster abbey',
#  'they are thinking of changing the name of this place',
#  'to put the camera away',
#  'was it my work were they mad was it jack did he yell',
#  'nobody yelled jack just was calling to make sure that you were getting better',
#  'this sounds like a hernia',
#  'this sounds like a hernia you have to you you go to the doctor',
#  'this thing sticking out of my stomach',
#  'why did i have to start working out again',
#  'why did i have to start working out again',
#  'yes santa coming',
#  'will the stable boy never get the princess',
#  'you are gonna do have sex with her right here on my couch',
#  'the leather sticks to my ass',
#  'this is not fair',
#  'i am just gonna sleep with her and then blow her off',
#  'what makes you think that',
#  'i am just gonna sleep with her and then blow her off',
#  'you think that i am just gonna sleep with her and then blow her off',
#  'i actally like her and might want something real',
#  'i have not felt this way about anyone since',
#  'i have not felt this way about anyone since rachel ok',
#  'i did not think i could ever love again',
#  'i did not think i could ever love again',
#  'i will see you tomorrow',
#  'it is like my favorite fairy tale',
#  'i had a really nice time tonight',
#  'i had a really nice time tonight',
#  'monica asked us out',
#  'my sister visiting and i think she is asleep on the couch',
#  'now she is asleep on the couch',
#  'hi',
#  'i wish you would told me we were having company i would fix myself up',
#  'i did not want her to think i was a terrible mother',
#  'it is beautiful i see it now',
#  'i do not see it',
#  'i saw that',
#  'that is our baby',
#  'hi listen i am sorry about before',
#  'i am sorry too',
#  'before',
#  'we do not have to make that a guest room',
#  'we do not have to make that a guest room',
#  'we can easily think of a way for us both to enjoy the room',
#  'what are you doing',
#  'brenda a bee',
#  'brenda a bee',
#  'it is flown into your blouse',
#  'you would better undo your buttons lest it sting you',
#  'i think i know what going on here',
#  'it must be hard that your wife is a lesbian',
#  'that is gonna leave a stain',
#  'it is fine you are at joey',
#  'you are at joey',
#  'i have never lived like this before',
#  'i have never lived like this before',
#  'chandler is worse',
#  'remembering stuff like that',
#  'i know monica worst thanksgiving',
#  'tell this story',
#  'let not tell this story',
#  'it is the one where joey got monica turkey stuck on his head',
#  'i know it is the one where joey got monica turkey stuck on his head',
#  'what joey got a turkey stuck on his head',
#  'you did not',
#  'i tell issac everything',
#  'you dog',
#  'how much we love em monogamy is too cruel a rule',
#  'we got to look out for each other we are the same you and me',
#  'we got to look out for each other we are the same you and me',
#  'we got to look out for each other we are the same you and me',
#  'we got to look out for each other we are the same you and me',
#  'she is directing the new al pacino movie you gotta get me an audition',
#  'i have not talked to her in like ten years',
#  'how was your audition',
#  'i am just practicing blowing you off',
#  'i am gonna be a big movie star',
#  'you got it',
#  'the audition went really good',
#  'the audition went really good',
#  'it is really classy',
#  'it is really classy',
#  'and the director is supposed to be the next next martin scorcese',
#  'and the director is supposed to be the next next martin scorcese',
#  'hello',
#  'they loved me',
#  'they want me to be totally naked in the movie',
#  'they want me to be totally naked in the movie',
#  'they want me to be totally naked in the movie',
#  'my grandmother gonna see this',
#  'ross wait',
#  'you suck',
#  'you suck',
#  'i lost',
#  'i lost',
#  's',
#  'nimitz and sold over two zero zero zero boxes',
#  'how would the interview go',
#  'i blew it i would not of even hired me',
#  'i blew it i would not of even hired me',
#  'that is not how that was supposed to come out',
#  'i lost',
#  'i blew it i would not of even hired me',
#  'this is the worst christmas ever',
#  'stay here at the coffee house',
#  'it is too late',
#  'terry already hired that girl over there',
#  'terry already hired that girl over there',
#  'she is even got waitress experience',
#  'terry already hired that girl over there',
#  'she is even got waitress experience',
#  'last night she was teaching everybody how to make napkin swans',
#  'he forgot to leave his grip size',
#  'he did not get the goggles',
#  'do they wait for me to do this',
#  'what are you guys doing here',
#  'he is not even wearing a jockstrap',
#  'that would be a shutdown',
#  'and that would be a shutdown',
#  'where are you guys going come on one more game',
#  'where are you guys going come on one more game',
#  'it is two three zero in the morning',
#  'where are you guys going come on one more game',
#  'it is two three zero in the morning',
#  'get out',
#  'you guys are always hanging out in my apartment',
#  'one more game',
#  'oh yeah',
#  'he says that walking with you makes this strange city feel like home',
#  'your eyes are very pretty',
#  'your eyes are very pretty',
#  'he is only had sex with one woman',
#  'he is only had sex with one woman',
#  'it is sweet it is romantic',
#  'it is romantic',
#  'he is only had sex with one woman',
#  'you kidding the guy a freak i judge him',
#  'that is attractive',
#  'i thought you were great in silence of the lambs',
#  'admit it all things considered you had fun tonight',
#  'admit it all things considered you had fun tonight',
#  'which part was the fun part where is my puck',
#  'the kid has it',
#  'that is my puck',
#  'i found it finders keepers losers weepers',
#  'gimme back my puck',
#  'no',
#  'no rough holding in my er',
#  'gimme back my puck',
#  'no',
#  'now that was fun',
#  'what we did was wrong',
#  'i just had sex',
#  'ethan focus how could you not tell me',
#  'you never told me how old you were',
#  'how could you not tell me',
#  'you never told me how old you were',
#  'my lie did not make one of us a felon in four eight states',
#  'how could you not tell me',
#  'my lie did not make one of us a felon in four eight states',
#  'how could you not tell me',
#  'my lie did not make one of us a felon in four eight states',
#  'what were you thinking',
#  'i was not thinking i was too busy falling',
#  'do not say it',
#  'i was not thinking i was too busy falling',
#  'in love with you',
#  'how could you not tell me',
#  'my lie did not make one of us a felon in four eight states',
#  'what were you thinking',
#  'i just had sex with somebody that was not alive during the bicentennial',
#  'how could you not tell me',
#  'i just had sex with somebody that was not alive during the bicentennial',
#  'how could you not tell me',
#  'you should not even be here it is a school night',
#  'i just had sex with somebody that was not alive during the bicentennial',
#  'i am like those women that you see with shiny guys named chad',
#  'i just had sex with somebody that was not alive during the bicentennial',
#  'i am like those women that you see with shiny guys named chad',
#  'i do not wanna die',
#  'i do not wanna die',
#  'it will be fun we can come back and we can haunt these guys',
#  'check out the ring',
#  'check out the ring',
#  'nice one and a half carat easy',
#  'hi',
#  'chandler gonna ask monica to marry him',
#  'chandler gonna ask monica to marry him',
#  'chandler gonna ask monica to marry him',
#  'i helped pick out the ring',
#  'you told her before you told us',
#  'i say you go in there and be the most committed guy there ever was',
#  'that makes sense',
#  'i say you go in there and be the most committed guy there ever was',
#  'amazingly that makes sense',
#  'jump off the high dive',
#  'jump off the high dive',
#  'if i am staring down the barrel of a gun',
#  'i do not know what i am going to do',
#  'i called the company that sent and th they do not care',
#  'they laughed at me if this is not an emergency then what is',
#  'i called the company that sent and th they do not care',
#  'i called nine one one and they laughed at me',
#  'hey guys',
#  'hey guys',
#  'hey',
#  'last night what a great party',
#  'the guys from work had a blast',
#  'what a great party',
#  'the guys from work had a blast',
#  'one of them had never been to a bachelor party before',
#  'another one had never been to a party before',
#  'that uh that wedding ring huh man that is nice',
#  'that is nice',
#  'i might want to get one of those',
#  'the ring is irreplaceable',
#  'every bride who has worn it has had a long and happy life',
#  'every bride who has worn it has had a long and happy life',
#  'so you might say it is a magic ring',
#  'you you you had sex with ursula',
#  'you you you had sex with ursula',
#  'i thought she was you',
#  'you you you had sex with ursula',
#  'i thought she was you and i kissed her',
#  'she was wearing different clothes',
#  'you you you had sex with ursula',
#  'i thought she was you and i kissed her',
#  'you you you had sex with ursula',
#  'i thought she was you and i kissed her and',
#  'this is too weird',
#  'this is too weird',
#  'i do not want to lose you',
#  'i thought she was you yeah it is too weird',
#  'i thought she was you yeah it is too weird',
#  'this is it',
#  'i guess this is it',
#  'it just would not have been feasible',
#  'it just would not have been feasible',
#  'having a dove place the ring on your finger would have been no problem',
#  'it was really fun being married to you tonight',
#  'it was really fun being married to you tonight',
#  'it was the easiest four zero zero bucks i have ever made',
#  'it was stupid',
#  'it was stupid',
#  'with the with the lilies and and the song and the stars',
#  'with the with the lilies and and the song and the stars',
#  'it was really wonderful',
#  'did you just make that up',
#  'and your breasts',
#  'you are coming on a little strong',
#  'i write erotic novels for children',
#  'i write erotic novels for children',
#  'i have a ph d',
#  'whazzup',
#  'whazzup',
#  'make sure nothing happens between him and molly',
#  'you do not trust him',
#  ...]

# %%
metrics = findEvalMetrics(true_labels, pred_labels)
metrics
# Out:
# [nltk_data] Downloading package wordnet to /home/nsl/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /home/nsl/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/nsl/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [[{'bleu': 0.7968855295258308,
#    'precisions': [0.8980452280567267],
#    'brevity_penalty': 0.8873556750033685,
#    'length_ratio': 0.8932484250890167,
#    'translation_length': 13045,
#    'reference_length': 14604},
#   {'bleu': 0.7903650243044782,
#    'precisions': [0.8980452280567267, 0.8834088687461121],
#    'brevity_penalty': 0.8873556750033685,
#    'length_ratio': 0.8932484250890167,
#    'translation_length': 13045,
#    'reference_length': 14604},
#   {'bleu': 0.7842001659169244,
#    'precisions': [0.8980452280567267, 0.8834088687461121, 0.8700167855644146],
#    'brevity_penalty': 0.8873556750033685,
#    'length_ratio': 0.8932484250890167,
#    'translation_length': 13045,
#    'reference_length': 14604},
#   {'bleu': 0.777436437515643,
#    'precisions': [0.8980452280567267,
#     0.8834088687461121,
#     0.8700167855644146,
#     0.8536523610583618],
#    'brevity_penalty': 0.8873556750033685,
#    'length_ratio': 0.8932484250890167,
#    'translation_length': 13045,
#    'reference_length': 14604}],
#  {'meteor': 0.8423298079807521}]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report, f1_score
accuracy = accuracy_score(true_labels, pred_labels)
precision = precision_score(true_labels, pred_labels, average='weighted', zero_division=1)
recall = recall_score(true_labels, pred_labels, average='weighted', zero_division=1)
f1 = f1_score(true_labels, pred_labels, average='weighted', zero_division=1)

# %%
print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1 Score: {f1}')
# Out:
# Accuracy: 0.6166294642857143
# Precision: 0.9844447544642857
# Recall: 0.6166294642857143
# F1 Score: 0.6218154167261309

# %%
# context = 'all right look you are not really gonna buy that are you do not you think you have embarrassed me enough for one day'
# question = 'oh i embarrass you'
# ans = 'you have embarrassed me enough for one day'
# question = 'Ohh , you are about to get a little luckier .'
# context = 'You look amazing . I am the luckiest man in the world .'
# answer = 'You look amazing . I am the luckiest man in the world .'
# from transformers import pipeline

# question_answerer = pipeline("question-answering", model="../models/span_nz", tokenizer="../models/span_nz", device=device)
# test_predictions = question_answerer(question=question, context=context)
# test_predictions
# from transformers import AutoTokenizer

# tokenizer = AutoTokenizer.from_pretrained("my_awesome_qa_model")
# inputs = tokenizer(question, context, return_tensors="pt")
# import torch
# from transformers import AutoModelForQuestionAnswering

# model = AutoModelForQuestionAnswering.from_pretrained("my_awesome_qa_model")
# with torch.no_grad():
#     outputs = model(**inputs)
# answer_start_index = outputs.start_logits.argmax()
# answer_end_index = outputs.end_logits.argmax()
# predict_answer_tokens = inputs.input_ids[0, answer_start_index : answer_end_index + 1]
# tokenizer.decode(predict_answer_tokens)
